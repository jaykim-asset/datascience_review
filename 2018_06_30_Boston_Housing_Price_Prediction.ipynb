# %%
from sklearn.datasets import load_boston
from statsmodels.graphics import utils

boston = load_boston()

dfX0 = pd.DataFrame(boston.data, columns = boston.feature_names)
dfX = sm.add_constant(dfX0)
dfy = pd.DataFrame(boston.target, columns = ['MEDV'])

model_boston = sm.OLS(dfy, dfX)
result_boston = model_boston.fit()

# %%
dfX
# Out:
#      const      CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD  \
# 0      1.0   0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0
# 1      1.0   0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0
# 2      1.0   0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0
# 3      1.0   0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0
# 4      1.0   0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0
# 5      1.0   0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0
# 6      1.0   0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0
# 7      1.0   0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0
# 8      1.0   0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0
# 9      1.0   0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0
# 10     1.0   0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0
# ...

# %%
print(result_boston.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Sat, 30 Jun 2018   Prob (F-statistic):          6.95e-135
# Time:                        11:56:06   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.4911      5.104      7.149      0.000      26.462      46.520
# ...

# %%
## 위에서 만든 result_boston 모형에 다시 dfX의 Data를 넣고 예측모형을 돌림
pred = result_boston.predict(dfX)

# %%
#################### IgNore this (Just to see what's going on) #######
df_checking = pd.DataFrame(dfy['MEDV'])
df_checking['pred'] = pred
df_checking.tail()
# Out:
#      MEDV       pred
# 501  22.4  23.532617
# 502  20.6  22.378698
# 503  23.9  27.629342
# 504  22.0  26.129838
# 505  11.9  22.348703

# %%
df_checking['MEDV'].mean(), df_checking['pred'].mean()
# Out:
# (22.532806324110698, 22.532806324110105)

# %%
df_checking['MEDV'].std(), df_checking['pred'].std()
################### igNore this #######################################
# Out:
# (9.19710408737982, 7.914896236677318)

# %% [markdown]
# #### - Outlier 찾기: 잔차가 큰 데이터 (표준화 잔차)

# %%
result_boston_outlier = result_boston.resid_pearson

# %%
# 시각화 하기
# %matplotlib inline
plt.figure(figsize=(10,2))
plt.stem(result_boston.resid_pearson)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# #### - Leverage 찾기

# %%
influence_boston = result_boston.get_influence()
hat = influence_boston.hat_matrix_diag

# %%
# 시각화 하기
plt.figure(figsize = (10, 2))
plt.stem(hat)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# #### - Cook's Distance
# - 잔차와 레버리지를 동시에 보기위한 기준으로 Cook's Distance
# - 레버리지가 커지거나 잔차의 크기가 커지면 Cook's Distance 값이 커진다.
# - Fox' Outlier Recommendation은 Cook's Distance가 다음과 같은 기준보다
# - 클 때 아웃라이어로 판단하자는 것.
# - Di > 4 / N - K - 1
# - 모든 데이터의 레버리지와 잔차를 동시에 보려면 plot_leverage_resid2 사용
#     - X축: 표준화 잔차의 제곱
#     - Y축: 레버리지값

# %%
cooks_distance, pvals = influence_boston.cooks_distance
fox_recommendation = 4 / (len(dfy) - 2)
idx = np.where(cooks_distance > fox_recommendation)[0]
idx
# Out:
# array([ 64, 141, 148, 161, 162, 163, 166, 186, 195, 204, 214, 225, 228,
#        233, 253, 262, 267, 364, 365, 367, 368, 369, 370, 371, 372, 374,
#        375, 380, 412, 414], dtype=int64)

# %%
ax = plt.subplot()
plt.scatter(dfy, pred)
plt.scatter(dfy.MEDV[idx], pred[idx], s=300, c="r", alpha=0.5)
utils.annotate_axes(range(len(idx)), idx, 
                    list(zip(dfy.MEDV[idx], pred[idx])), [(-20, 15)] * len(idx), size="small", ax=ax)

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
sm.graphics.plot_leverage_resid2(result_boston)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
idx2 = list(set(range(len(dfX))).difference(idx))
dfX = dfX.iloc[idx2, :].reset_index(drop=True)
dfy = dfy.iloc[idx2, :].reset_index(drop=True)
model_boston2 = sm.OLS(dfy, dfX)
result_boston2 = model_boston2.fit()
print(result_boston2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     175.4
# Date:                Sat, 30 Jun 2018   Prob (F-statistic):          3.07e-169
# Time:                        11:54:24   Log-Likelihood:                -1226.7
# No. Observations:                 476   AIC:                             2481.
# Df Residuals:                     462   BIC:                             2540.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.9186      4.002      5.227      0.000      13.054      28.783
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# - result_boston의 Loss of Fit Probability = 6.95e-135
# - result2_boston의 Loss of Fit Probability = 3.07e-169
# - result2의 성능이 개선되었다
