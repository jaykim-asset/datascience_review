# %% [markdown]
# ### 확률의 수학적 정의
# - 우리는 초등학교부터 고등학교, 그리고 대학교에 이르기까지 확률에 대한 여러가지 지식을 배운다. 그러나 그 교육과정 어디에도 확률의 수학적 정의를 명확히 서술한 내용은 보기 힘들다. 확률의 수학적 정의를 아는 것은 확률과 관련된 복잡한 문제를 푸는것 뿐 아니라 지금까지 생각해오던 확률에 대한 관점을 새롭게 환기시키는데 큰 도움이 된다. 여기에서는 확률의 수학적 정의를 살펴보고 필요한 개념을 소개한다.
# - 확률을 정의하려면 다음의 3가지 개념을 알아야 한다.
#     - 확률 표본
#     - 표본 공간
#     - 사건

# %% [markdown]
# ### 표본 공간과 확률 표본
# - 확률은 우리가 현실에서 해결하고자 하는 문제와 결부하여 정의한다. 예를 들어 다음과 같은 문제들을 생각해보자.
#     1. 동전을 한번 던졌다. 동전이 앞면이 나올 것인가 뒷면이 나올 것인가?
#     2. 플레잉카드뭉치에서 카드 한장을 선택하였다. 이 카드는 어떤 무늬인가?
#     3. 주사위를 던져 하나의 숫자가 나왔다. 이 숫자는 무엇인가?
#     4. 약속 날짜를 정하기로 했다. 결정된 날짜가 31일인가 아닌가?
#     5. 과일가게에서 손님이 과일을 하나 샀다. 이 과일은 어떤 과일인가?
#     6. 삼성전자 주식의 가격은 내일 몇 % 오를까?
#     7. 자다가 갑자기 잠을 깨고 시계를 보았다. 시계의 분침은 몇 분을 가리키고 있을까?
#     8. 체온을 측정하였다. 체온이 몇 도일까?
# - 이 문제들의 공통점은 답을 100% 확신할 수 없다는 점이다. 어떤 문제는 무엇이 답인지 전혀 예측할 수 없는 것도 있고 어떤 문제는 어느 정도 정확도 혹은 범위내에서 예측할 수 있는 것도 있다. 확률론은 이러한 문제가 어떤 답을 가질 수 있고 그 답의 신뢰성을 계산하는 정량적인 방법을 제시한다.

# %% [markdown]
# - 이러한 문제를 확률론의 방법으로 접근하기 위해 우선 확률 표본(sample)과 표본 공간(sample space)을 정의해야 한다.
# - **확률 표본 or 표본 (sample)**은 풀고자 하는 확률적 문제에서 발생할 수 있는 하나의 현상, 혹은 선택될 수 있는 하나의 경우를 말한다.
# - **표본 공간 (sample space)**는 답이 될 수 있는 혹은 선택될 수 있는 모든 표본의 집합을 말한다. 보통 $\Omega$라는 그리스 문자로 표기한다.
# - 표본 공간을 정의한다는 것은 어떤 경우(현상)이 가능하고 어떤 경우(현상)이 가능하지 않은가를 정의하는 작업.

# %% [markdown]
# - 예를 들어 동전 던지기 문제에서는 "앞면(H)이 나오는 현상" or "뒷면(T)이 나오는 결과"가 각각 표본이 될 수 있다.

# %% [markdown]
# #### 연습 문제 1
# - 1. 주사위를 던져 나오는 숫자를 구하는 문제를 확률론적으로 접근 할 때, 표본 공간 $\Omega$를 구하라.
#     - i) 주사위를 던졌을 때 숫자가 1이 나오는 현상
#     - ii) 주사위를 던졌을 때 숫자가 2가 나오는 현상
#     - iii) 주사위를 던졌을 때 숫자가 3이 나오는 현상
#     - iv) 주사위를 던졌을 때 숫자가 4가 나오는 현상
#     - v) 주사위를 던졌을 때 숫자가 5가 나오는 현상
#     - vi) 주사위를 던졌을 때 숫자가 6이 나오는 현상
#     - 표본공간은 i) ~ vi)까지
# - 2. 약속 날짜를 정하기로 했다. 결정된 날짜가 31일인가 아닌지 구하는 문제를 확률론적으로 접근할 때 표본 공간 $\Omega$를 구하라
#     - 1/ 31이 될 수도 있고, 7 / 365도 될수도 있고 더 나아가 윤년도 계산

# %% [markdown]
# - 표본 공간은 풀고자하는 문제에 의해 정해진다. 예를 들어 과일가게에서 손님이 산 과일을 맞추는 문제에서 표본공간은 그 과일에서 파는 과일에 따라 달라진다. 예를 들어 사과와 오렌지만 파는 과일가게였다면, 표본 공간은 다음과 같을 것
# - $\Omega$ = {A, O}
# - 표본이 연속적인 숫자인 경우에는 표본 공간이 무한개의 원소를 가질 수 있다. 예를 들어 삼성전자의 주식은 다음날 -30%부터 30%까지 내리거나 오를 수 있다. 따라서 표본 공간은 다음과 같다.
# - $\Omega$ = {x: -30 <= x <= 30}
# - 이 표본 공간은 구간이 정해져 있어도 구갠내 모든 실수의 원소로 가지므로 원소의 갯수가 무한개이다 (정확히 말하면 매매시 틱사이즈라고 부르는 가격단위가 정해져 있으므로 원소의 갯수는 무한개는 아니다. 그러나 여기에서는 이를 무시하기로 하자.)

# %% [markdown]
# #### 연습문제 2
# - 1. 잠을 자다 깨어나 시계를 보았을 때 분침이 가리키는 각도를 표본이라고 하면, 표본 공간 $\Omega$는? 이 표본 공간의 표본의 갯수는?
#     - 표본: 각도는 정확한 숫자가 아니라서, 0
#     - 표본의 공간: 무한대
#     - 표본 공간의 표본의 개수: 무한대
# - 2. 측정한 체온을 표본이라고 하면, 표본 공간 $\Omega$는? 이 표본 공간의 표본의 갯수는?
#     - 표본 공간(체온): 무제한
#     - 표본 공간의 표본의 갯수: 무제한

# %% [markdown]
# ### 사건
# - 사건(event)는 표본공간의 부분집합.
# - 즉, 전체 표본 공간 중에서 우리가 관심을 가지고 있는 일부 표본의 집합을 뜻한다.
# - 위에서 예로 든 동전 표본 공간에서는 가능한 사건(부분집합)은 다음과 같다.
#     - A = {} = 0
#     - B = {H}
#     - C = {T}
#     - D = {H, T}
# - 예로 든 B라는 사건은 "동전의 앞면이 나오는 경우"를 뜻하고 D라는 사건은 "동전의 앞면이 나오거나 뒷면이 나오는 경우"를 뜻하며, 이를 다른 말로 하면 "3보다 큰 숫자가 주사위의 윗면이 되는 경우"를 뜻한다. "~가 나오는 경우"라고 ㅁ라할 때, 이 "경우"라는 개념이 바로 사건(부분집합)에 해당한다.
# - 파이썬으로 다음처럼 부분집합의 집합을 구현할 수 있다. 부분집합을 set자료형이 아닌 frozenset 자료형으로 만드는 이유는 딕셔너리 key로 사용하기 위함.

# %%
A = frozenset([])
B = frozenset(['H'])
C = frozenset(['T'])
D = frozenset(['H', 'T'])
set([A, B, C, D])
# Out:
# {frozenset(), frozenset({'H'}), frozenset({'T'}), frozenset({'H', 'T'})}

# %% [markdown]
# #### 연습 문제 4
#
# 1. 플레잉카드 한장을 뽑아서 무늬를 결정하는 문제의 표본 공간 $\Omega$의 모든 사건을 구하고 이를 `frozenset`의 `set`으로 만든다.
# 2. 주사위를 하나 던져서 숫자를 결정하는 문제의 표본 공간 $\Omega$의 모든 사건을 구하고 이를 frozenset의 set으로 만든다.

# %% [markdown]
# ### 확률 (Probability)
# - 확률: 사건(부분집합)을 입력하면 숫자(확률값)이 출력되는 함수.
# - 확률의 정의역은 표본 공간의 모든 사건(부분집합)의 집합이다. (주의: 엄격한 정의로는 모드느 사건의 집합이 아니라 시그마 대수(sigma algebra)라는 특별한 사건 집합에 대해서만 정의하면 된다. 하지만 여기에서는 시그마 대수는 고려하지 않기로 한다.)
# - 사건(부분집합) -> 확률값(숫자)

# %% [markdown]
# - 즉, 모든 각각의 사건(부분 집합)에 어떤 숫자를 할당한 것이 확률이다.
# - 다만 이 함수는 다음과 같은 세가지 규칙을 지켜야 한다.
#     - 1) 모든 사건에 대하여, 사건은 실수이며, 0 또는 양수이다.
#     - 2) 전체집합의 사건의 경우 확률은 1이다.
#     - 3) 공통 원소가 없는 경우, 두 사건의 합집합의 확률은 각각의 사건 확률의 합과 같다.
#     - 이 세가지를 **콜모고로프의 공리**라고 한다.

# %% [markdown]
# ### 확률은 표본이 아닌 사건을 입력으로 가지는 함수
# - 확률에 대해 사람들이 흔히 가지고 있는 오해는 확률이 "표본 하나 하나에 대해 정의되어 있는 숫자"라는 것이다.
# - 표본 -> 숫자
# - 즉, 표본을 입력하여 숫자(확률값)을 출력하는 함수라고 잘못 알고 있다. 예를 들어 주사위를 던져 숫자 1이 나타날 다음처럼 생각한다.
# - P(1) = 1/6
# - 하지만, 확률은 표본이 아닌 **사건에 대해 정의** 해야 하므로, 이 수식은 틀렸다 (이 식의 P는 확률이 아니라, 확률질량함수). 올바른 식은 다음과 같다.
# - P({1}) = 1/6

# %% [markdown]
# ### 주사위 한 면의 확률은 정말 1/6?
# - 위에서 주사위의 확률값 할당을 이야기 할 때, 호가률을 정의한 "예"라는 말을 썻다는 점을 주의하자. 그렇다면 P({1}) = 1/6이 아닌 경우도 있다는 말인가? 답은 "그렇다"이다, 왜 일까? 주사위의 면은 6개이니깐 당연히 나올 수 있는 경우의 수는 6개, 따라서 1을 6으로 나눈 값이 아니란 말인가?
# - 여러분 손에 현실의 주사위가 있다고 하자. 그 주사위를 던지면 정말로 특정한 하나의 면이 나올 가능성이 "정확하게" 6분의 1일까? 이렇게 묻는다면 대부분은 "정확하게는 그렇지 않다"고 대답할 것이다. 그 이유는 주사위를 아주 정밀하게 만들지 않으면 어떤 면이 미세하게나마 더 잘나오게되는 경우가 발생할 수 있기 때문이다. 더 극단적인 경우를 생각해 보자. 누군가가 주사위 도박에서 사기를 치기 위해 특수한 주사위를 만들었다고 하자. 이 주사위는 절대로 6이 나오지 않으며 10번을 던지면 5번은 반드시 1이 나오게 만들었다면?  이 때는 확률값이 어떻게 할당되어 있는 상태인가?

# %% [markdown]
# - 이 때는 확률이 다음과 같이 할당되어 있다고 할 수 있다.
# - P({1}) = 0.5
# - P({6}) = 0
# - 전체 사건의 확률들이 콜모고로프 정의만 만족하면 된다.

# %% [markdown]
# - 그렇다면 우리는 왜 지금까지 주사위의 한 면이 나올 확률을 1/6이라고 생각해 왔던 것일까? 그 이유는 확률의ㅡ 정의와는 무관한 다음 사실을 가정하고 있기 때문이다.
#     - 주사위가 공정(Fair)한 주사위이다. 혹은 공정하지 않다고 생각할 수 있는 증거가 아직 없다.
# - 주사위가 공정하다면 특정한 주사위 하나의 면이 나올 확률값은 모두 같고 이를 x라고 하자.
# - P({1}) = P({2}) = P({3}) = P({4}) = P({5}) = P({6}) = x
# - 그리고 이 사건들은 서로 공통원소가 없고 합집합은 전체 집합이므로, 확률의 성징을 이용하여 다음과 같이 확률이 1/6임을 구할 수가 있다.
# - P({1}) + P({2}) + P({3}) + P({4}) + P({5}) + P({6}) = 6x = P({1,2,3,4,5,6}) = P(omega) = 1
# - x = 1/6

# %% [markdown]
# - 즉 이 방법은 확률 값을 만드는 방법의 하나일 뿐이고 현식에서 꼭 이대로 확률 값 즉, 숫자를 배당할 이유는 없다.
# - 이 논리에 따르면 표본의 갯수가 유한하고 각 사건에 대해 원소의 갯수 이외의 아무런 정보가 없다면 각 사건의 확률은 다음과 같다고 보는 것이 타당.
# - P(A) = card(A)/card(omega)
# - 그러나, 만약 다른 곳에서 얻은 정보(예:도메인지식)이나 표본에 대한 데이터가 존재하는 경우에는 보다 믿을 수 있는 확률 값을 계산할 수 있다.

# %% [markdown]
# ### 단순사건과 확률질량 함수
# - 콜로고로프의 정리를 사용하면 어떤 사건의 확률값을 이용하여 다른 사건의 확률 값을 계산할 수 있다.
# - 단순사건 (Atomic Event): 표본을 1개만 가지는 사건.
# - 단순사건은 교집합을 가지지 않으므로, 유한개의 사건만 있는 경우, 모든 단순사건의 확률 값을 알면 콜모고로프의 세번째 공리에 의해 다른 모든 사건의 확률값을 계산할 수 있다.
# - 예를 들어 P({1}) = 0.1, P({2}) = 0.3, P({3}) = 0.4, P({4}) = 0.2
# - 다음처럼 모든 사건에 대학 확률을 계산할 수 있다.
# - P({1, 2}) = 0.1 + 0.3 = 0.4
# - 확률질량함수(probability mass function): 표본이 숫자인 경우, 사건 대신 숫자를 입력으로 가지고 확률값을 출력하는 함수p
# - 확률과 확률 질량함수는 다른  개념
# - 확률: P({1}) = 0.2
# - 확률질량함수: p(1) = 0.2
# - 확률: P({1,2}) = 0.3
# - 확률질량함수: p(1,2) = 정의되지 않는다.

# %% [markdown]
# ### 표본의 수가 무한한 경우
# - 왜 확률을 정의 할 때, 입력을 표본이 아닌 사건으로 정의하였을까? 다시 말해 왜 확률값을 표본에 대해 할당하지 않고 사건에 대해 할당하였을까? 그 이유는 표본의 수가 무한한 경우를 다루기 위해서이다.
# - 잠에서 깨어나 시계를 보았을 때 시계의 분침이 이루는 각도를 결정하는 문제를 생각하자. 정각 12시를 가리킨다면 0도이고 정각 1시를 가리키면 30도이다. 그렇다면 이 시계 바늘 문제에서 분침이 정각 12시를 가르킬 확률 즉, 각도가 정확하게 0도가 될 확률은 얼마일까?
# - 만약 모든 각도에 대해 가능성이 똑같다면, 바늘이 정각 12시를 가르킬 확률 즉, 각도가 정확하게 0이 될 확률은 0이다.
# - P({degree = 0}) = 0
# - 각도가 0이 아닌 어떤 경우도 마찬가지이다. 예를 들어 시계 바늘이 1시를 가리키는 경우, 즉 각도가 30도가 되는 경우도 마찬가지이다.
# - P({degree = 30}) = 0
# - 왜 그럴까? 모든 각도에 대해 가능성이 똑같으므로 그 확률을 x라는 값이라고 하자. 그런데 각도가 나올 수 있는 경우는 무한대의 경우가 있으므로 만약 x가 0이 아니라면 x * infinite = infinite로 전체 표본 집합의 확률이 무한대가 된다. 즉, 1이 아니다. 따라서 표본의 수가 무한하고 모든 표본에 대해 표본 하나만을 가진 사건의 확률이 동일하다면, 표본 하나에 대한 사건의 확률은 언제나 0이다.

# %% [markdown]
# - 이번에는 다음과 같은 사건을 생각해보자, 확률은 얼마라고 말할 수 있을까?
#     - 시계 바늘이 12와 1시 사이에 있는 경우, 즉 각도가 0보다 크고 같거나 30보다 작은 경우
#     - P({0 <= x <= 30}) = 1/12
#     - 이 경우에는 동일한 가능성을 지닌 사건 12개가 있으므로 전체집합의 확률 1을 12로 나누어주면 주어진 사건에 대한 확률은 1/12 가 된다.
# - P({0 <= x <= 60 or 90<= x <= 150}) = 4/12 = 1/3

# %% [markdown]
# - 다만 원소의 수가 무한대인 표본 집합의 경우에는 사건의 수도 무한대이므로 확률을 할당하거나 어떻게 할당했는지 다른 사람에게 설명하기 어렵다. 이경우에는 확률밀도 함수(probability density Function)을 사용하면 된다.
