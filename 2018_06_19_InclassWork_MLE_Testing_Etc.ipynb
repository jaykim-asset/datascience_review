# %%
# 연습 문제 1
# 1. N = 10이고 유의 수준이 10%라면, 앞면이 나온 횟수가 몇 번 이어야지 
# 동전이 fair하지 않다고 이야기기 할 수 있을까?
N = 10
p_sig = 0.1
theta = 0.2
np.random.seed(0)
x = sp.stats.bernoulli(theta).rvs(N)
n = np.count_nonzero(x)
n
# Out:
# 2

# %%
sp.stats.binom_test(n, N)
# Out:
# 0.10937500000000003

# %%
# 앞면이 나온 횟수가 1번이어야, 동전이 fair하지 않다고 이야기 할 수 있습니다.
# 앞면이 나온 횟수가 9번이야, 동전이 fair하지 않다고 이야기 할 수 있습니다.

# %%
# 2. N =1000이고 유의 수준이 10%이라면 앞면이 나온 횟수가 몇 번 이어야지
# 동전이 fair하지 않다고 이야기 할 수 있을까? 이 때, fair하다고 이야기 할 수 있는
# 경우의 범위는 N = 10일 때와 비교하여 넓은가 혹은 좁은가?
N_1 = 1000
theta_1 = 0.47
np.random.seed(1)
x_1 = sp.stats.bernoulli(theta_1).rvs(N_1)
n_1 = np.count_nonzero(x_1)
n_1
# Out:
# 472

# %%
sp.stats.binom_test(n_1, N_1)
# Out:
# 0.08193870178886331

# %%
# theta = 0.47 -> 472번
# theta = 0.4

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
Female = tips[tips['sex'] == 'Female']
Female = Female[['sex', 'smoker']].reset_index()
Female = Female.groupby(['smoker', 'sex']).size().reset_index(name = 'counts')
Female.reset_index(drop=True, inplace=True)
Female
# Female = Female.groupby('smoker').size().reset_index(name = 'counts')
# Female = Female.sort_values(by=['counts'], ascending=False)
# Female.reset_index(drop=True, inplace=True)
# Out:
#   smoker     sex  counts
# 0    Yes  Female      33
# 1     No  Female      54

# %%
# 문제 3. 
# 1. 여자 손님 중 비흡연자가 흡연자보다 많다고 할 수 있는가?
N = 87
theta = 0.5
np.random.seed(0)
x = sp.stats.bernoulli(theta).rvs(N)
n = np.count_nonzero(x)
n
#
# Out:
# 43

# %%
# %matplotlib inline
plt.hist(33, )

# %%
# 2. 저녁에 오는 여자 손님 중 비흡연자가 흡연자보다 많다고 할 수 있는가?
Female = tips[(tips['sex'] == 'Female') & (tips['time'] == 'Dinner')]
Female = Female[['sex', 'smoker', 'time']].reset_index()
Female = Female.groupby(['smoker', 'sex', 'time']).size().reset_index(name = 'counts')
Female.reset_index(drop=True, inplace=True)
Female
# Out:
#   smoker     sex    time  counts
# 0    Yes  Female  Dinner      23
# 1     No  Female  Dinner      29

# %%
# 2. 저녁에 오는 여자 손님 중 비흡연자가 흡연자보다 많다고 할 수 있는가?
N = 52
theta = 0.5
x_1 = sp.stats.bernoulli(theta).rvs(N)
n = np.count_nonzero(x_1)
n
# Out:
# 29

# %%
n = np.array([10, 0, 0, 0])

# %%
n
# Out:
# array([10,  0,  0,  0])

# %%
sp.stats.chisquare(n)
# Out:
# Power_divergenceResult(statistic=30.0, pvalue=1.3800570312932553e-06)

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...
