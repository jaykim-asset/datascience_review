# %%
data_key = pd.read_csv('key.csv')
data_weather = pd.read_csv('weather.csv')
data_train = pd.read_csv('train.csv')

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'} #retina 및 png압축

# %%
data_weather_nan = data_weather.copy()
data_weather_filled = data_weather.copy()
data_weather_nan
# Out:
#        station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat  \
# 0                1  2012-01-01   52   31   42      M       36      40   23
# 1                2  2012-01-01   48   33   41     16       37      39   24
# 2                3  2012-01-01   55   34   45      9       24      36   20
# 3                4  2012-01-01   63   47   55      4       28      43   10
# 4                6  2012-01-01   63   34   49      0       31      43   16
# 5                7  2012-01-01   50   33   42      M       26      35   23
# 6                8  2012-01-01   66   45    M      M       34      46    M
# 7                9  2012-01-01   34   19   27      M       17      23   38
# 8               10  2012-01-01   73   53   63      M       55      58    2
# 9               11  2012-01-01   72   48   60      7       54      56    5
# 10              12  2012-01-01   72   48   60      M       54      57    5
# ...

# %%
data_weather_nan['tmax'] = pd.to_numeric(data_weather_nan['tmax'], errors = 'coerce')
data_weather_nan['tmin'] = pd.to_numeric(data_weather_nan['tmin'], errors = 'coerce')
data_weather_nan['tavg'] = pd.to_numeric(data_weather_nan['tavg'], errors = 'coerce')
data_weather_nan['depart'] = pd.to_numeric(data_weather_nan['depart'], errors = 'coerce')
data_weather_nan['dewpoint'] = pd.to_numeric(data_weather_nan['dewpoint'], errors = 'coerce')
data_weather_nan['wetbulb'] = pd.to_numeric(data_weather_nan['wetbulb'], errors = 'coerce')
data_weather_nan['heat'] = pd.to_numeric(data_weather_nan['heat'], errors = 'coerce')
data_weather_nan['cool'] = pd.to_numeric(data_weather_nan['cool'], errors = 'coerce')
data_weather_nan['snowfall'] = pd.to_numeric(data_weather_nan['snowfall'], errors = 'coerce')
data_weather_nan['preciptotal'] = pd.to_numeric(data_weather_nan['preciptotal'], errors = 'coerce')
data_weather_nan['stnpressure'] = pd.to_numeric(data_weather_nan['stnpressure'], errors = 'coerce')
data_weather_nan['sealevel'] = pd.to_numeric(data_weather_nan['sealevel'], errors = 'coerce')
data_weather_nan['resultspeed'] = pd.to_numeric(data_weather_nan['resultspeed'], errors = 'coerce')
data_weather_nan['resultdir'] = pd.to_numeric(data_weather_nan['resultdir'], errors = 'coerce')
data_weather_nan['avgspeed'] = pd.to_numeric(data_weather_nan['avgspeed'], errors = 'coerce')

# %%
data_weather_nan
# Out:
#        station_nbr        date  tmax  tmin  tavg  depart  dewpoint  wetbulb  \
# 0                1  2012-01-01  52.0  31.0  42.0     NaN      36.0     40.0
# 1                2  2012-01-01  48.0  33.0  41.0    16.0      37.0     39.0
# 2                3  2012-01-01  55.0  34.0  45.0     9.0      24.0     36.0
# 3                4  2012-01-01  63.0  47.0  55.0     4.0      28.0     43.0
# 4                6  2012-01-01  63.0  34.0  49.0     0.0      31.0     43.0
# 5                7  2012-01-01  50.0  33.0  42.0     NaN      26.0     35.0
# 6                8  2012-01-01  66.0  45.0   NaN     NaN      34.0     46.0
# 7                9  2012-01-01  34.0  19.0  27.0     NaN      17.0     23.0
# 8               10  2012-01-01  73.0  53.0  63.0     NaN      55.0     58.0
# 9               11  2012-01-01  72.0  48.0  60.0     7.0      54.0     56.0
# 10              12  2012-01-01  72.0  48.0  60.0     NaN      54.0     57.0
# ...

# %%
result_weather_nan = round(data_weather_nan.groupby('station_nbr').agg(['median', 'mean', 'min', 'max']),2)

# %%
result_weather_nan
# Out:
#               tmax                       tmin                      tavg  \
#             median   mean   min    max median   mean   min   max median
# station_nbr
# 1             63.0  61.50  14.0   97.0   43.0  42.59  -4.0  77.0   54.0
# 2             61.0  57.82   9.0   93.0   43.0  41.49  -4.0  74.0   53.0
# 3             76.0  73.68  17.0  112.0   54.0  51.17  -2.0  88.0   66.0
# 4             85.0  82.30  31.0  109.0   63.0  60.06  22.0  80.0   74.0
# 5             70.0  71.70  60.0   93.0   51.0  52.50  40.0  68.0   60.0
# 6             84.0  81.70  31.0  107.0   60.0  56.42  12.0  78.0   72.0
# 7             77.0  74.10  16.0  112.0   55.0  52.06   3.0  85.0   67.0
# 8             84.0  81.64  33.0  109.0   64.0  60.45  19.0  81.0   77.0
# 9             60.0  56.66 -11.0  102.0   40.0  38.32 -21.0  80.0   51.0
# 10            83.0  81.18  41.0  102.0   67.0  64.61  25.0  82.0   75.0
# 11            82.0  79.95  39.0   99.0   61.0  58.95  21.0  78.0   72.0
# ...

# %%
# Station 1의 [tmax]의 median, mean, min, max
# 아래 nan_station_i가 왜 안되는지 확인하기
for i in range(1,21):
    nan_station_tmax_i = dict(result_weather_nan['tmax'].loc[i])
    print(nan_station_tmax_i, i)
# Out:
# {'median': 63.0, 'mean': 61.5, 'min': 14.0, 'max': 97.0} 1
# {'median': 61.0, 'mean': 57.82, 'min': 9.0, 'max': 93.0} 2
# {'median': 76.0, 'mean': 73.68, 'min': 17.0, 'max': 112.0} 3
# {'median': 85.0, 'mean': 82.3, 'min': 31.0, 'max': 109.0} 4
# {'median': 70.0, 'mean': 71.7, 'min': 60.0, 'max': 93.0} 5
# {'median': 84.0, 'mean': 81.7, 'min': 31.0, 'max': 107.0} 6
# {'median': 77.0, 'mean': 74.1, 'min': 16.0, 'max': 112.0} 7
# {'median': 84.0, 'mean': 81.64, 'min': 33.0, 'max': 109.0} 8
# {'median': 60.0, 'mean': 56.66, 'min': -11.0, 'max': 102.0} 9
# {'median': 83.0, 'mean': 81.18, 'min': 41.0, 'max': 102.0} 10
# {'median': 82.0, 'mean': 79.95, 'min': 39.0, 'max': 99.0} 11
# {'median': 83.0, 'mean': 80.41, 'min': 41.0, 'max': 98.0} 12
# {'median': 67.0, 'mean': 65.26, 'min': 2.0, 'max': 100.0} 13
# {'median': 77.0, 'mean': 74.28, 'min': 18.0, 'max': 113.0} 14
# {'median': 62.0, 'mean': 59.54, 'min': 7.0, 'max': 96.0} 15
# ...

# %%
nan_station_tmax_1 = dict(result_weather_nan['tmax'].loc[1])
nan_station_tmax_2 = dict(result_weather_nan['tmax'].loc[2])
nan_station_tmax_3 = dict(result_weather_nan['tmax'].loc[3])
nan_station_tmax_4 = dict(result_weather_nan['tmax'].loc[4])
nan_station_tmax_5 = dict(result_weather_nan['tmax'].loc[5])
nan_station_tmax_6 = dict(result_weather_nan['tmax'].loc[6])
nan_station_tmax_7 = dict(result_weather_nan['tmax'].loc[7])
nan_station_tmax_8 = dict(result_weather_nan['tmax'].loc[8])
nan_station_tmax_9 = dict(result_weather_nan['tmax'].loc[9])
nan_station_tmax_10 = dict(result_weather_nan['tmax'].loc[10])
nan_station_tmax_11 = dict(result_weather_nan['tmax'].loc[11])
nan_station_tmax_12 = dict(result_weather_nan['tmax'].loc[12])
nan_station_tmax_13 = dict(result_weather_nan['tmax'].loc[13])
nan_station_tmax_14 = dict(result_weather_nan['tmax'].loc[14])
nan_station_tmax_15 = dict(result_weather_nan['tmax'].loc[15])
nan_station_tmax_16 = dict(result_weather_nan['tmax'].loc[16])
nan_station_tmax_17 = dict(result_weather_nan['tmax'].loc[17])
nan_station_tmax_18 = dict(result_weather_nan['tmax'].loc[18])
nan_station_tmax_19 = dict(result_weather_nan['tmax'].loc[19])
nan_station_tmax_20 = dict(result_weather_nan['tmax'].loc[20])

# %%
nan_station_tmax_12
# Out:
# {'max': 98.0, 'mean': 80.41, 'median': 83.0, 'min': 41.0}

# %%
print(nan_station_tmax_12['median'], nan_station_tmax_12['mean'], nan_station_tmax_12['min'], nan_station_tmax_12['max'])
# Out:
# 83.0 80.41 41.0 98.0

# %%
result_weather_nan['tmax']
# Out:
#              median   mean   min    max
# station_nbr
# 1              63.0  61.50  14.0   97.0
# 2              61.0  57.82   9.0   93.0
# 3              76.0  73.68  17.0  112.0
# 4              85.0  82.30  31.0  109.0
# 5              70.0  71.70  60.0   93.0
# 6              84.0  81.70  31.0  107.0
# 7              77.0  74.10  16.0  112.0
# 8              84.0  81.64  33.0  109.0
# 9              60.0  56.66 -11.0  102.0
# 10             83.0  81.18  41.0  102.0
# 11             82.0  79.95  39.0   99.0
# 12             83.0  80.41  41.0   98.0
# 13             67.0  65.26   2.0  100.0
# 14             77.0  74.28  18.0  113.0
# 15             62.0  59.54   7.0   96.0
# 16             62.0  60.29  14.0   96.0
# 17             77.0  74.54  19.0  114.0
# 18             82.0  79.47  24.0  108.0
# 19             59.0  57.18  -4.0  103.0
# 20             82.0  79.37  25.0  108.0

# %%
data_weather_filled.head(5)
# Out:
#    station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat cool  \
# 0            1  2012-01-01   52   31   42      M       36      40   23    0
# 1            2  2012-01-01   48   33   41     16       37      39   24    0
# 2            3  2012-01-01   55   34   45      9       24      36   20    0
# 3            4  2012-01-01   63   47   55      4       28      43   10    0
# 4            6  2012-01-01   63   34   49      0       31      43   16    0
#
#   sunrise sunset     codesum snowfall preciptotal stnpressure sealevel  \
# 0       -      -  RA FZFG BR        M        0.05       29.78    29.92
# 1    0716   1626          RA      0.0        0.07       28.82    29.91
# 2    0735   1720                  0.0        0.00       29.77    30.47
# 3    0728   1742                  0.0        0.00       29.79    30.48
# 4    0727   1742                  0.0        0.00       29.95    30.47
#
#   resultspeed resultdir avgspeed
# 0         3.6        20      4.6
# ...

# %%
data_weather_filled['tmax'] = pd.to_numeric(data_weather_filled['tmax'], errors = 'coerce')
data_weather_filled['tmin'] = pd.to_numeric(data_weather_filled['tmin'], errors = 'coerce')
data_weather_filled['tavg'] = pd.to_numeric(data_weather_filled['tavg'], errors = 'coerce')
data_weather_filled['depart'] = pd.to_numeric(data_weather_filled['depart'], errors = 'coerce')
data_weather_filled['dewpoint'] = pd.to_numeric(data_weather_filled['dewpoint'], errors = 'coerce')
data_weather_filled['wetbulb'] = pd.to_numeric(data_weather_filled['wetbulb'], errors = 'coerce')
data_weather_filled['heat'] = pd.to_numeric(data_weather_filled['heat'], errors = 'coerce')
data_weather_filled['cool'] = pd.to_numeric(data_weather_filled['cool'], errors = 'coerce')
data_weather_filled['snowfall'] = pd.to_numeric(data_weather_filled['snowfall'], errors = 'coerce')
data_weather_filled['preciptotal'] = pd.to_numeric(data_weather_filled['preciptotal'], errors = 'coerce')
data_weather_filled['stnpressure'] = pd.to_numeric(data_weather_filled['stnpressure'], errors = 'coerce')
data_weather_filled['sealevel'] = pd.to_numeric(data_weather_filled['sealevel'], errors = 'coerce')
data_weather_filled['resultspeed'] = pd.to_numeric(data_weather_filled['resultspeed'], errors = 'coerce')
data_weather_filled['resultdir'] = pd.to_numeric(data_weather_filled['resultdir'], errors = 'coerce')
data_weather_filled['avgspeed'] = pd.to_numeric(data_weather_filled['avgspeed'], errors = 'coerce')

data_weather_filled['tmax'] = data_weather_filled['tmax'].combine_first(data_weather['tmax'])
data_weather_filled['tmin'] = data_weather_filled['tmin'].combine_first(data_weather['tmin'])
data_weather_filled['tavg'] = data_weather_filled['tavg'].combine_first(data_weather['tavg'])
data_weather_filled['depart'] = data_weather_filled['depart'].combine_first(data_weather['depart'])
data_weather_filled['dewpoint'] =data_weather_filled['dewpoint'].combine_first(data_weather['dewpoint'])
data_weather_filled['wetbulb'] = data_weather_filled['wetbulb'].combine_first(data_weather['wetbulb'])
data_weather_filled['heat'] = data_weather_filled['heat'].combine_first(data_weather['heat'])
data_weather_filled['cool'] = data_weather_filled['cool'].combine_first(data_weather['cool'])
data_weather_filled['snowfall'] = data_weather_filled['snowfall'].combine_first(data_weather['snowfall'])
data_weather_filled['preciptotal'] = data_weather_filled['preciptotal'].combine_first(data_weather['preciptotal'])
data_weather_filled['stnpressure'] = data_weather_filled['stnpressure'].combine_first(data_weather['stnpressure'])
data_weather_filled['sealevel'] = data_weather_filled['sealevel'].combine_first(data_weather['sealevel'])
data_weather_filled['resultspeed'] = data_weather_filled['resultspeed'].combine_first(data_weather['resultspeed'])
data_weather_filled['resultdir'] = data_weather_filled['resultdir'].combine_first(data_weather['resultdir'])
data_weather_filled['avgspeed'] = data_weather_filled['avgspeed'].combine_first(data_weather['avgspeed'])

# %%
# result_weather_filled 생성
data_weather_filled
result_weather_filled = data_weather_filled.copy()

# %%
# 일단 Station1의 tmax만 filtering해서, M 값에, nan넣고 구한 median 값 넣기
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 1) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_1['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 2) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_2['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 3) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_3['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 4) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_4['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 5) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_5['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 6) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_6['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 7) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_7['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 8) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_8['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 9) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_9['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 10) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_10['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 11) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_11['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 12) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_12['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 13) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_13['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 14) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_14['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 15) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_15['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 16) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_16['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 17) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_17['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 18) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_18['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 19) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_19['median']
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 20) & (result_weather_filled['tmax'] == 'M')] = nan_station_tmax_20['median']
# nan_station_tmax_20 = dict(result_weather_nan['tmax'].loc[20])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ...

# %%
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 1)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==1)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 2)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==2)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 3)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==3)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 4)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==4)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 5)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==5)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 6)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==6)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 7)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==7)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 8)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==8)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 9)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==9)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 10)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==10)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 11)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==11)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 12)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==12)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 13)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==13)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 14)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==14)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 15)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==15)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 16)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==16)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 17)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==17)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 18)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==18)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 19)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==19)].astype('int')
result_weather_filled['tmax'][(result_weather_filled['station_nbr'] == 20)] = result_weather_filled['tmax'][(result_weather_filled['station_nbr'] ==20)].astype('int')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
nan_station_tmin = []
for i in range(1,21):
    tmp = dict(result_weather_nan['tmin'].loc[i])
    nan_station_tmin.append(tmp)  
nan_station_tmin[1]
# Out:
# {'max': 74.0, 'mean': 41.49, 'median': 43.0, 'min': -4.0}

# %%
# tmix만 filtering해서, M 값에, nan넣고 구한 median 값 넣기
nan_station_tmin = [,]
for i in range(1,21):
    tmp = dict(result_weather_nan['tmin'].loc[i])
    nan_station_tmin.append(tmp)  
# nan_station_tmin_2 = dict(result_weather_nan['tmin'].loc[2])  
# nan_station_tmin_3 = dict(result_weather_nan['tmin'].loc[3])  
# nan_station_tmin_4 = dict(result_weather_nan['tmin'].loc[4])  
# nan_station_tmin_5 = dict(result_weather_nan['tmin'].loc[5])  
# nan_station_tmin_6 = dict(result_weather_nan['tmin'].loc[6])  
# nan_station_tmin_7 = dict(result_weather_nan['tmin'].loc[7])  
# nan_station_tmin_8 = dict(result_weather_nan['tmin'].loc[8])  
# nan_station_tmin_9 = dict(result_weather_nan['tmin'].loc[9])  
# nan_station_tmin_10 = dict(result_weather_nan['tmin'].loc[10])
# nan_station_tmin_11 = dict(result_weather_nan['tmin'].loc[11])
# nan_station_tmin_12 = dict(result_weather_nan['tmin'].loc[12])
# nan_station_tmin_13 = dict(result_weather_nan['tmin'].loc[13])
# nan_station_tmin_14 = dict(result_weather_nan['tmin'].loc[14])
# nan_station_tmin_15 = dict(result_weather_nan['tmin'].loc[15])
# nan_station_tmin_16 = dict(result_weather_nan['tmin'].loc[16])
# nan_station_tmin_17 = dict(result_weather_nan['tmin'].loc[17])
# nan_station_tmin_18 = dict(result_weather_nan['tmin'].loc[18])
# nan_station_tmin_19 = dict(result_weather_nan['tmin'].loc[19])
# nan_station_tmin_20 = dict(result_weather_nan['tmin'].loc[20])


result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 1) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_1['median']                    
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 2) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_2['median']                    
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 3) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_3['median']                    
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 4) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_4['median']                    
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 5) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_5['median']                    
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 6) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_6['median']                    
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 7) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_7['median']                    
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 8) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_8['median']                    
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 9) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_9['median']                    
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 10) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_10['median']                  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 11) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_11['median']                  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 12) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_12['median']                  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 13) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_13['median']                  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 14) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_14['median']                  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 15) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_15['median']                  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 16) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_16['median']                  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 17) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_17['median']                  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 18) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_18['median']                  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 19) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_19['median']                  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 20) & (result_weather_filled['tmin'] == 'M')] = nan_station_tmin_20['median']                  
                                                                                                                                                                      
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 1)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==1)].astype('int')  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 2)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==2)].astype('int')  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 3)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==3)].astype('int')  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 4)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==4)].astype('int')  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 5)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==5)].astype('int')  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 6)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==6)].astype('int')  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 7)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==7)].astype('int')  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 8)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==8)].astype('int')  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 9)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==9)].astype('int')  
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 10)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==10)].astype('int')
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 11)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==11)].astype('int')
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 12)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==12)].astype('int')
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 13)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==13)].astype('int')
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 14)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==14)].astype('int')
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 15)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==15)].astype('int')
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 16)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==16)].astype('int')
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 17)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==17)].astype('int')
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 18)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==18)].astype('int')
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 19)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==19)].astype('int')
result_weather_filled['tmin'][(result_weather_filled['station_nbr'] == 20)] = result_weather_filled['tmin'][(result_weather_filled['station_nbr'] ==20)].astype('int')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# ...

# %%
# tavg만 filtering해서, M 값에, nan넣고 구한 median 값 넣기                                                                                                           
nan_station_tavg_1 = dict(result_weather_nan['tavg'].loc[1])                                                                                                          
nan_station_tavg_2 = dict(result_weather_nan['tavg'].loc[2])                                                                                                          
nan_station_tavg_3 = dict(result_weather_nan['tavg'].loc[3])                                                                                                          
nan_station_tavg_4 = dict(result_weather_nan['tavg'].loc[4])                                                                                                          
nan_station_tavg_5 = dict(result_weather_nan['tavg'].loc[5])                                                                                                          
nan_station_tavg_6 = dict(result_weather_nan['tavg'].loc[6])                                                                                                          
nan_station_tavg_7 = dict(result_weather_nan['tavg'].loc[7])                                                                                                          
nan_station_tavg_8 = dict(result_weather_nan['tavg'].loc[8])                                                                                                          
nan_station_tavg_9 = dict(result_weather_nan['tavg'].loc[9])                                                                                                          
nan_station_tavg_10 = dict(result_weather_nan['tavg'].loc[10])                                                                                                        
nan_station_tavg_11 = dict(result_weather_nan['tavg'].loc[11])                                                                                                        
nan_station_tavg_12 = dict(result_weather_nan['tavg'].loc[12])                                                                                                        
nan_station_tavg_13 = dict(result_weather_nan['tavg'].loc[13])                                                                                                        
nan_station_tavg_14 = dict(result_weather_nan['tavg'].loc[14])                                                                                                        
nan_station_tavg_15 = dict(result_weather_nan['tavg'].loc[15])                                                                                                        
nan_station_tavg_16 = dict(result_weather_nan['tavg'].loc[16])                                                                                                        
nan_station_tavg_17 = dict(result_weather_nan['tavg'].loc[17])                                                                                                        
nan_station_tavg_18 = dict(result_weather_nan['tavg'].loc[18])                                                                                                        
nan_station_tavg_19 = dict(result_weather_nan['tavg'].loc[19])                                                                                                        
nan_station_tavg_20 = dict(result_weather_nan['tavg'].loc[20])                                                                                                        
                                                                                                                                                                      
                                                                                                                                                                      
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 1) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_1['median']                    
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 2) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_2['median']                    
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 3) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_3['median']                    
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 4) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_4['median']                    
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 5) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_5['median']                    
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 6) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_6['median']                    
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 7) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_7['median']                    
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 8) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_8['median']                    
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 9) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_9['median']                    
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 10) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_10['median']                  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 11) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_11['median']                  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 12) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_12['median']                  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 13) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_13['median']                  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 14) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_14['median']                  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 15) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_15['median']                  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 16) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_16['median']                  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 17) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_17['median']                  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 18) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_18['median']                  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 19) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_19['median']                  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 20) & (result_weather_filled['tavg'] == 'M')] = nan_station_tavg_20['median']                  
                                                                                                                                                                      
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 1)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==1)].astype('int')  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 2)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==2)].astype('int')  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 3)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==3)].astype('int')  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 4)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==4)].astype('int')  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 5)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==5)].astype('int')  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 6)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==6)].astype('int')  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 7)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==7)].astype('int')  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 8)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==8)].astype('int')  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 9)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==9)].astype('int')  
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 10)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==10)].astype('int')
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 11)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==11)].astype('int')
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 12)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==12)].astype('int')
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 13)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==13)].astype('int')
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 14)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==14)].astype('int')
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 15)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==15)].astype('int')
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 16)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==16)].astype('int')
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 17)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==17)].astype('int')
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 18)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==18)].astype('int')
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 19)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==19)].astype('int')
result_weather_filled['tavg'][(result_weather_filled['station_nbr'] == 20)] = result_weather_filled['tavg'][(result_weather_filled['station_nbr'] ==20)].astype('int')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# ...

# %%
result_weather_filled.columns
# Out:
# Index(['station_nbr', 'date', 'tmax', 'tmin', 'tavg', 'depart', 'dewpoint',
#        'wetbulb', 'heat', 'cool', 'sunrise', 'sunset', 'codesum', 'snowfall',
#        'preciptotal', 'stnpressure', 'sealevel', 'resultspeed', 'resultdir',
#        'avgspeed'],
#       dtype='object')

# %%
# depart만 filtering해서, M 값에, nan넣고 구한 median 값 넣기                                                                                                           
nan_station_depart_1 = dict(result_weather_nan['depart'].loc[1])                                                                                                          
nan_station_depart_2 = dict(result_weather_nan['depart'].loc[2])                                                                                                          
nan_station_depart_3 = dict(result_weather_nan['depart'].loc[3])                                                                                                          
nan_station_depart_4 = dict(result_weather_nan['depart'].loc[4])                                                                                                          
nan_station_depart_5 = dict(result_weather_nan['depart'].loc[5])                                                                                                          
nan_station_depart_6 = dict(result_weather_nan['depart'].loc[6])                                                                                                          
nan_station_depart_7 = dict(result_weather_nan['depart'].loc[7])                                                                                                          
nan_station_depart_8 = dict(result_weather_nan['depart'].loc[8])                                                                                                          
nan_station_depart_9 = dict(result_weather_nan['depart'].loc[9])                                                                                                          
nan_station_depart_10 = dict(result_weather_nan['depart'].loc[10])                                                                                                        
nan_station_depart_11 = dict(result_weather_nan['depart'].loc[11])                                                                                                        
nan_station_depart_12 = dict(result_weather_nan['depart'].loc[12])                                                                                                        
nan_station_depart_13 = dict(result_weather_nan['depart'].loc[13])                                                                                                        
nan_station_depart_14 = dict(result_weather_nan['depart'].loc[14])                                                                                                        
nan_station_depart_15 = dict(result_weather_nan['depart'].loc[15])                                                                                                        
nan_station_depart_16 = dict(result_weather_nan['depart'].loc[16])                                                                                                        
nan_station_depart_17 = dict(result_weather_nan['depart'].loc[17])                                                                                                        
nan_station_depart_18 = dict(result_weather_nan['depart'].loc[18])                                                                                                        
nan_station_depart_19 = dict(result_weather_nan['depart'].loc[19])                                                                                                        
nan_station_depart_20 = dict(result_weather_nan['depart'].loc[20])                                                                                                        
                                                                                                                                                                      
                                                                                                                                                                      
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 1) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_1['median']                    
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 2) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_2['median']                    
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 3) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_3['median']                    
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 4) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_4['median']                    
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 5) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_5['median']                    
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 6) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_6['median']                    
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 7) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_7['median']                    
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 8) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_8['median']                    
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 9) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_9['median']                    
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 10) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_10['median']                  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 11) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_11['median']                  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 12) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_12['median']                  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 13) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_13['median']                  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 14) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_14['median']                  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 15) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_15['median']                  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 16) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_16['median']                  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 17) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_17['median']                  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 18) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_18['median']                  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 19) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_19['median']                  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 20) & (result_weather_filled['depart'] == 'M')] = nan_station_depart_20['median']                  
                                                                                                                                                                      
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 1)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==1)].astype('int')  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 2)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==2)].astype('int')  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 3)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==3)].astype('int')  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 4)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==4)].astype('int')  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 5)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==5)].astype('int')  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 6)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==6)].astype('int')  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 7)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==7)].astype('int')  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 8)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==8)].astype('int')  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 9)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==9)].astype('int')  
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 10)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==10)].astype('int')
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 11)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==11)].astype('int')
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 12)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==12)].astype('int')
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 13)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==13)].astype('int')
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 14)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==14)].astype('int')
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 15)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==15)].astype('int')
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 16)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==16)].astype('int')
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 17)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==17)].astype('int')
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 18)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==18)].astype('int')
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 19)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==19)].astype('int')
result_weather_filled['depart'][(result_weather_filled['station_nbr'] == 20)] = result_weather_filled['depart'][(result_weather_filled['station_nbr'] ==20)].astype('int')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# ...
