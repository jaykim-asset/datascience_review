# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

data_key = pd.read_csv('key.csv')
data_key = data_key[data_key['station_nbr'] != 5]
data_weather = pd.read_csv('weather.csv')
data_weather = data_weather[data_weather['station_nbr'] != 5] ## Station 5번 제거한 나머지
data_train = pd.read_csv('train.csv')

df = pd.merge(data_weather, data_key)
station_nbr = df['station_nbr']
df.drop('station_nbr', axis=1, inplace=True)
df['station_nbr'] = station_nbr
df = pd.merge(df, data_train)
df.head() # Station 5번을 뺀 나머지 Merge 완성
# Out:
#          date tmax tmin tavg depart dewpoint wetbulb heat cool sunrise  ...    \
# 0  2012-01-01   52   31   42      M       36      40   23    0       -  ...
# 1  2012-01-01   52   31   42      M       36      40   23    0       -  ...
# 2  2012-01-01   52   31   42      M       36      40   23    0       -  ...
# 3  2012-01-01   52   31   42      M       36      40   23    0       -  ...
# 4  2012-01-01   52   31   42      M       36      40   23    0       -  ...
#
#   preciptotal stnpressure sealevel resultspeed resultdir avgspeed store_nbr  \
# 0        0.05       29.78    29.92         3.6        20      4.6         1
# 1        0.05       29.78    29.92         3.6        20      4.6         1
# 2        0.05       29.78    29.92         3.6        20      4.6         1
# 3        0.05       29.78    29.92         3.6        20      4.6         1
# 4        0.05       29.78    29.92         3.6        20      4.6         1
#
#   station_nbr item_nbr  units
# ...

# %%
# 'M'과 '-'을 np.nan으로 값을 변경하기 전에, '  T'값을 먼저 snowfall=0.05, preciptotal = 0.005로 변경하자 
df['snowfall'][df['snowfall'] == '  T'] = 0.05
df['preciptotal'][df['preciptotal'] == '  T'] = 0.005
df['snowfall'][df['snowfall'] == '  T'], df['preciptotal'][df['preciptotal'] == '  T']
# T 값 변경 완료. 이제, 19개 Station 별로 정리하기 (5번 Station 생략)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# (Series([], Name: snowfall, dtype: object),
#  Series([], Name: preciptotal, dtype: object))

# %%
df_s_1 = df[df['station_nbr'] == 1]; df_s_8 = df[df['station_nbr'] == 8]; df_s_15 = df[df['station_nbr'] == 15]
df_s_2 = df[df['station_nbr'] == 2]; df_s_9 = df[df['station_nbr'] == 9]; df_s_16 = df[df['station_nbr'] == 16]
df_s_3 = df[df['station_nbr'] == 3]; df_s_10 = df[df['station_nbr'] == 10]; df_s_17 = df[df['station_nbr'] == 17]
df_s_4 = df[df['station_nbr'] == 4]; df_s_11 = df[df['station_nbr'] == 11]; df_s_18 = df[df['station_nbr'] == 18]
df_s_5 = df[df['station_nbr'] == 5]; df_s_12 = df[df['station_nbr'] == 12]; df_s_19 = df[df['station_nbr'] == 19]
df_s_6 = df[df['station_nbr'] == 6]; df_s_13 = df[df['station_nbr'] == 13]; df_s_20 = df[df['station_nbr'] == 20]
df_s_7 = df[df['station_nbr'] == 7]; df_s_14 = df[df['station_nbr'] == 14]

# %%
# Each Station tmin 의 M값을 np.nan으로 변경
df_s_1_tmin = df_s_1['tmin'].copy(); df_s_1_tmin = pd.to_numeric(df_s_1_tmin, errors = 'coerce')
df_s_2_tmin = df_s_2['tmin'].copy(); df_s_2_tmin = pd.to_numeric(df_s_2_tmin, errors = 'coerce')
df_s_3_tmin = df_s_3['tmin'].copy(); df_s_3_tmin = pd.to_numeric(df_s_3_tmin, errors = 'coerce')
df_s_4_tmin = df_s_4['tmin'].copy(); df_s_4_tmin = pd.to_numeric(df_s_4_tmin, errors = 'coerce')
df_s_5_tmin = df_s_5['tmin'].copy(); df_s_5_tmin = pd.to_numeric(df_s_5_tmin, errors = 'coerce')
df_s_6_tmin = df_s_6['tmin'].copy(); df_s_6_tmin = pd.to_numeric(df_s_6_tmin, errors = 'coerce')
df_s_7_tmin = df_s_7['tmin'].copy(); df_s_7_tmin = pd.to_numeric(df_s_7_tmin, errors = 'coerce')
df_s_8_tmin = df_s_8['tmin'].copy(); df_s_8_tmin = pd.to_numeric(df_s_8_tmin, errors = 'coerce')
df_s_9_tmin = df_s_9['tmin'].copy(); df_s_9_tmin = pd.to_numeric(df_s_9_tmin, errors = 'coerce')
df_s_10_tmin = df_s_10['tmin'].copy(); df_s_10_tmin = pd.to_numeric(df_s_10_tmin, errors = 'coerce')
df_s_11_tmin = df_s_11['tmin'].copy(); df_s_11_tmin = pd.to_numeric(df_s_11_tmin, errors = 'coerce')
df_s_12_tmin = df_s_12['tmin'].copy(); df_s_12_tmin = pd.to_numeric(df_s_12_tmin, errors = 'coerce')
df_s_13_tmin = df_s_13['tmin'].copy(); df_s_13_tmin = pd.to_numeric(df_s_13_tmin, errors = 'coerce')
df_s_14_tmin = df_s_14['tmin'].copy(); df_s_14_tmin = pd.to_numeric(df_s_14_tmin, errors = 'coerce')
df_s_15_tmin = df_s_15['tmin'].copy(); df_s_15_tmin = pd.to_numeric(df_s_15_tmin, errors = 'coerce')
df_s_16_tmin = df_s_16['tmin'].copy(); df_s_16_tmin = pd.to_numeric(df_s_16_tmin, errors = 'coerce')
df_s_17_tmin = df_s_17['tmin'].copy(); df_s_17_tmin = pd.to_numeric(df_s_17_tmin, errors = 'coerce')
df_s_18_tmin = df_s_18['tmin'].copy(); df_s_18_tmin = pd.to_numeric(df_s_18_tmin, errors = 'coerce')
df_s_19_tmin = df_s_19['tmin'].copy(); df_s_19_tmin = pd.to_numeric(df_s_19_tmin, errors = 'coerce')
df_s_20_tmin = df_s_20['tmin'].copy(); df_s_20_tmin = pd.to_numeric(df_s_20_tmin, errors = 'coerce')

# 각 각의 Station의 Nan 값에, 위에서 구한 각각 station의 평균 값을 넣어서 NaN 값 뺏을 때와 비교할 것.
df_s_1_tmin_with_mean = df_s_1_tmin.copy(); df_s_1_tmin_with_mean[df_s_1_tmin_with_mean.isnull()] = df_s_1_tmin.mean()
df_s_2_tmin_with_mean = df_s_2_tmin.copy(); df_s_2_tmin_with_mean[df_s_2_tmin_with_mean.isnull()] = df_s_2_tmin.mean()
df_s_3_tmin_with_mean = df_s_3_tmin.copy(); df_s_3_tmin_with_mean[df_s_3_tmin_with_mean.isnull()] = df_s_3_tmin.mean()
df_s_4_tmin_with_mean = df_s_4_tmin.copy(); df_s_4_tmin_with_mean[df_s_4_tmin_with_mean.isnull()] = df_s_4_tmin.mean()
df_s_5_tmin_with_mean = df_s_5_tmin.copy(); df_s_5_tmin_with_mean[df_s_5_tmin_with_mean.isnull()] = df_s_5_tmin.mean()
df_s_6_tmin_with_mean = df_s_6_tmin.copy(); df_s_6_tmin_with_mean[df_s_6_tmin_with_mean.isnull()] = df_s_6_tmin.mean()
df_s_7_tmin_with_mean = df_s_7_tmin.copy(); df_s_7_tmin_with_mean[df_s_7_tmin_with_mean.isnull()] = df_s_7_tmin.mean()
df_s_8_tmin_with_mean = df_s_8_tmin.copy(); df_s_8_tmin_with_mean[df_s_8_tmin_with_mean.isnull()] = df_s_8_tmin.mean()
df_s_9_tmin_with_mean = df_s_9_tmin.copy(); df_s_9_tmin_with_mean[df_s_9_tmin_with_mean.isnull()] = df_s_9_tmin.mean()
df_s_10_tmin_with_mean = df_s_10_tmin.copy(); df_s_10_tmin_with_mean[df_s_10_tmin_with_mean.isnull()] = df_s_10_tmin.mean()
df_s_11_tmin_with_mean = df_s_11_tmin.copy(); df_s_11_tmin_with_mean[df_s_11_tmin_with_mean.isnull()] = df_s_11_tmin.mean()
df_s_12_tmin_with_mean = df_s_12_tmin.copy(); df_s_12_tmin_with_mean[df_s_12_tmin_with_mean.isnull()] = df_s_12_tmin.mean()
df_s_13_tmin_with_mean = df_s_13_tmin.copy(); df_s_13_tmin_with_mean[df_s_13_tmin_with_mean.isnull()] = df_s_13_tmin.mean()
df_s_14_tmin_with_mean = df_s_14_tmin.copy(); df_s_14_tmin_with_mean[df_s_14_tmin_with_mean.isnull()] = df_s_14_tmin.mean()
df_s_15_tmin_with_mean = df_s_15_tmin.copy(); df_s_15_tmin_with_mean[df_s_15_tmin_with_mean.isnull()] = df_s_15_tmin.mean()
df_s_16_tmin_with_mean = df_s_16_tmin.copy(); df_s_16_tmin_with_mean[df_s_16_tmin_with_mean.isnull()] = df_s_16_tmin.mean()
df_s_17_tmin_with_mean = df_s_17_tmin.copy(); df_s_17_tmin_with_mean[df_s_17_tmin_with_mean.isnull()] = df_s_17_tmin.mean()
df_s_18_tmin_with_mean = df_s_18_tmin.copy(); df_s_18_tmin_with_mean[df_s_18_tmin_with_mean.isnull()] = df_s_18_tmin.mean()
df_s_19_tmin_with_mean = df_s_19_tmin.copy(); df_s_19_tmin_with_mean[df_s_19_tmin_with_mean.isnull()] = df_s_19_tmin.mean()
df_s_20_tmin_with_mean = df_s_20_tmin.copy(); df_s_20_tmin_with_mean[df_s_20_tmin_with_mean.isnull()] = df_s_20_tmin.mean()

# %%
# 각 각의 Station 별로 tmin의 값이 np.nan일 때, 즉, missing value를 뺏을 때의 전체 mean 값을 나타낸다. 
print('#station1_without_nan_mean:', round(df_s_1_tmin.mean(),4), '#station1_without_nan_std:', round(df_s_1_tmin.std(),4)); 
print('#station2_without_nan_mean:', round(df_s_2_tmin.mean(),4), '#station2_without_nan_std:', round(df_s_2_tmin.std(),4)); 
print('#station3_without_nan_mean:', round(df_s_3_tmin.mean(),4), '#station3_without_nan_std:', round(df_s_3_tmin.std(),4)); 
print('#station4_without_nan_mean:', round(df_s_4_tmin.mean(),4), '#station4_without_nan_std:', round(df_s_4_tmin.std(),4)); 
print('#station5_without_nan_mean:', round(df_s_5_tmin.mean(),4), '#station5_without_nan_std:', round(df_s_5_tmin.std(),4)); 
print('#station6_without_nan_mean:', round(df_s_6_tmin.mean(),4), '#station6_without_nan_std:', round(df_s_6_tmin.std(),4)); 
print('#station7_without_nan_mean:', round(df_s_7_tmin.mean(),4), '#station7_without_nan_std:', round(df_s_7_tmin.std(),4)); 
print('#station8_without_nan_mean:', round(df_s_8_tmin.mean(),4), '#station8_without_nan_std:', round(df_s_8_tmin.std(),4)); 
print('#station9_without_nan_mean:', round(df_s_9_tmin.mean(),4), '#station9_without_nan_std:', round(df_s_9_tmin.std(),4)); 
print('#station10_without_nan_mean:', round(df_s_10_tmin.mean(),4), '#station10_without_nan_std:', round(df_s_10_tmin.std(),4));  
print('#station11_without_nan_mean:', round(df_s_11_tmin.mean(),4), '#station11_without_nan_std:', round(df_s_11_tmin.std(),4)); 
print('#station12_without_nan_mean:', round(df_s_12_tmin.mean(),4), '#station12_without_nan_std:', round(df_s_12_tmin.std(),4)); 
print('#station13_without_nan_mean:', round(df_s_13_tmin.mean(),4), '#station13_without_nan_std:', round(df_s_13_tmin.std(),4)); 
print('#station14_without_nan_mean:', round(df_s_14_tmin.mean(),4), '#station14_without_nan_std:', round(df_s_14_tmin.std(),4)); 
print('#station15_without_nan_mean:', round(df_s_15_tmin.mean(),4), '#station15_without_nan_std:', round(df_s_15_tmin.std(),4)); 
print('#station16_without_nan_mean:', round(df_s_16_tmin.mean(),4), '#station16_without_nan_std:', round(df_s_16_tmin.std(),4)); 
print('#station17_without_nan_mean:', round(df_s_17_tmin.mean(),4), '#station17_without_nan_std:', round(df_s_17_tmin.std(),4)); 
print('#station18_without_nan_mean:', round(df_s_18_tmin.mean(),4), '#station18_without_nan_std:', round(df_s_18_tmin.std(),4)); 
print('#station19_without_nan_mean:', round(df_s_19_tmin.mean(),4), '#station19_without_nan_std:', round(df_s_19_tmin.std(),4)); 
print('#station20_without_nan_mean:', round(df_s_20_tmin.mean(),4), '#station20_without_nan_std:', round(df_s_20_tmin.std(),4));
# Out:
# #station1_without_nan_mean: 41.6667 #station1_without_nan_std: 16.7849
# #station2_without_nan_mean: 41.8505 #station2_without_nan_std: 16.8047
# #station3_without_nan_mean: 50.5998 #station3_without_nan_std: 18.4918
# #station4_without_nan_mean: 59.6078 #station4_without_nan_std: 14.6697
# #station5_without_nan_mean: nan #station5_without_nan_std: nan
# #station6_without_nan_mean: 55.6764 #station6_without_nan_std: 16.0694
# #station7_without_nan_mean: 50.5926 #station7_without_nan_std: 18.8176
# #station8_without_nan_mean: 59.9928 #station8_without_nan_std: 14.4755
# #station9_without_nan_mean: 36.9119 #station9_without_nan_std: 22.4505
# #station10_without_nan_mean: 64.5223 #station10_without_nan_std: 12.0811
# #station11_without_nan_mean: 58.6846 #station11_without_nan_std: 12.8808
# #station12_without_nan_mean: 60.991 #station12_without_nan_std: 12.3177
# #station13_without_nan_mean: 37.4059 #station13_without_nan_std: 17.1014
# ...

# %%
print('stat1_nan_as_mean:',round(df_s_1_tmin_with_mean.mean(),4),'#stat1_nan_as_std:', round(df_s_1_tmin_with_mean.std(),4));
print('stat2_nan_as_mean:',round(df_s_2_tmin_with_mean.mean(),4),'#stat2_nan_as_std:', round(df_s_2_tmin_with_mean.std(),4));
print('stat3_nan_as_mean:',round(df_s_3_tmin_with_mean.mean(),4),'#stat3_nan_as_std:', round(df_s_3_tmin_with_mean.std(),4));
print('stat4_nan_as_mean:',round(df_s_4_tmin_with_mean.mean(),4),'#stat4_nan_as_std:', round(df_s_4_tmin_with_mean.std(),4));
print('stat5_nan_as_mean:',round(df_s_5_tmin_with_mean.mean(),4),'#stat5_nan_as_std:', round(df_s_5_tmin_with_mean.std(),4));
print('stat6_nan_as_mean:',round(df_s_6_tmin_with_mean.mean(),4),'#stat6_nan_as_std:', round(df_s_6_tmin_with_mean.std(),4));
print('stat7_nan_as_mean:',round(df_s_7_tmin_with_mean.mean(),4),'#stat7_nan_as_std:', round(df_s_7_tmin_with_mean.std(),4));
print('stat8_nan_as_mean:',round(df_s_8_tmin_with_mean.mean(),4),'#stat8_nan_as_std:', round(df_s_8_tmin_with_mean.std(),4));
print('stat9_nan_as_mean:',round(df_s_9_tmin_with_mean.mean(),4),'#stat9_nan_as_std:', round(df_s_9_tmin_with_mean.std(),4));
print('stat10_nan_as_mean:',round(df_s_10_tmin_with_mean.mean(),4),'#stat10_nan_as_std:', round(df_s_10_tmin_with_mean.std(),4));
print('stat11_nan_as_mean:',round(df_s_11_tmin_with_mean.mean(),4),'#stat11_nan_as_std:', round(df_s_11_tmin_with_mean.std(),4));
print('stat12_nan_as_mean:',round(df_s_12_tmin_with_mean.mean(),4),'#stat12_nan_as_std:', round(df_s_12_tmin_with_mean.std(),4));
print('stat13_nan_as_mean:',round(df_s_13_tmin_with_mean.mean(),4),'#stat13_nan_as_std:', round(df_s_13_tmin_with_mean.std(),4));
print('stat14_nan_as_mean:',round(df_s_14_tmin_with_mean.mean(),4),'#stat14_nan_as_std:', round(df_s_14_tmin_with_mean.std(),4));
print('stat15_nan_as_mean:',round(df_s_15_tmin_with_mean.mean(),4),'#stat15_nan_as_std:', round(df_s_15_tmin_with_mean.std(),4));
print('stat16_nan_as_mean:',round(df_s_16_tmin_with_mean.mean(),4),'#stat16_nan_as_std:', round(df_s_16_tmin_with_mean.std(),4));
print('stat17_nan_as_mean:',round(df_s_17_tmin_with_mean.mean(),4),'#stat17_nan_as_std:', round(df_s_17_tmin_with_mean.std(),4));
print('stat18_nan_as_mean:',round(df_s_18_tmin_with_mean.mean(),4),'#stat18_nan_as_std:', round(df_s_18_tmin_with_mean.std(),4));
print('stat19_nan_as_mean:',round(df_s_19_tmin_with_mean.mean(),4),'#stat19_nan_as_std:', round(df_s_19_tmin_with_mean.std(),4));
print('stat20_nan_as_mean:',round(df_s_20_tmin_with_mean.mean(),4),'#stat20_nan_as_std:', round(df_s_20_tmin_with_mean.std(),4));
# Out:
# stat1_nan_as_mean: 41.6667 #stat1_nan_as_std: 16.7668
# stat2_nan_as_mean: 41.8505 #stat2_nan_as_std: 16.7949
# stat3_nan_as_mean: 50.5998 #stat3_nan_as_std: 18.4716
# stat4_nan_as_mean: 59.6078 #stat4_nan_as_std: 14.6537
# stat5_nan_as_mean: nan #stat5_nan_as_std: nan
# stat6_nan_as_mean: 55.6764 #stat6_nan_as_std: 16.0521
# stat7_nan_as_mean: 50.5926 #stat7_nan_as_std: 18.4785
# stat8_nan_as_mean: 59.9928 #stat8_nan_as_std: 14.3869
# stat9_nan_as_mean: 36.9119 #stat9_nan_as_std: 22.3685
# stat10_nan_as_mean: 64.5223 #stat10_nan_as_std: 12.0811
# stat11_nan_as_mean: 58.6846 #stat11_nan_as_std: 12.8738
# stat12_nan_as_mean: 60.991 #stat12_nan_as_std: 12.3107
# stat13_nan_as_mean: 37.4059 #stat13_nan_as_std: 17.0929
# stat14_nan_as_mean: 49.8534 #stat14_nan_as_std: 17.6998
# stat15_nan_as_mean: 36.9054 #stat15_nan_as_std: 17.2226
# stat16_nan_as_mean: 40.8605 #stat16_nan_as_std: 16.67
# stat17_nan_as_mean: 48.907 #stat17_nan_as_std: 18.5071
# ...

# %%
y1 = np.array([df_s_1_tmin.mean(), df_s_2_tmin.mean(), df_s_3_tmin.mean(), df_s_4_tmin.mean(), df_s_5_tmin.mean(),
             df_s_6_tmin.mean(), df_s_7_tmin.mean(), df_s_8_tmin.mean(), df_s_9_tmin.mean(), df_s_10_tmin.mean(), 
             df_s_11_tmin.mean(), df_s_12_tmin.mean(), df_s_13_tmin.mean(), df_s_14_tmin.mean(), df_s_15_tmin.mean(),
             df_s_16_tmin.mean(), df_s_17_tmin.mean(), df_s_18_tmin.mean(), df_s_19_tmin.mean(), df_s_20_tmin.mean()])

y2 = np.array([df_s_1_tmin_with_mean.mean(), df_s_2_tmin_with_mean.mean(), df_s_3_tmin_with_mean.mean(), df_s_4_tmin_with_mean.mean()
             ,df_s_5_tmin_with_mean.mean(), df_s_6_tmin_with_mean.mean(), df_s_7_tmin_with_mean.mean(), df_s_8_tmin_with_mean.mean()
             ,df_s_9_tmin_with_mean.mean(), df_s_10_tmin_with_mean.mean(), df_s_11_tmin_with_mean.mean(), df_s_12_tmin_with_mean.mean()
             ,df_s_13_tmin_with_mean.mean(), df_s_14_tmin_with_mean.mean(), df_s_15_tmin_with_mean.mean(), df_s_16_tmin_with_mean.mean()
             ,df_s_17_tmin_with_mean.mean(),df_s_18_tmin_with_mean.mean(),df_s_19_tmin_with_mean.mean(),df_s_20_tmin_with_mean.mean()])

plt.figure(figsize=(10,5))
plt.plot()
x = range(1, 21)
plt.xlabel('Station Number')
plt.ylabel('tmin')
plt.bar(x, y1, color='y')
plt.bar(x, y2, color='r')
plt.show()

#### tmin 에서는
# 이 Graph가 나타내는 바는, y1과 y2가 차이가 거의 없다는 것. 그래프에는 r color와 y color이 있는데, 하나만 보인다는 것은
# 우리가 그래프에서 눈으로 보이지 않는 정도의 차이가 나온다는 것이다, 즉 차이가 극히 작다고 판단 할 수 있다.
# Missing Values를 np.nan으로 바꾸고, 거기서 Mean 값을 구하여 np.nan에 대입하여도, 
# 따라서, 여기서는 Missing Value에 Mean값을 적용하여 회귀 분석에 적용 할 수있다고 판단된다.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(12,6))
xticks = range(1,21)
plt.plot(xticks, y1, 'ro-', label='stations_without_nan_mean')
plt.plot(xticks, y2, 'bd:', label='stations_nan_as_mean')
plt.legend(loc=0)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
y3 = np.array([df_s_1_tmin.std(), df_s_2_tmin.std(), df_s_3_tmin.std(), df_s_4_tmin.std(), df_s_5_tmin.std(),
             df_s_6_tmin.std(), df_s_7_tmin.std(), df_s_8_tmin.std(), df_s_9_tmin.std(), df_s_10_tmin.std(), 
             df_s_11_tmin.std(), df_s_12_tmin.std(), df_s_13_tmin.std(), df_s_14_tmin.std(), df_s_15_tmin.std(),
             df_s_16_tmin.std(), df_s_17_tmin.std(), df_s_18_tmin.std(), df_s_19_tmin.std(), df_s_20_tmin.std()])

y4 = np.array([df_s_1_tmin_with_mean.std(), df_s_2_tmin_with_mean.std(), df_s_3_tmin_with_mean.std(), df_s_4_tmin_with_mean.std()
             ,df_s_5_tmin_with_mean.std(), df_s_6_tmin_with_mean.std(), df_s_7_tmin_with_mean.std(), df_s_8_tmin_with_mean.std()
             ,df_s_9_tmin_with_mean.std(), df_s_10_tmin_with_mean.std(), df_s_11_tmin_with_mean.std(), df_s_12_tmin_with_mean.std()
             ,df_s_13_tmin_with_mean.std(), df_s_14_tmin_with_mean.std(), df_s_15_tmin_with_mean.std(), df_s_16_tmin_with_mean.std()
             ,df_s_17_tmin_with_mean.std(),df_s_18_tmin_with_mean.std(),df_s_19_tmin_with_mean.std(),df_s_20_tmin_with_mean.std()])

plt.figure(figsize=(10,5))
plt.plot()
x = range(1, 21)
plt.xlabel('Station Number')
plt.ylabel('tmin')
plt.bar(x, y3, color='r')
plt.bar(x, y4, color='g')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(12,6))
xticks = range(1,21)
plt.plot(xticks, y3, 'ro-', label='stations_without_nan_std')
plt.plot(xticks, y4, 'bd:', label='stations_nan_as_std')
plt.legend(loc=0)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# # 7번 station에서 STD의 차이가 살짝 보인다.
# # 나머지 mean값의 대체에는 영향이 많이 적어 보인다.
