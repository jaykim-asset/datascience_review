# %%
data_key = pd.read_csv('key.csv')
data_key = data_key[data_key['station_nbr'] != 5]
data_weather = pd.read_csv('weather.csv')
data_weather = data_weather[data_weather['station_nbr'] != 5] ## Station 5번 제거한 나머지
data_train = pd.read_csv('train.csv')

df = pd.merge(data_weather, data_key)
station_nbr = df['station_nbr']
df.drop('station_nbr', axis=1, inplace=True)
df['station_nbr'] = station_nbr
df = pd.merge(df, data_train)
df # Station 5번을 뺀 나머지 Merge 완성
# Out:
#                date tmax tmin tavg depart dewpoint wetbulb heat cool sunrise  \
# 0        2012-01-01   52   31   42      M       36      40   23    0       -
# 1        2012-01-01   52   31   42      M       36      40   23    0       -
# 2        2012-01-01   52   31   42      M       36      40   23    0       -
# 3        2012-01-01   52   31   42      M       36      40   23    0       -
# 4        2012-01-01   52   31   42      M       36      40   23    0       -
# 5        2012-01-01   52   31   42      M       36      40   23    0       -
# 6        2012-01-01   52   31   42      M       36      40   23    0       -
# 7        2012-01-01   52   31   42      M       36      40   23    0       -
# 8        2012-01-01   52   31   42      M       36      40   23    0       -
# 9        2012-01-01   52   31   42      M       36      40   23    0       -
# 10       2012-01-01   52   31   42      M       36      40   23    0       -
# ...

# %% [markdown]
# # 1. tmax column

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) tmax 작업
df_tmax = df['tmax']

print('Total:', len(df_tmax))
print('Total 정상값:', (len(df_tmax[df_tmax != 'M'])))
print('Total 이상값:', (len(df_tmax[df_tmax == 'M']) | len(df_tmax[df_tmax == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_tmax) - (len(df_tmax[df_tmax != 'M'])) - (len(df_tmax[df_tmax == 'M']) + len(df_tmax[df_tmax == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_tmax_n = df_tmax.copy()
df_tmax_n = pd.to_numeric(df_tmax_n, errors = 'coerce')

print('Total_n:', len(df_tmax_n) )
print('Total_n 정상값:', len(df_tmax_n) - len(df_tmax_n[df_tmax_n.isnull()]))
print('Total_n 이상값:', len(df_tmax_n[df_tmax_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_tmax_n) - (len(df_tmax_n) - len(df_tmax_n[df_tmax_n.isnull()])) - len(df_tmax_n[df_tmax_n.isnull()]))
print('###############################')

#### df_tmax_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_tmax_n_mean = df_tmax_n.mean(); df_tmax_n_median = df_tmax_n.median(); df_tmax_n_min = df_tmax_n.min(); 
df_tmax_n_max = df_tmax_n.max();   df_tmax_n_count = len(df_tmax_n);
print('df_tmax_n_mean:', df_tmax_n_mean)
print('df_tmax_n_median:', df_tmax_n_median) 
print('df_tmax_n_min:', df_tmax_n_min) 
print('df_tmax_n_max:', df_tmax_n_max) 
print('df_tmax_n_count:', df_tmax_n_count)
print('###############################')

#### df_tmax_n에서 찾은 Mean값을 np.nan으로 대체 함
df_tmax_filled_mean = df_tmax_n.copy()
df_tmax_filled_mean[df_tmax_filled_mean.isnull()] = df_tmax_n_mean 

df_tmax_filled_mean_of_mean = df_tmax_filled_mean.mean()
df_tmax_filled_mean_of_median = df_tmax_filled_mean.median()
df_tmax_filled_mean_of_min = df_tmax_filled_mean.min()
df_tmax_filled_mean_of_max = df_tmax_filled_mean.max()
df_tmax_filled_mean_of_count = len(df_tmax_filled_mean)

print('df_tmax_filled_mean_of_mean:', df_tmax_filled_mean_of_mean)
print('df_tmax_filled_mean_of_median:', df_tmax_filled_mean_of_median) 
print('df_tmax_filled_mean_of_min:', df_tmax_filled_mean_of_min) 
print('df_tmax_filled_mean_of_max:', df_tmax_filled_mean_of_max) 
print('df_tmax_filled_mean_of_count:', df_tmax_filled_mean_of_count)
print('###############################')

#### df_tmax_n에서 찾은 Median값을 np.nan으로 대체 함
df_tmax_filled_median = df_tmax_n.copy()
df_tmax_filled_median[df_tmax_filled_median.isnull()] = df_tmax_n_median

df_tmax_filled_median_of_mean = df_tmax_filled_median.mean()
df_tmax_filled_median_of_median = df_tmax_filled_median.median()
df_tmax_filled_median_of_min = df_tmax_filled_median.min()
df_tmax_filled_median_of_max = df_tmax_filled_median.max()
df_tmax_filled_median_of_count = len(df_tmax_filled_median)

print('df_tmax_filled_median_of_mean:', df_tmax_filled_median_of_mean)
print('df_tmax_filled_median_of_median:', df_tmax_filled_median_of_median) 
print('df_tmax_filled_median_of_min:', df_tmax_filled_median_of_min) 
print('df_tmax_filled_median_of_max:', df_tmax_filled_median_of_max) 
print('df_tmax_filled_median_of_count:', df_tmax_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4502826
# Total 이상값: 20313
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4502826
# Total_n 이상값: 20313
# Total_n 정상값 - 이상값: 0
# ###############################
# df_tmax_n_mean: 72.08265542572597
# df_tmax_n_median: 76.0
# df_tmax_n_min: -11.0
# df_tmax_n_max: 114.0
# df_tmax_n_count: 4523139
# ###############################
# df_tmax_filled_mean_of_mean: 72.08265542574253
# df_tmax_filled_mean_of_median: 75.0
# df_tmax_filled_mean_of_min: -11.0
# df_tmax_filled_mean_of_max: 114.0
# df_tmax_filled_mean_of_count: 4523139
# ###############################
# df_tmax_filled_median_of_mean: 72.10024785884316
# df_tmax_filled_median_of_median: 76.0
# df_tmax_filled_median_of_min: -11.0
# df_tmax_filled_median_of_max: 114.0
# df_tmax_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 2. tmin column

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) tmin 작업
df_tmin = df['tmin']

print('Total:', len(df_tmin))
print('Total 정상값:', (len(df_tmin[df_tmin != 'M'])))
print('Total 이상값:', (len(df_tmin[df_tmin == 'M']) | len(df_tmin[df_tmin == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_tmin) - (len(df_tmin[df_tmin != 'M'])) - (len(df_tmin[df_tmin == 'M']) + len(df_tmin[df_tmin == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_tmin_n = df_tmin.copy()
df_tmin_n = pd.to_numeric(df_tmin_n, errors = 'coerce')

print('Total_n:', len(df_tmin_n) )
print('Total_n 정상값:', len(df_tmin_n) - len(df_tmin_n[df_tmin_n.isnull()]))
print('Total_n 이상값:', len(df_tmin_n[df_tmin_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_tmin_n) - (len(df_tmin_n) - len(df_tmin_n[df_tmin_n.isnull()])) - len(df_tmin_n[df_tmin_n.isnull()]))
print('###############################')

#### df_tmin_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_tmin_n_mean = df_tmin_n.mean(); df_tmin_n_median = df_tmin_n.median(); df_tmin_n_min = df_tmin_n.min(); 
df_tmin_n_max = df_tmin_n.max();   df_tmin_n_count = len(df_tmin_n);
print('df_tmin_n_mean:', df_tmin_n_mean)
print('df_tmin_n_median:', df_tmin_n_median) 
print('df_tmin_n_min:', df_tmin_n_min) 
print('df_tmin_n_max:', df_tmin_n_max) 
print('df_tmin_n_count:', df_tmin_n_count)
print('###############################')

#### df_tmin_n에서 찾은 Mean값을 np.nan으로 대체 함
df_tmin_filled_mean = df_tmin_n.copy()
df_tmin_filled_mean[df_tmin_filled_mean.isnull()] = df_tmin_n_mean 

df_tmin_filled_mean_of_mean = df_tmin_filled_mean.mean()
df_tmin_filled_mean_of_median = df_tmin_filled_mean.median()
df_tmin_filled_mean_of_min = df_tmin_filled_mean.min()
df_tmin_filled_mean_of_max = df_tmin_filled_mean.max()
df_tmin_filled_mean_of_count = len(df_tmin_filled_mean)

print('df_tmin_filled_mean_of_mean:', df_tmin_filled_mean_of_mean)
print('df_tmin_filled_mean_of_median:', df_tmin_filled_mean_of_median) 
print('df_tmin_filled_mean_of_min:', df_tmin_filled_mean_of_min) 
print('df_tmin_filled_mean_of_max:', df_tmin_filled_mean_of_max) 
print('df_tmin_filled_mean_of_count:', df_tmin_filled_mean_of_count)
print('###############################')

#### df_tmin_n에서 찾은 Median값을 np.nan으로 대체 함
df_tmin_filled_median = df_tmin_n.copy()
df_tmin_filled_median[df_tmin_filled_median.isnull()] = df_tmin_n_median

df_tmin_filled_median_of_mean = df_tmin_filled_median.mean()
df_tmin_filled_median_of_median = df_tmin_filled_median.median()
df_tmin_filled_median_of_min = df_tmin_filled_median.min()
df_tmin_filled_median_of_max = df_tmin_filled_median.max()
df_tmin_filled_median_of_count = len(df_tmin_filled_median)

print('df_tmin_filled_median_of_mean:', df_tmin_filled_median_of_mean)
print('df_tmin_filled_median_of_median:', df_tmin_filled_median_of_median) 
print('df_tmin_filled_median_of_min:', df_tmin_filled_median_of_min) 
print('df_tmin_filled_median_of_max:', df_tmin_filled_median_of_max) 
print('df_tmin_filled_median_of_count:', df_tmin_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4502937
# Total 이상값: 20202
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4502937
# Total_n 이상값: 20202
# Total_n 정상값 - 이상값: 0
# ###############################
# df_tmin_n_mean: 49.90171814529051
# df_tmin_n_median: 52.0
# df_tmin_n_min: -21.0
# df_tmin_n_max: 88.0
# df_tmin_n_count: 4523139
# ###############################
# df_tmin_filled_mean_of_mean: 49.90171814528899
# df_tmin_filled_mean_of_median: 52.0
# df_tmin_filled_mean_of_min: -21.0
# df_tmin_filled_mean_of_max: 88.0
# df_tmin_filled_mean_of_count: 4523139
# ###############################
# df_tmin_filled_median_of_mean: 49.911089842695525
# df_tmin_filled_median_of_median: 52.0
# df_tmin_filled_median_of_min: -21.0
# df_tmin_filled_median_of_max: 88.0
# df_tmin_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 3. tavg column

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) tavg 작업
df_tavg = df['tavg']

print('Total:', len(df_tavg))
print('Total 정상값:', (len(df_tavg[df_tavg != 'M'])))
print('Total 이상값:', (len(df_tavg[df_tavg == 'M']) | len(df_tavg[df_tavg == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_tavg) - (len(df_tavg[df_tavg != 'M'])) - (len(df_tavg[df_tavg == 'M']) + len(df_tavg[df_tavg == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_tavg_n = df_tavg.copy()
df_tavg_n = pd.to_numeric(df_tavg_n, errors = 'coerce')

print('Total_n:', len(df_tavg_n) )
print('Total_n 정상값:', len(df_tavg_n) - len(df_tavg_n[df_tavg_n.isnull()]))
print('Total_n 이상값:', len(df_tavg_n[df_tavg_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_tavg_n) - (len(df_tavg_n) - len(df_tavg_n[df_tavg_n.isnull()])) - len(df_tavg_n[df_tavg_n.isnull()]))
print('###############################')

#### df_tavg_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_tavg_n_mean = df_tavg_n.mean(); df_tavg_n_median = df_tavg_n.median(); df_tavg_n_min = df_tavg_n.min(); 
df_tavg_n_max = df_tavg_n.max();   df_tavg_n_count = len(df_tavg_n);
print('df_tavg_n_mean:', df_tavg_n_mean)
print('df_tavg_n_median:', df_tavg_n_median) 
print('df_tavg_n_min:', df_tavg_n_min) 
print('df_tavg_n_max:', df_tavg_n_max) 
print('df_tavg_n_count:', df_tavg_n_count)
print('###############################')

#### df_tavg_n에서 찾은 Mean값을 np.nan으로 대체 함
df_tavg_filled_mean = df_tavg_n.copy()
df_tavg_filled_mean[df_tavg_filled_mean.isnull()] = df_tavg_n_mean 

df_tavg_filled_mean_of_mean = df_tavg_filled_mean.mean()
df_tavg_filled_mean_of_median = df_tavg_filled_mean.median()
df_tavg_filled_mean_of_min = df_tavg_filled_mean.min()
df_tavg_filled_mean_of_max = df_tavg_filled_mean.max()
df_tavg_filled_mean_of_count = len(df_tavg_filled_mean)

print('df_tavg_filled_mean_of_mean:', df_tavg_filled_mean_of_mean)
print('df_tavg_filled_mean_of_median:', df_tavg_filled_mean_of_median) 
print('df_tavg_filled_mean_of_min:', df_tavg_filled_mean_of_min) 
print('df_tavg_filled_mean_of_max:', df_tavg_filled_mean_of_max) 
print('df_tavg_filled_mean_of_count:', df_tavg_filled_mean_of_count)
print('###############################')

#### df_tavg_n에서 찾은 Median값을 np.nan으로 대체 함
df_tavg_filled_median = df_tavg_n.copy()
df_tavg_filled_median[df_tavg_filled_median.isnull()] = df_tavg_n_median

df_tavg_filled_median_of_mean = df_tavg_filled_median.mean()
df_tavg_filled_median_of_median = df_tavg_filled_median.median()
df_tavg_filled_median_of_min = df_tavg_filled_median.min()
df_tavg_filled_median_of_max = df_tavg_filled_median.max()
df_tavg_filled_median_of_count = len(df_tavg_filled_median)

print('df_tavg_filled_median_of_mean:', df_tavg_filled_median_of_mean)
print('df_tavg_filled_median_of_median:', df_tavg_filled_median_of_median) 
print('df_tavg_filled_median_of_min:', df_tavg_filled_median_of_min) 
print('df_tavg_filled_median_of_max:', df_tavg_filled_median_of_max) 
print('df_tavg_filled_median_of_count:', df_tavg_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4426569
# Total 이상값: 96570
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4426569
# Total_n 이상값: 96570
# Total_n 정상값 - 이상값: 0
# ###############################
# df_tavg_n_mean: 61.18202562752326
# df_tavg_n_median: 64.0
# df_tavg_n_min: -16.0
# df_tavg_n_max: 100.0
# df_tavg_n_count: 4523139
# ###############################
# df_tavg_filled_mean_of_mean: 61.18202562755173
# df_tavg_filled_mean_of_median: 63.0
# df_tavg_filled_mean_of_min: -16.0
# df_tavg_filled_mean_of_max: 100.0
# df_tavg_filled_mean_of_count: 4523139
# ###############################
# df_tavg_filled_median_of_mean: 61.242189992392454
# df_tavg_filled_median_of_median: 64.0
# df_tavg_filled_median_of_min: -16.0
# df_tavg_filled_median_of_max: 100.0
# df_tavg_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 4. depart column

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) depart 작업
df_depart = df['depart']

print('Total:', len(df_depart))
print('Total 정상값:', (len(df_depart[df_depart != 'M'])))
print('Total 이상값:', (len(df_depart[df_depart == 'M']) | len(df_depart[df_depart == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_depart) - (len(df_depart[df_depart != 'M'])) - (len(df_depart[df_depart == 'M']) + len(df_depart[df_depart == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_depart_n = df_depart.copy()
df_depart_n = pd.to_numeric(df_depart_n, errors = 'coerce')

print('Total_n:', len(df_depart_n) )
print('Total_n 정상값:', len(df_depart_n) - len(df_depart_n[df_depart_n.isnull()]))
print('Total_n 이상값:', len(df_depart_n[df_depart_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_depart_n) - (len(df_depart_n) - len(df_depart_n[df_depart_n.isnull()])) - len(df_depart_n[df_depart_n.isnull()]))
print('###############################')

#### df_depart_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_depart_n_mean = df_depart_n.mean(); df_depart_n_median = df_depart_n.median(); df_depart_n_min = df_depart_n.min(); 
df_depart_n_max = df_depart_n.max();   df_depart_n_count = len(df_depart_n);
print('df_depart_n_mean:', df_depart_n_mean)
print('df_depart_n_median:', df_depart_n_median) 
print('df_depart_n_min:', df_depart_n_min) 
print('df_depart_n_max:', df_depart_n_max) 
print('df_depart_n_count:', df_depart_n_count)
print('###############################')

#### df_depart_n에서 찾은 Mean값을 np.nan으로 대체 함
df_depart_filled_mean = df_depart_n.copy()
df_depart_filled_mean[df_depart_filled_mean.isnull()] = df_depart_n_mean 

df_depart_filled_mean_of_mean = df_depart_filled_mean.mean()
df_depart_filled_mean_of_median = df_depart_filled_mean.median()
df_depart_filled_mean_of_min = df_depart_filled_mean.min()
df_depart_filled_mean_of_max = df_depart_filled_mean.max()
df_depart_filled_mean_of_count = len(df_depart_filled_mean)

print('df_depart_filled_mean_of_mean:', df_depart_filled_mean_of_mean)
print('df_depart_filled_mean_of_median:', df_depart_filled_mean_of_median) 
print('df_depart_filled_mean_of_min:', df_depart_filled_mean_of_min) 
print('df_depart_filled_mean_of_max:', df_depart_filled_mean_of_max) 
print('df_depart_filled_mean_of_count:', df_depart_filled_mean_of_count)
print('###############################')

#### df_depart_n에서 찾은 Median값을 np.nan으로 대체 함
df_depart_filled_median = df_depart_n.copy()
df_depart_filled_median[df_depart_filled_median.isnull()] = df_depart_n_median

df_depart_filled_median_of_mean = df_depart_filled_median.mean()
df_depart_filled_median_of_median = df_depart_filled_median.median()
df_depart_filled_median_of_min = df_depart_filled_median.min()
df_depart_filled_median_of_max = df_depart_filled_median.max()
df_depart_filled_median_of_count = len(df_depart_filled_median)

print('df_depart_filled_median_of_mean:', df_depart_filled_median_of_mean)
print('df_depart_filled_median_of_median:', df_depart_filled_median_of_median) 
print('df_depart_filled_median_of_min:', df_depart_filled_median_of_min) 
print('df_depart_filled_median_of_max:', df_depart_filled_median_of_max) 
print('df_depart_filled_median_of_count:', df_depart_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 1544232
# Total 이상값: 2978907
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 1544232
# Total_n 이상값: 2978907
# Total_n 정상값 - 이상값: 0
# ###############################
# df_depart_n_mean: 1.7560379528464636
# df_depart_n_median: 2.0
# df_depart_n_min: -32.0
# df_depart_n_max: 33.0
# df_depart_n_count: 4523139
# ###############################
# df_depart_filled_mean_of_mean: 1.7560379529822
# df_depart_filled_mean_of_median: 1.7560379528464636
# df_depart_filled_mean_of_min: -32.0
# df_depart_filled_mean_of_max: 33.0
# df_depart_filled_mean_of_count: 4523139
# ###############################
# df_depart_filled_median_of_mean: 1.9167096125058283
# df_depart_filled_median_of_median: 2.0
# df_depart_filled_median_of_min: -32.0
# df_depart_filled_median_of_max: 33.0
# df_depart_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 5. dewpoint column

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) dewpoint 작업
df_dewpoint = df['dewpoint']

print('Total:', len(df_dewpoint))
print('Total 정상값:', (len(df_dewpoint[df_dewpoint != 'M'])))
print('Total 이상값:', (len(df_dewpoint[df_dewpoint == 'M']) | len(df_dewpoint[df_dewpoint == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_dewpoint) - (len(df_dewpoint[df_dewpoint != 'M'])) - (len(df_dewpoint[df_dewpoint == 'M']) + len(df_dewpoint[df_dewpoint == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_dewpoint_n = df_dewpoint.copy()
df_dewpoint_n = pd.to_numeric(df_dewpoint_n, errors = 'coerce')

print('Total_n:', len(df_dewpoint_n) )
print('Total_n 정상값:', len(df_dewpoint_n) - len(df_dewpoint_n[df_dewpoint_n.isnull()]))
print('Total_n 이상값:', len(df_dewpoint_n[df_dewpoint_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_dewpoint_n) - (len(df_dewpoint_n) - len(df_dewpoint_n[df_dewpoint_n.isnull()])) - len(df_dewpoint_n[df_dewpoint_n.isnull()]))
print('###############################')

#### df_dewpoint_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_dewpoint_n_mean = df_dewpoint_n.mean(); df_dewpoint_n_median = df_dewpoint_n.median(); df_dewpoint_n_min = df_dewpoint_n.min(); 
df_dewpoint_n_max = df_dewpoint_n.max();   df_dewpoint_n_count = len(df_dewpoint_n);
print('df_dewpoint_n_mean:', df_dewpoint_n_mean)
print('df_dewpoint_n_median:', df_dewpoint_n_median) 
print('df_dewpoint_n_min:', df_dewpoint_n_min) 
print('df_dewpoint_n_max:', df_dewpoint_n_max) 
print('df_dewpoint_n_count:', df_dewpoint_n_count)
print('###############################')

#### df_dewpoint_n에서 찾은 Mean값을 np.nan으로 대체 함
df_dewpoint_filled_mean = df_dewpoint_n.copy()
df_dewpoint_filled_mean[df_dewpoint_filled_mean.isnull()] = df_dewpoint_n_mean 

df_dewpoint_filled_mean_of_mean = df_dewpoint_filled_mean.mean()
df_dewpoint_filled_mean_of_median = df_dewpoint_filled_mean.median()
df_dewpoint_filled_mean_of_min = df_dewpoint_filled_mean.min()
df_dewpoint_filled_mean_of_max = df_dewpoint_filled_mean.max()
df_dewpoint_filled_mean_of_count = len(df_dewpoint_filled_mean)

print('df_dewpoint_filled_mean_of_mean:', df_dewpoint_filled_mean_of_mean)
print('df_dewpoint_filled_mean_of_median:', df_dewpoint_filled_mean_of_median) 
print('df_dewpoint_filled_mean_of_min:', df_dewpoint_filled_mean_of_min) 
print('df_dewpoint_filled_mean_of_max:', df_dewpoint_filled_mean_of_max) 
print('df_dewpoint_filled_mean_of_count:', df_dewpoint_filled_mean_of_count)
print('###############################')

#### df_dewpoint_n에서 찾은 Median값을 np.nan으로 대체 함
df_dewpoint_filled_median = df_dewpoint_n.copy()
df_dewpoint_filled_median[df_dewpoint_filled_median.isnull()] = df_dewpoint_n_median

df_dewpoint_filled_median_of_mean = df_dewpoint_filled_median.mean()
df_dewpoint_filled_median_of_median = df_dewpoint_filled_median.median()
df_dewpoint_filled_median_of_min = df_dewpoint_filled_median.min()
df_dewpoint_filled_median_of_max = df_dewpoint_filled_median.max()
df_dewpoint_filled_median_of_count = len(df_dewpoint_filled_median)

print('df_dewpoint_filled_median_of_mean:', df_dewpoint_filled_median_of_mean)
print('df_dewpoint_filled_median_of_median:', df_dewpoint_filled_median_of_median) 
print('df_dewpoint_filled_median_of_min:', df_dewpoint_filled_median_of_min) 
print('df_dewpoint_filled_median_of_max:', df_dewpoint_filled_median_of_max) 
print('df_dewpoint_filled_median_of_count:', df_dewpoint_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4481514
# Total 이상값: 41625
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4481514
# Total_n 이상값: 41625
# Total_n 정상값 - 이상값: 0
# ###############################
# df_dewpoint_n_mean: 46.13964432555605
# df_dewpoint_n_median: 49.0
# df_dewpoint_n_min: -24.0
# df_dewpoint_n_max: 77.0
# df_dewpoint_n_count: 4523139
# ###############################
# df_dewpoint_filled_mean_of_mean: 46.13964432554912
# df_dewpoint_filled_mean_of_median: 49.0
# df_dewpoint_filled_mean_of_min: -24.0
# df_dewpoint_filled_mean_of_max: 77.0
# df_dewpoint_filled_mean_of_count: 4523139
# ###############################
# df_dewpoint_filled_median_of_mean: 46.16596726300032
# df_dewpoint_filled_median_of_median: 49.0
# df_dewpoint_filled_median_of_min: -24.0
# df_dewpoint_filled_median_of_max: 77.0
# df_dewpoint_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 6. wetbulb column

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) dewpoint 작업
df_dewpoint = df['dewpoint']

print('Total:', len(df_dewpoint))
print('Total 정상값:', (len(df_dewpoint[df_dewpoint != 'M'])))
print('Total 이상값:', (len(df_dewpoint[df_dewpoint == 'M']) | len(df_dewpoint[df_dewpoint == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_dewpoint) - (len(df_dewpoint[df_dewpoint != 'M'])) - (len(df_dewpoint[df_dewpoint == 'M']) + len(df_dewpoint[df_dewpoint == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_dewpoint_n = df_dewpoint.copy()
df_dewpoint_n = pd.to_numeric(df_dewpoint_n, errors = 'coerce')

print('Total_n:', len(df_dewpoint_n) )
print('Total_n 정상값:', len(df_dewpoint_n) - len(df_dewpoint_n[df_dewpoint_n.isnull()]))
print('Total_n 이상값:', len(df_dewpoint_n[df_dewpoint_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_dewpoint_n) - (len(df_dewpoint_n) - len(df_dewpoint_n[df_dewpoint_n.isnull()])) - len(df_dewpoint_n[df_dewpoint_n.isnull()]))
print('###############################')

#### df_dewpoint_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_dewpoint_n_mean = df_dewpoint_n.mean(); df_dewpoint_n_median = df_dewpoint_n.median(); df_dewpoint_n_min = df_dewpoint_n.min(); 
df_dewpoint_n_max = df_dewpoint_n.max();   df_dewpoint_n_count = len(df_dewpoint_n);
print('df_dewpoint_n_mean:', df_dewpoint_n_mean)
print('df_dewpoint_n_median:', df_dewpoint_n_median) 
print('df_dewpoint_n_min:', df_dewpoint_n_min) 
print('df_dewpoint_n_max:', df_dewpoint_n_max) 
print('df_dewpoint_n_count:', df_dewpoint_n_count)
print('###############################')

#### df_dewpoint_n에서 찾은 Mean값을 np.nan으로 대체 함
df_dewpoint_filled_mean = df_dewpoint_n.copy()
df_dewpoint_filled_mean[df_dewpoint_filled_mean.isnull()] = df_dewpoint_n_mean 

df_dewpoint_filled_mean_of_mean = df_dewpoint_filled_mean.mean()
df_dewpoint_filled_mean_of_median = df_dewpoint_filled_mean.median()
df_dewpoint_filled_mean_of_min = df_dewpoint_filled_mean.min()
df_dewpoint_filled_mean_of_max = df_dewpoint_filled_mean.max()
df_dewpoint_filled_mean_of_count = len(df_dewpoint_filled_mean)

print('df_dewpoint_filled_mean_of_mean:', df_dewpoint_filled_mean_of_mean)
print('df_dewpoint_filled_mean_of_median:', df_dewpoint_filled_mean_of_median) 
print('df_dewpoint_filled_mean_of_min:', df_dewpoint_filled_mean_of_min) 
print('df_dewpoint_filled_mean_of_max:', df_dewpoint_filled_mean_of_max) 
print('df_dewpoint_filled_mean_of_count:', df_dewpoint_filled_mean_of_count)
print('###############################')

#### df_dewpoint_n에서 찾은 Median값을 np.nan으로 대체 함
df_dewpoint_filled_median = df_dewpoint_n.copy()
df_dewpoint_filled_median[df_dewpoint_filled_median.isnull()] = df_dewpoint_n_median

df_dewpoint_filled_median_of_mean = df_dewpoint_filled_median.mean()
df_dewpoint_filled_median_of_median = df_dewpoint_filled_median.median()
df_dewpoint_filled_median_of_min = df_dewpoint_filled_median.min()
df_dewpoint_filled_median_of_max = df_dewpoint_filled_median.max()
df_dewpoint_filled_median_of_count = len(df_dewpoint_filled_median)

print('df_dewpoint_filled_median_of_mean:', df_dewpoint_filled_median_of_mean)
print('df_dewpoint_filled_median_of_median:', df_dewpoint_filled_median_of_median) 
print('df_dewpoint_filled_median_of_min:', df_dewpoint_filled_median_of_min) 
print('df_dewpoint_filled_median_of_max:', df_dewpoint_filled_median_of_max) 
print('df_dewpoint_filled_median_of_count:', df_dewpoint_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4481514
# Total 이상값: 41625
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4481514
# Total_n 이상값: 41625
# Total_n 정상값 - 이상값: 0
# ###############################
# df_dewpoint_n_mean: 46.13964432555605
# df_dewpoint_n_median: 49.0
# df_dewpoint_n_min: -24.0
# df_dewpoint_n_max: 77.0
# df_dewpoint_n_count: 4523139
# ###############################
# df_dewpoint_filled_mean_of_mean: 46.13964432554912
# df_dewpoint_filled_mean_of_median: 49.0
# df_dewpoint_filled_mean_of_min: -24.0
# df_dewpoint_filled_mean_of_max: 77.0
# df_dewpoint_filled_mean_of_count: 4523139
# ###############################
# df_dewpoint_filled_median_of_mean: 46.16596726300032
# df_dewpoint_filled_median_of_median: 49.0
# df_dewpoint_filled_median_of_min: -24.0
# df_dewpoint_filled_median_of_max: 77.0
# df_dewpoint_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 7. heat column

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) heat 작업
df_heat = df['heat']

print('Total:', len(df_heat))
print('Total 정상값:', (len(df_heat[df_heat != 'M'])))
print('Total 이상값:', (len(df_heat[df_heat == 'M']) | len(df_heat[df_heat == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_heat) - (len(df_heat[df_heat != 'M'])) - (len(df_heat[df_heat == 'M']) + len(df_heat[df_heat == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_heat_n = df_heat.copy()
df_heat_n = pd.to_numeric(df_heat_n, errors = 'coerce')

print('Total_n:', len(df_heat_n) )
print('Total_n 정상값:', len(df_heat_n) - len(df_heat_n[df_heat_n.isnull()]))
print('Total_n 이상값:', len(df_heat_n[df_heat_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_heat_n) - (len(df_heat_n) - len(df_heat_n[df_heat_n.isnull()])) - len(df_heat_n[df_heat_n.isnull()]))
print('###############################')

#### df_heat_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_heat_n_mean = df_heat_n.mean(); df_heat_n_median = df_heat_n.median(); df_heat_n_min = df_heat_n.min(); 
df_heat_n_max = df_heat_n.max();   df_heat_n_count = len(df_heat_n);
print('df_heat_n_mean:', df_heat_n_mean)
print('df_heat_n_median:', df_heat_n_median) 
print('df_heat_n_min:', df_heat_n_min) 
print('df_heat_n_max:', df_heat_n_max) 
print('df_heat_n_count:', df_heat_n_count)
print('###############################')

#### df_heat_n에서 찾은 Mean값을 np.nan으로 대체 함
df_heat_filled_mean = df_heat_n.copy()
df_heat_filled_mean[df_heat_filled_mean.isnull()] = df_heat_n_mean 

df_heat_filled_mean_of_mean = df_heat_filled_mean.mean()
df_heat_filled_mean_of_median = df_heat_filled_mean.median()
df_heat_filled_mean_of_min = df_heat_filled_mean.min()
df_heat_filled_mean_of_max = df_heat_filled_mean.max()
df_heat_filled_mean_of_count = len(df_heat_filled_mean)

print('df_heat_filled_mean_of_mean:', df_heat_filled_mean_of_mean)
print('df_heat_filled_mean_of_median:', df_heat_filled_mean_of_median) 
print('df_heat_filled_mean_of_min:', df_heat_filled_mean_of_min) 
print('df_heat_filled_mean_of_max:', df_heat_filled_mean_of_max) 
print('df_heat_filled_mean_of_count:', df_heat_filled_mean_of_count)
print('###############################')

#### df_heat_n에서 찾은 Median값을 np.nan으로 대체 함
df_heat_filled_median = df_heat_n.copy()
df_heat_filled_median[df_heat_filled_median.isnull()] = df_heat_n_median

df_heat_filled_median_of_mean = df_heat_filled_median.mean()
df_heat_filled_median_of_median = df_heat_filled_median.median()
df_heat_filled_median_of_min = df_heat_filled_median.min()
df_heat_filled_median_of_max = df_heat_filled_median.max()
df_heat_filled_median_of_count = len(df_heat_filled_median)

print('df_heat_filled_median_of_mean:', df_heat_filled_median_of_mean)
print('df_heat_filled_median_of_median:', df_heat_filled_median_of_median) 
print('df_heat_filled_median_of_min:', df_heat_filled_median_of_min) 
print('df_heat_filled_median_of_max:', df_heat_filled_median_of_max) 
print('df_heat_filled_median_of_count:', df_heat_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4426569
# Total 이상값: 96570
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4426569
# Total_n 이상값: 96570
# Total_n 정상값 - 이상값: 0
# ###############################
# df_heat_n_mean: 9.633566538779808
# df_heat_n_median: 1.0
# df_heat_n_min: 0.0
# df_heat_n_max: 81.0
# df_heat_n_count: 4523139
# ###############################
# df_heat_filled_mean_of_mean: 9.633566538765315
# df_heat_filled_mean_of_median: 2.0
# df_heat_filled_mean_of_min: 0.0
# df_heat_filled_mean_of_max: 81.0
# df_heat_filled_mean_of_count: 4523139
# ###############################
# df_heat_filled_median_of_mean: 9.449238018110874
# df_heat_filled_median_of_median: 1.0
# df_heat_filled_median_of_min: 0.0
# df_heat_filled_median_of_max: 81.0
# df_heat_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 8. cool column

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) cool 작업
df_cool = df['cool']

print('Total:', len(df_cool))
print('Total 정상값:', (len(df_cool[df_cool != 'M'])))
print('Total 이상값:', (len(df_cool[df_cool == 'M']) | len(df_cool[df_cool == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_cool) - (len(df_cool[df_cool != 'M'])) - (len(df_cool[df_cool == 'M']) + len(df_cool[df_cool == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_cool_n = df_cool.copy()
df_cool_n = pd.to_numeric(df_cool_n, errors = 'coerce')

print('Total_n:', len(df_cool_n) )
print('Total_n 정상값:', len(df_cool_n) - len(df_cool_n[df_cool_n.isnull()]))
print('Total_n 이상값:', len(df_cool_n[df_cool_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_cool_n) - (len(df_cool_n) - len(df_cool_n[df_cool_n.isnull()])) - len(df_cool_n[df_cool_n.isnull()]))
print('###############################')

#### df_cool_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_cool_n_mean = df_cool_n.mean(); df_cool_n_median = df_cool_n.median(); df_cool_n_min = df_cool_n.min(); 
df_cool_n_max = df_cool_n.max();   df_cool_n_count = len(df_cool_n);
print('df_cool_n_mean:', df_cool_n_mean)
print('df_cool_n_median:', df_cool_n_median) 
print('df_cool_n_min:', df_cool_n_min) 
print('df_cool_n_max:', df_cool_n_max) 
print('df_cool_n_count:', df_cool_n_count)
print('###############################')

#### df_cool_n에서 찾은 Mean값을 np.nan으로 대체 함
df_cool_filled_mean = df_cool_n.copy()
df_cool_filled_mean[df_cool_filled_mean.isnull()] = df_cool_n_mean 

df_cool_filled_mean_of_mean = df_cool_filled_mean.mean()
df_cool_filled_mean_of_median = df_cool_filled_mean.median()
df_cool_filled_mean_of_min = df_cool_filled_mean.min()
df_cool_filled_mean_of_max = df_cool_filled_mean.max()
df_cool_filled_mean_of_count = len(df_cool_filled_mean)

print('df_cool_filled_mean_of_mean:', df_cool_filled_mean_of_mean)
print('df_cool_filled_mean_of_median:', df_cool_filled_mean_of_median) 
print('df_cool_filled_mean_of_min:', df_cool_filled_mean_of_min) 
print('df_cool_filled_mean_of_max:', df_cool_filled_mean_of_max) 
print('df_cool_filled_mean_of_count:', df_cool_filled_mean_of_count)
print('###############################')

#### df_cool_n에서 찾은 Median값을 np.nan으로 대체 함
df_cool_filled_median = df_cool_n.copy()
df_cool_filled_median[df_cool_filled_median.isnull()] = df_cool_n_median

df_cool_filled_median_of_mean = df_cool_filled_median.mean()
df_cool_filled_median_of_median = df_cool_filled_median.median()
df_cool_filled_median_of_min = df_cool_filled_median.min()
df_cool_filled_median_of_max = df_cool_filled_median.max()
df_cool_filled_median_of_count = len(df_cool_filled_median)

print('df_cool_filled_median_of_mean:', df_cool_filled_median_of_mean)
print('df_cool_filled_median_of_median:', df_cool_filled_median_of_median) 
print('df_cool_filled_median_of_min:', df_cool_filled_median_of_min) 
print('df_cool_filled_median_of_max:', df_cool_filled_median_of_max) 
print('df_cool_filled_median_of_count:', df_cool_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4426569
# Total 이상값: 96570
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4426569
# Total_n 이상값: 96570
# Total_n 정상값 - 이상값: 0
# ###############################
# df_cool_n_mean: 5.815592166303067
# df_cool_n_median: 0.0
# df_cool_n_min: 0.0
# df_cool_n_max: 35.0
# df_cool_n_count: 4523139
# ###############################
# df_cool_filled_mean_of_mean: 5.815592166297728
# df_cool_filled_mean_of_median: 0.0
# df_cool_filled_mean_of_min: 0.0
# df_cool_filled_mean_of_max: 35.0
# df_cool_filled_mean_of_count: 4523139
# ###############################
# df_cool_filled_median_of_mean: 5.6914280105033255
# df_cool_filled_median_of_median: 0.0
# df_cool_filled_median_of_min: 0.0
# df_cool_filled_median_of_max: 35.0
# df_cool_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 9. sunrise column = TimeSeries

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) sunrise 작업
df_sunrise = df['sunrise']

print('Total:', len(df_sunrise))
print('Total 정상값:', (len(df_sunrise[df_sunrise != '-'])))
print('Total 이상값:', (len(df_sunrise[df_sunrise == '-']) | len(df_sunrise[df_sunrise == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_sunrise) - (len(df_sunrise[df_sunrise != '-'])) - (len(df_sunrise[df_sunrise == '-']) + len(df_sunrise[df_sunrise == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_sunrise_n = df_sunrise.copy()
df_sunrise_n = pd.to_numeric(df_sunrise_n, errors = 'coerce')

print('Total_n:', len(df_sunrise_n) )
print('Total_n 정상값:', len(df_sunrise_n) - len(df_sunrise_n[df_sunrise_n.isnull()]))
print('Total_n 이상값:', len(df_sunrise_n[df_sunrise_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_sunrise_n) - (len(df_sunrise_n) - len(df_sunrise_n[df_sunrise_n.isnull()])) - len(df_sunrise_n[df_sunrise_n.isnull()]))
print('###############################')

#### df_sunrise_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_sunrise_n_mean = df_sunrise_n.mean(); df_sunrise_n_median = df_sunrise_n.median(); df_sunrise_n_min = df_sunrise_n.min(); 
df_sunrise_n_max = df_sunrise_n.max();   df_sunrise_n_count = len(df_sunrise_n);
print('df_sunrise_n_mean:', df_sunrise_n_mean)
print('df_sunrise_n_median:', df_sunrise_n_median) 
print('df_sunrise_n_min:', df_sunrise_n_min) 
print('df_sunrise_n_max:', df_sunrise_n_max) 
print('df_sunrise_n_count:', df_sunrise_n_count)
print('###############################')

#### df_sunrise_n에서 찾은 Mean값을 np.nan으로 대체 함
df_sunrise_filled_mean = df_sunrise_n.copy()
df_sunrise_filled_mean[df_sunrise_filled_mean.isnull()] = df_sunrise_n_mean 

df_sunrise_filled_mean_of_mean = df_sunrise_filled_mean.mean()
df_sunrise_filled_mean_of_median = df_sunrise_filled_mean.median()
df_sunrise_filled_mean_of_min = df_sunrise_filled_mean.min()
df_sunrise_filled_mean_of_max = df_sunrise_filled_mean.max()
df_sunrise_filled_mean_of_count = len(df_sunrise_filled_mean)

print('df_sunrise_filled_mean_of_mean:', df_sunrise_filled_mean_of_mean)
print('df_sunrise_filled_mean_of_median:', df_sunrise_filled_mean_of_median) 
print('df_sunrise_filled_mean_of_min:', df_sunrise_filled_mean_of_min) 
print('df_sunrise_filled_mean_of_max:', df_sunrise_filled_mean_of_max) 
print('df_sunrise_filled_mean_of_count:', df_sunrise_filled_mean_of_count)
print('###############################')

#### df_sunrise_n에서 찾은 Median값을 np.nan으로 대체 함
df_sunrise_filled_median = df_sunrise_n.copy()
df_sunrise_filled_median[df_sunrise_filled_median.isnull()] = df_sunrise_n_median

df_sunrise_filled_median_of_mean = df_sunrise_filled_median.mean()
df_sunrise_filled_median_of_median = df_sunrise_filled_median.median()
df_sunrise_filled_median_of_min = df_sunrise_filled_median.min()
df_sunrise_filled_median_of_max = df_sunrise_filled_median.max()
df_sunrise_filled_median_of_count = len(df_sunrise_filled_median)

print('df_sunrise_filled_median_of_mean:', df_sunrise_filled_median_of_mean)
print('df_sunrise_filled_median_of_median:', df_sunrise_filled_median_of_median) 
print('df_sunrise_filled_median_of_min:', df_sunrise_filled_median_of_min) 
print('df_sunrise_filled_median_of_max:', df_sunrise_filled_median_of_max) 
print('df_sunrise_filled_median_of_count:', df_sunrise_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 1846041
# Total 이상값: 2677098
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 1846041
# Total_n 이상값: 2677098
# Total_n 정상값 - 이상값: 0
# ###############################
# df_sunrise_n_mean: 602.9494919126931
# df_sunrise_n_median: 612.0
# df_sunrise_n_min: 406.0
# df_sunrise_n_max: 740.0
# df_sunrise_n_count: 4523139
# ###############################
# df_sunrise_filled_mean_of_mean: 602.9494919339216
# df_sunrise_filled_mean_of_median: 602.9494919126931
# df_sunrise_filled_mean_of_min: 406.0
# df_sunrise_filled_mean_of_max: 740.0
# df_sunrise_filled_mean_of_count: 4523139
# ###############################
# df_sunrise_filled_median_of_mean: 608.3061915629831
# df_sunrise_filled_median_of_median: 612.0
# df_sunrise_filled_median_of_min: 406.0
# df_sunrise_filled_median_of_max: 740.0
# df_sunrise_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 9. sunset column = TimeSeries

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) sunset 작업
df_sunset = df['sunset']

print('Total:', len(df_sunset))
print('Total 정상값:', (len(df_sunset[df_sunset != '-'])))
print('Total 이상값:', (len(df_sunset[df_sunset == '-']) | len(df_sunset[df_sunset == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_sunset) - (len(df_sunset[df_sunset != '-'])) - (len(df_sunset[df_sunset == '-']) + len(df_sunset[df_sunset == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_sunset_n = df_sunset.copy()
df_sunset_n = pd.to_numeric(df_sunset_n, errors = 'coerce')

print('Total_n:', len(df_sunset_n) )
print('Total_n 정상값:', len(df_sunset_n) - len(df_sunset_n[df_sunset_n.isnull()]))
print('Total_n 이상값:', len(df_sunset_n[df_sunset_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_sunset_n) - (len(df_sunset_n) - len(df_sunset_n[df_sunset_n.isnull()])) - len(df_sunset_n[df_sunset_n.isnull()]))
print('###############################')

#### df_sunset_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_sunset_n_mean = df_sunset_n.mean(); df_sunset_n_median = df_sunset_n.median(); df_sunset_n_min = df_sunset_n.min(); 
df_sunset_n_max = df_sunset_n.max();   df_sunset_n_count = len(df_sunset_n);
print('df_sunset_n_mean:', df_sunset_n_mean)
print('df_sunset_n_median:', df_sunset_n_median) 
print('df_sunset_n_min:', df_sunset_n_min) 
print('df_sunset_n_max:', df_sunset_n_max) 
print('df_sunset_n_count:', df_sunset_n_count)
print('###############################')

#### df_sunset_n에서 찾은 Mean값을 np.nan으로 대체 함
df_sunset_filled_mean = df_sunset_n.copy()
df_sunset_filled_mean[df_sunset_filled_mean.isnull()] = df_sunset_n_mean 

df_sunset_filled_mean_of_mean = df_sunset_filled_mean.mean()
df_sunset_filled_mean_of_median = df_sunset_filled_mean.median()
df_sunset_filled_mean_of_min = df_sunset_filled_mean.min()
df_sunset_filled_mean_of_max = df_sunset_filled_mean.max()
df_sunset_filled_mean_of_count = len(df_sunset_filled_mean)

print('df_sunset_filled_mean_of_mean:', df_sunset_filled_mean_of_mean)
print('df_sunset_filled_mean_of_median:', df_sunset_filled_mean_of_median) 
print('df_sunset_filled_mean_of_min:', df_sunset_filled_mean_of_min) 
print('df_sunset_filled_mean_of_max:', df_sunset_filled_mean_of_max) 
print('df_sunset_filled_mean_of_count:', df_sunset_filled_mean_of_count)
print('###############################')

#### df_sunset_n에서 찾은 Median값을 np.nan으로 대체 함
df_sunset_filled_median = df_sunset_n.copy()
df_sunset_filled_median[df_sunset_filled_median.isnull()] = df_sunset_n_median

df_sunset_filled_median_of_mean = df_sunset_filled_median.mean()
df_sunset_filled_median_of_median = df_sunset_filled_median.median()
df_sunset_filled_median_of_min = df_sunset_filled_median.min()
df_sunset_filled_median_of_max = df_sunset_filled_median.max()
df_sunset_filled_median_of_count = len(df_sunset_filled_median)

print('df_sunset_filled_median_of_mean:', df_sunset_filled_median_of_mean)
print('df_sunset_filled_median_of_median:', df_sunset_filled_median_of_median) 
print('df_sunset_filled_median_of_min:', df_sunset_filled_median_of_min) 
print('df_sunset_filled_median_of_max:', df_sunset_filled_median_of_max) 
print('df_sunset_filled_median_of_count:', df_sunset_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 1846041
# Total 이상값: 2677098
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 1846041
# Total_n 이상값: 2677098
# Total_n 정상값 - 이상값: 0
# ###############################
# df_sunset_n_mean: 1832.1746136732609
# df_sunset_n_median: 1837.0
# df_sunset_n_min: 1611.0
# df_sunset_n_max: 1949.0
# df_sunset_n_count: 4523139
# ###############################
# df_sunset_filled_mean_of_mean: 1832.1746137405323
# df_sunset_filled_mean_of_median: 1832.1746136732609
# df_sunset_filled_mean_of_min: 1611.0
# df_sunset_filled_mean_of_max: 1949.0
# df_sunset_filled_mean_of_count: 4523139
# ###############################
# df_sunset_filled_median_of_mean: 1835.0306019779628
# df_sunset_filled_median_of_median: 1837.0
# df_sunset_filled_median_of_min: 1611.0
# df_sunset_filled_median_of_max: 1949.0
# df_sunset_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 10. CodeSum은 잠시 대기

# %% [markdown]
# # 11. SnowFall Column - 정상값 찾기

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) snowfall 작업
df_snowfall = df['snowfall']

print('Total:', len(df_snowfall))
# print('Total 정상값:', len(df_snowfall[(df_snowfall != 'M') | (df_snowfall != '  T')]))
print('Total 이상값:', (len(df_snowfall[df_snowfall == 'M']) | len(df_snowfall[df_snowfall == '  T'])))
# print('Total - 정상값 - 이상값:', 
#       len(df_snowfall) - (len(df_snowfall[df_snowfall != 'M'])) - (len(df_snowfall[df_snowfall == 'M']) + len(df_snowfall[df_snowfall == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_snowfall_n = df_snowfall.copy()

df_snowfall_n_for_min = pd.to_numeric(df_snowfall_n, errors = 'coerce')
df_snowfall_n[df_snowfall_n == '  T'] = 0.05

df_snowfall_n = pd.to_numeric(df_snowfall_n, errors = 'coerce')

print('Total_n:', len(df_snowfall_n) )
print('Total_n 정상값:', len(df_snowfall_n) - len(df_snowfall_n[df_snowfall_n.isnull()]))
print('Total_n 이상값:', len(df_snowfall_n[df_snowfall_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_snowfall_n) - (len(df_snowfall_n) - len(df_snowfall_n[df_snowfall_n.isnull()])) - len(df_snowfall_n[df_snowfall_n.isnull()]))
print('###############################')

#### df_snowfall_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_snowfall_n_mean = df_snowfall_n.mean(); df_snowfall_n_median = df_snowfall_n.median(); df_snowfall_n_min = df_snowfall_n.min(); 
df_snowfall_n_max = df_snowfall_n.max();   df_snowfall_n_count = len(df_snowfall_n);
print('df_snowfall_n_mean:', df_snowfall_n_mean)
print('df_snowfall_n_median:', df_snowfall_n_median) 
print('df_snowfall_n_min:', df_snowfall_n_min) 
print('df_snowfall_n_max:', df_snowfall_n_max) 
print('df_snowfall_n_count:', df_snowfall_n_count)
print('###############################')

#### df_snowfall_n에서 찾은 Mean값을 np.nan으로 대체 함
df_snowfall_filled_mean = df_snowfall_n.copy()
df_snowfall_filled_mean[df_snowfall_filled_mean.isnull()] = df_snowfall_n_mean 

df_snowfall_filled_mean_of_mean = df_snowfall_filled_mean.mean()
df_snowfall_filled_mean_of_median = df_snowfall_filled_mean.median()
df_snowfall_filled_mean_of_min = df_snowfall_filled_mean.min()
df_snowfall_filled_mean_of_max = df_snowfall_filled_mean.max()
df_snowfall_filled_mean_of_count = len(df_snowfall_filled_mean)

print('df_snowfall_filled_mean_of_mean:', df_snowfall_filled_mean_of_mean)
print('df_snowfall_filled_mean_of_median:', df_snowfall_filled_mean_of_median) 
print('df_snowfall_filled_mean_of_min:', df_snowfall_filled_mean_of_min) 
print('df_snowfall_filled_mean_of_max:', df_snowfall_filled_mean_of_max) 
print('df_snowfall_filled_mean_of_count:', df_snowfall_filled_mean_of_count)
print('###############################')

#### df_snowfall_n에서 찾은 Median값을 np.nan으로 대체 함
df_snowfall_filled_median = df_snowfall_n.copy()
df_snowfall_filled_median[df_snowfall_filled_median.isnull()] = df_snowfall_n_median

df_snowfall_filled_median_of_mean = df_snowfall_filled_median.mean()
df_snowfall_filled_median_of_median = df_snowfall_filled_median.median()
df_snowfall_filled_median_of_min = df_snowfall_filled_median.min()
df_snowfall_filled_median_of_max = df_snowfall_filled_median.max()
df_snowfall_filled_median_of_count = len(df_snowfall_filled_median)

print('df_snowfall_filled_median_of_mean:', df_snowfall_filled_median_of_mean)
print('df_snowfall_filled_median_of_median:', df_snowfall_filled_median_of_median) 
print('df_snowfall_filled_median_of_min:', df_snowfall_filled_median_of_min) 
print('df_snowfall_filled_median_of_max:', df_snowfall_filled_median_of_max) 
print('df_snowfall_filled_median_of_count:', df_snowfall_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 이상값: 1571831
# ###############################
# Total_n: 4523139
# Total_n 정상값: 2957484
# Total_n 이상값: 1565655
# Total_n 정상값 - 이상값: 0
# ###############################
# df_snowfall_n_mean: 0.016322624230598104
# df_snowfall_n_median: 0.0
# df_snowfall_n_min: 0.0
# df_snowfall_n_max: 16.2
# df_snowfall_n_count: 4523139
# ###############################
# df_snowfall_filled_mean_of_mean: 0.01632262423020898
# df_snowfall_filled_mean_of_median: 0.0
# df_snowfall_filled_mean_of_min: 0.0
# df_snowfall_filled_mean_of_max: 16.2
# df_snowfall_filled_mean_of_count: 4523139
# ###############################
# df_snowfall_filled_median_of_mean: 0.010672654543671153
# df_snowfall_filled_median_of_median: 0.0
# df_snowfall_filled_median_of_min: 0.0
# df_snowfall_filled_median_of_max: 16.2
# df_snowfall_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 12. Preciptotal Column - 정상값 찾기

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) preciptotal 작업
df_preciptotal = df['preciptotal']

print('Total:', len(df_preciptotal))
# print('Total 정상값:', len(df_preciptotal[(df_preciptotal != 'M') | (df_preciptotal != '  T')]))
print('Total 이상값:', (len(df_preciptotal[df_preciptotal == 'M']) | len(df_preciptotal[df_preciptotal == '  T'])))
# print('Total - 정상값 - 이상값:', 
#       len(df_preciptotal) - (len(df_preciptotal[df_preciptotal != 'M'])) - (len(df_preciptotal[df_preciptotal == 'M']) + len(df_preciptotal[df_preciptotal == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_preciptotal_n = df_preciptotal.copy()

df_preciptotal_n_for_min = pd.to_numeric(df_preciptotal_n, errors = 'coerce')
df_preciptotal_n[df_preciptotal_n == '  T'] = 0.005

df_preciptotal_n = pd.to_numeric(df_preciptotal_n, errors = 'coerce')

print('Total_n:', len(df_preciptotal_n) )
print('Total_n 정상값:', len(df_preciptotal_n) - len(df_preciptotal_n[df_preciptotal_n.isnull()]))
print('Total_n 이상값:', len(df_preciptotal_n[df_preciptotal_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_preciptotal_n) - (len(df_preciptotal_n) - len(df_preciptotal_n[df_preciptotal_n.isnull()])) - len(df_preciptotal_n[df_preciptotal_n.isnull()]))
print('###############################')

#### df_preciptotal_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_preciptotal_n_mean = df_preciptotal_n.mean(); df_preciptotal_n_median = df_preciptotal_n.median(); df_preciptotal_n_min = df_preciptotal_n.min(); 
df_preciptotal_n_max = df_preciptotal_n.max();   df_preciptotal_n_count = len(df_preciptotal_n);
print('df_preciptotal_n_mean:', df_preciptotal_n_mean)
print('df_preciptotal_n_median:', df_preciptotal_n_median) 
print('df_preciptotal_n_min:', df_preciptotal_n_min) 
print('df_preciptotal_n_max:', df_preciptotal_n_max) 
print('df_preciptotal_n_count:', df_preciptotal_n_count)
print('###############################')

#### df_preciptotal_n에서 찾은 Mean값을 np.nan으로 대체 함
df_preciptotal_filled_mean = df_preciptotal_n.copy()
df_preciptotal_filled_mean[df_preciptotal_filled_mean.isnull()] = df_preciptotal_n_mean 

df_preciptotal_filled_mean_of_mean = df_preciptotal_filled_mean.mean()
df_preciptotal_filled_mean_of_median = df_preciptotal_filled_mean.median()
df_preciptotal_filled_mean_of_min = df_preciptotal_filled_mean.min()
df_preciptotal_filled_mean_of_max = df_preciptotal_filled_mean.max()
df_preciptotal_filled_mean_of_count = len(df_preciptotal_filled_mean)

print('df_preciptotal_filled_mean_of_mean:', df_preciptotal_filled_mean_of_mean)
print('df_preciptotal_filled_mean_of_median:', df_preciptotal_filled_mean_of_median) 
print('df_preciptotal_filled_mean_of_min:', df_preciptotal_filled_mean_of_min) 
print('df_preciptotal_filled_mean_of_max:', df_preciptotal_filled_mean_of_max) 
print('df_preciptotal_filled_mean_of_count:', df_preciptotal_filled_mean_of_count)
print('###############################')

#### df_preciptotal_n에서 찾은 Median값을 np.nan으로 대체 함
df_preciptotal_filled_median = df_preciptotal_n.copy()
df_preciptotal_filled_median[df_preciptotal_filled_median.isnull()] = df_preciptotal_n_median

df_preciptotal_filled_median_of_mean = df_preciptotal_filled_median.mean()
df_preciptotal_filled_median_of_median = df_preciptotal_filled_median.median()
df_preciptotal_filled_median_of_min = df_preciptotal_filled_median.min()
df_preciptotal_filled_median_of_max = df_preciptotal_filled_median.max()
df_preciptotal_filled_median_of_count = len(df_preciptotal_filled_median)

print('df_preciptotal_filled_median_of_mean:', df_preciptotal_filled_median_of_mean)
print('df_preciptotal_filled_median_of_median:', df_preciptotal_filled_median_of_median) 
print('df_preciptotal_filled_median_of_min:', df_preciptotal_filled_median_of_min) 
print('df_preciptotal_filled_median_of_max:', df_preciptotal_filled_median_of_max) 
print('df_preciptotal_filled_median_of_count:', df_preciptotal_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 이상값: 564958
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4515369
# Total_n 이상값: 7770
# Total_n 정상값 - 이상값: 0
# ###############################
# df_preciptotal_n_mean: 0.07369306030196988
# df_preciptotal_n_median: 0.0
# df_preciptotal_n_min: 0.0
# df_preciptotal_n_max: 7.36
# df_preciptotal_n_count: 4523139
# ###############################
# df_preciptotal_filled_mean_of_mean: 0.07369306030198323
# df_preciptotal_filled_mean_of_median: 0.0
# df_preciptotal_filled_mean_of_min: 0.0
# df_preciptotal_filled_mean_of_max: 7.36
# df_preciptotal_filled_mean_of_count: 4523139
# ###############################
# df_preciptotal_filled_median_of_mean: 0.07356646788936742
# df_preciptotal_filled_median_of_median: 0.0
# df_preciptotal_filled_median_of_min: 0.0
# df_preciptotal_filled_median_of_max: 7.36
# df_preciptotal_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 13. stnpressure column

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) stnpressure 작업
df_stnpressure = df['stnpressure']

print('Total:', len(df_stnpressure))
print('Total 정상값:', (len(df_stnpressure[df_stnpressure != 'M'])))
print('Total 이상값:', (len(df_stnpressure[df_stnpressure == 'M']) | len(df_stnpressure[df_stnpressure == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_stnpressure) - (len(df_stnpressure[df_stnpressure != 'M'])) - (len(df_stnpressure[df_stnpressure == 'M']) + len(df_stnpressure[df_stnpressure == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_stnpressure_n = df_stnpressure.copy()
df_stnpressure_n = pd.to_numeric(df_stnpressure_n, errors = 'coerce')

print('Total_n:', len(df_stnpressure_n) )
print('Total_n 정상값:', len(df_stnpressure_n) - len(df_stnpressure_n[df_stnpressure_n.isnull()]))
print('Total_n 이상값:', len(df_stnpressure_n[df_stnpressure_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_stnpressure_n) - (len(df_stnpressure_n) - len(df_stnpressure_n[df_stnpressure_n.isnull()])) - len(df_stnpressure_n[df_stnpressure_n.isnull()]))
print('###############################')

#### df_stnpressure_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_stnpressure_n_mean = df_stnpressure_n.mean(); df_stnpressure_n_median = df_stnpressure_n.median(); df_stnpressure_n_min = df_stnpressure_n.min(); 
df_stnpressure_n_max = df_stnpressure_n.max();   df_stnpressure_n_count = len(df_stnpressure_n);
print('df_stnpressure_n_mean:', df_stnpressure_n_mean)
print('df_stnpressure_n_median:', df_stnpressure_n_median) 
print('df_stnpressure_n_min:', df_stnpressure_n_min) 
print('df_stnpressure_n_max:', df_stnpressure_n_max) 
print('df_stnpressure_n_count:', df_stnpressure_n_count)
print('###############################')

#### df_stnpressure_n에서 찾은 Mean값을 np.nan으로 대체 함
df_stnpressure_filled_mean = df_stnpressure_n.copy()
df_stnpressure_filled_mean[df_stnpressure_filled_mean.isnull()] = df_stnpressure_n_mean 

df_stnpressure_filled_mean_of_mean = df_stnpressure_filled_mean.mean()
df_stnpressure_filled_mean_of_median = df_stnpressure_filled_mean.median()
df_stnpressure_filled_mean_of_min = df_stnpressure_filled_mean.min()
df_stnpressure_filled_mean_of_max = df_stnpressure_filled_mean.max()
df_stnpressure_filled_mean_of_count = len(df_stnpressure_filled_mean)

print('df_stnpressure_filled_mean_of_mean:', df_stnpressure_filled_mean_of_mean)
print('df_stnpressure_filled_mean_of_median:', df_stnpressure_filled_mean_of_median) 
print('df_stnpressure_filled_mean_of_min:', df_stnpressure_filled_mean_of_min) 
print('df_stnpressure_filled_mean_of_max:', df_stnpressure_filled_mean_of_max) 
print('df_stnpressure_filled_mean_of_count:', df_stnpressure_filled_mean_of_count)
print('###############################')

#### df_stnpressure_n에서 찾은 Median값을 np.nan으로 대체 함
df_stnpressure_filled_median = df_stnpressure_n.copy()
df_stnpressure_filled_median[df_stnpressure_filled_median.isnull()] = df_stnpressure_n_median

df_stnpressure_filled_median_of_mean = df_stnpressure_filled_median.mean()
df_stnpressure_filled_median_of_median = df_stnpressure_filled_median.median()
df_stnpressure_filled_median_of_min = df_stnpressure_filled_median.min()
df_stnpressure_filled_median_of_max = df_stnpressure_filled_median.max()
df_stnpressure_filled_median_of_count = len(df_stnpressure_filled_median)

print('df_stnpressure_filled_median_of_mean:', df_stnpressure_filled_median_of_mean)
print('df_stnpressure_filled_median_of_median:', df_stnpressure_filled_median_of_median) 
print('df_stnpressure_filled_median_of_min:', df_stnpressure_filled_median_of_min) 
print('df_stnpressure_filled_median_of_max:', df_stnpressure_filled_median_of_max) 
print('df_stnpressure_filled_median_of_count:', df_stnpressure_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4507710
# Total 이상값: 15429
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4507710
# Total_n 이상값: 15429
# Total_n 정상값 - 이상값: 0
# ###############################
# df_stnpressure_n_mean: 28.77338537312747
# df_stnpressure_n_median: 29.34
# df_stnpressure_n_min: 23.72
# df_stnpressure_n_max: 30.61
# df_stnpressure_n_count: 4523139
# ###############################
# df_stnpressure_filled_mean_of_mean: 28.773385373134744
# df_stnpressure_filled_mean_of_median: 29.33
# df_stnpressure_filled_mean_of_min: 23.72
# df_stnpressure_filled_mean_of_max: 30.61
# df_stnpressure_filled_mean_of_count: 4523139
# ###############################
# df_stnpressure_filled_median_of_mean: 28.775318167393234
# df_stnpressure_filled_median_of_median: 29.34
# df_stnpressure_filled_median_of_min: 23.72
# df_stnpressure_filled_median_of_max: 30.61
# df_stnpressure_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 14. sealevel

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) sealevel 작업
df_sealevel = df['sealevel']

print('Total:', len(df_sealevel))
print('Total 정상값:', (len(df_sealevel[df_sealevel != 'M'])))
print('Total 이상값:', (len(df_sealevel[df_sealevel == 'M']) | len(df_sealevel[df_sealevel == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_sealevel) - (len(df_sealevel[df_sealevel != 'M'])) - (len(df_sealevel[df_sealevel == 'M']) + len(df_sealevel[df_sealevel == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_sealevel_n = df_sealevel.copy()
df_sealevel_n = pd.to_numeric(df_sealevel_n, errors = 'coerce')

print('Total_n:', len(df_sealevel_n) )
print('Total_n 정상값:', len(df_sealevel_n) - len(df_sealevel_n[df_sealevel_n.isnull()]))
print('Total_n 이상값:', len(df_sealevel_n[df_sealevel_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_sealevel_n) - (len(df_sealevel_n) - len(df_sealevel_n[df_sealevel_n.isnull()])) - len(df_sealevel_n[df_sealevel_n.isnull()]))
print('###############################')

#### df_sealevel_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_sealevel_n_mean = df_sealevel_n.mean(); df_sealevel_n_median = df_sealevel_n.median(); df_sealevel_n_min = df_sealevel_n.min(); 
df_sealevel_n_max = df_sealevel_n.max();   df_sealevel_n_count = len(df_sealevel_n);
print('df_sealevel_n_mean:', df_sealevel_n_mean)
print('df_sealevel_n_median:', df_sealevel_n_median) 
print('df_sealevel_n_min:', df_sealevel_n_min) 
print('df_sealevel_n_max:', df_sealevel_n_max) 
print('df_sealevel_n_count:', df_sealevel_n_count)
print('###############################')

#### df_sealevel_n에서 찾은 Mean값을 np.nan으로 대체 함
df_sealevel_filled_mean = df_sealevel_n.copy()
df_sealevel_filled_mean[df_sealevel_filled_mean.isnull()] = df_sealevel_n_mean 

df_sealevel_filled_mean_of_mean = df_sealevel_filled_mean.mean()
df_sealevel_filled_mean_of_median = df_sealevel_filled_mean.median()
df_sealevel_filled_mean_of_min = df_sealevel_filled_mean.min()
df_sealevel_filled_mean_of_max = df_sealevel_filled_mean.max()
df_sealevel_filled_mean_of_count = len(df_sealevel_filled_mean)

print('df_sealevel_filled_mean_of_mean:', df_sealevel_filled_mean_of_mean)
print('df_sealevel_filled_mean_of_median:', df_sealevel_filled_mean_of_median) 
print('df_sealevel_filled_mean_of_min:', df_sealevel_filled_mean_of_min) 
print('df_sealevel_filled_mean_of_max:', df_sealevel_filled_mean_of_max) 
print('df_sealevel_filled_mean_of_count:', df_sealevel_filled_mean_of_count)
print('###############################')

#### df_sealevel_n에서 찾은 Median값을 np.nan으로 대체 함
df_sealevel_filled_median = df_sealevel_n.copy()
df_sealevel_filled_median[df_sealevel_filled_median.isnull()] = df_sealevel_n_median

df_sealevel_filled_median_of_mean = df_sealevel_filled_median.mean()
df_sealevel_filled_median_of_median = df_sealevel_filled_median.median()
df_sealevel_filled_median_of_min = df_sealevel_filled_median.min()
df_sealevel_filled_median_of_max = df_sealevel_filled_median.max()
df_sealevel_filled_median_of_count = len(df_sealevel_filled_median)

print('df_sealevel_filled_median_of_mean:', df_sealevel_filled_median_of_mean)
print('df_sealevel_filled_median_of_median:', df_sealevel_filled_median_of_median) 
print('df_sealevel_filled_median_of_min:', df_sealevel_filled_median_of_min) 
print('df_sealevel_filled_median_of_max:', df_sealevel_filled_median_of_max) 
print('df_sealevel_filled_median_of_count:', df_sealevel_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4357971
# Total 이상값: 165168
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4357971
# Total_n 이상값: 165168
# Total_n 정상값 - 이상값: 0
# ###############################
# df_sealevel_n_mean: 30.01504979497168
# df_sealevel_n_median: 30.01
# df_sealevel_n_min: 29.16
# df_sealevel_n_max: 30.8
# df_sealevel_n_count: 4523139
# ###############################
# df_sealevel_filled_mean_of_mean: 30.015049794947966
# df_sealevel_filled_mean_of_median: 30.01
# df_sealevel_filled_mean_of_min: 29.16
# df_sealevel_filled_mean_of_max: 30.8
# df_sealevel_filled_mean_of_count: 4523139
# ###############################
# df_sealevel_filled_median_of_mean: 30.014865395457512
# df_sealevel_filled_median_of_median: 30.01
# df_sealevel_filled_median_of_min: 29.16
# df_sealevel_filled_median_of_max: 30.8
# df_sealevel_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 15. resultspeed

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) resultspeed 작업
df_resultspeed = df['resultspeed']

print('Total:', len(df_resultspeed))
print('Total 정상값:', (len(df_resultspeed[df_resultspeed != 'M'])))
print('Total 이상값:', (len(df_resultspeed[df_resultspeed == 'M']) | len(df_resultspeed[df_resultspeed == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_resultspeed) - (len(df_resultspeed[df_resultspeed != 'M'])) - (len(df_resultspeed[df_resultspeed == 'M']) + len(df_resultspeed[df_resultspeed == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_resultspeed_n = df_resultspeed.copy()
df_resultspeed_n = pd.to_numeric(df_resultspeed_n, errors = 'coerce')

print('Total_n:', len(df_resultspeed_n) )
print('Total_n 정상값:', len(df_resultspeed_n) - len(df_resultspeed_n[df_resultspeed_n.isnull()]))
print('Total_n 이상값:', len(df_resultspeed_n[df_resultspeed_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_resultspeed_n) - (len(df_resultspeed_n) - len(df_resultspeed_n[df_resultspeed_n.isnull()])) - len(df_resultspeed_n[df_resultspeed_n.isnull()]))
print('###############################')

#### df_resultspeed_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_resultspeed_n_mean = df_resultspeed_n.mean(); df_resultspeed_n_median = df_resultspeed_n.median(); df_resultspeed_n_min = df_resultspeed_n.min(); 
df_resultspeed_n_max = df_resultspeed_n.max();   df_resultspeed_n_count = len(df_resultspeed_n);
print('df_resultspeed_n_mean:', df_resultspeed_n_mean)
print('df_resultspeed_n_median:', df_resultspeed_n_median) 
print('df_resultspeed_n_min:', df_resultspeed_n_min) 
print('df_resultspeed_n_max:', df_resultspeed_n_max) 
print('df_resultspeed_n_count:', df_resultspeed_n_count)
print('###############################')

#### df_resultspeed_n에서 찾은 Mean값을 np.nan으로 대체 함
df_resultspeed_filled_mean = df_resultspeed_n.copy()
df_resultspeed_filled_mean[df_resultspeed_filled_mean.isnull()] = df_resultspeed_n_mean 

df_resultspeed_filled_mean_of_mean = df_resultspeed_filled_mean.mean()
df_resultspeed_filled_mean_of_median = df_resultspeed_filled_mean.median()
df_resultspeed_filled_mean_of_min = df_resultspeed_filled_mean.min()
df_resultspeed_filled_mean_of_max = df_resultspeed_filled_mean.max()
df_resultspeed_filled_mean_of_count = len(df_resultspeed_filled_mean)

print('df_resultspeed_filled_mean_of_mean:', df_resultspeed_filled_mean_of_mean)
print('df_resultspeed_filled_mean_of_median:', df_resultspeed_filled_mean_of_median) 
print('df_resultspeed_filled_mean_of_min:', df_resultspeed_filled_mean_of_min) 
print('df_resultspeed_filled_mean_of_max:', df_resultspeed_filled_mean_of_max) 
print('df_resultspeed_filled_mean_of_count:', df_resultspeed_filled_mean_of_count)
print('###############################')

#### df_resultspeed_n에서 찾은 Median값을 np.nan으로 대체 함
df_resultspeed_filled_median = df_resultspeed_n.copy()
df_resultspeed_filled_median[df_resultspeed_filled_median.isnull()] = df_resultspeed_n_median

df_resultspeed_filled_median_of_mean = df_resultspeed_filled_median.mean()
df_resultspeed_filled_median_of_median = df_resultspeed_filled_median.median()
df_resultspeed_filled_median_of_min = df_resultspeed_filled_median.min()
df_resultspeed_filled_median_of_max = df_resultspeed_filled_median.max()
df_resultspeed_filled_median_of_count = len(df_resultspeed_filled_median)

print('df_resultspeed_filled_median_of_mean:', df_resultspeed_filled_median_of_mean)
print('df_resultspeed_filled_median_of_median:', df_resultspeed_filled_median_of_median) 
print('df_resultspeed_filled_median_of_min:', df_resultspeed_filled_median_of_min) 
print('df_resultspeed_filled_median_of_max:', df_resultspeed_filled_median_of_max) 
print('df_resultspeed_filled_median_of_count:', df_resultspeed_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4497054
# Total 이상값: 26085
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4497054
# Total_n 이상값: 26085
# Total_n 정상값 - 이상값: 0
# ###############################
# df_resultspeed_n_mean: 6.392745717541813
# df_resultspeed_n_median: 5.5
# df_resultspeed_n_min: 0.0
# df_resultspeed_n_max: 28.4
# df_resultspeed_n_count: 4523139
# ###############################
# df_resultspeed_filled_mean_of_mean: 6.392745717545582
# df_resultspeed_filled_mean_of_median: 5.6
# df_resultspeed_filled_mean_of_min: 0.0
# df_resultspeed_filled_mean_of_max: 28.4
# df_resultspeed_filled_mean_of_count: 4523139
# ###############################
# df_resultspeed_filled_median_of_mean: 6.387597241662314
# df_resultspeed_filled_median_of_median: 5.5
# df_resultspeed_filled_median_of_min: 0.0
# df_resultspeed_filled_median_of_max: 28.4
# df_resultspeed_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 16. resultdir

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) resultdir 작업
df_resultdir = df['resultdir']

print('Total:', len(df_resultdir))
print('Total 정상값:', (len(df_resultdir[df_resultdir != 'M'])))
print('Total 이상값:', (len(df_resultdir[df_resultdir == 'M']) | len(df_resultdir[df_resultdir == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_resultdir) - (len(df_resultdir[df_resultdir != 'M'])) - (len(df_resultdir[df_resultdir == 'M']) + len(df_resultdir[df_resultdir == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_resultdir_n = df_resultdir.copy()
df_resultdir_n = pd.to_numeric(df_resultdir_n, errors = 'coerce')

print('Total_n:', len(df_resultdir_n) )
print('Total_n 정상값:', len(df_resultdir_n) - len(df_resultdir_n[df_resultdir_n.isnull()]))
print('Total_n 이상값:', len(df_resultdir_n[df_resultdir_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_resultdir_n) - (len(df_resultdir_n) - len(df_resultdir_n[df_resultdir_n.isnull()])) - len(df_resultdir_n[df_resultdir_n.isnull()]))
print('###############################')

#### df_resultdir_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_resultdir_n_mean = df_resultdir_n.mean(); df_resultdir_n_median = df_resultdir_n.median(); df_resultdir_n_min = df_resultdir_n.min(); 
df_resultdir_n_max = df_resultdir_n.max();   df_resultdir_n_count = len(df_resultdir_n);
print('df_resultdir_n_mean:', df_resultdir_n_mean)
print('df_resultdir_n_median:', df_resultdir_n_median) 
print('df_resultdir_n_min:', df_resultdir_n_min) 
print('df_resultdir_n_max:', df_resultdir_n_max) 
print('df_resultdir_n_count:', df_resultdir_n_count)
print('###############################')

#### df_resultdir_n에서 찾은 Mean값을 np.nan으로 대체 함
df_resultdir_filled_mean = df_resultdir_n.copy()
df_resultdir_filled_mean[df_resultdir_filled_mean.isnull()] = df_resultdir_n_mean 

df_resultdir_filled_mean_of_mean = df_resultdir_filled_mean.mean()
df_resultdir_filled_mean_of_median = df_resultdir_filled_mean.median()
df_resultdir_filled_mean_of_min = df_resultdir_filled_mean.min()
df_resultdir_filled_mean_of_max = df_resultdir_filled_mean.max()
df_resultdir_filled_mean_of_count = len(df_resultdir_filled_mean)

print('df_resultdir_filled_mean_of_mean:', df_resultdir_filled_mean_of_mean)
print('df_resultdir_filled_mean_of_median:', df_resultdir_filled_mean_of_median) 
print('df_resultdir_filled_mean_of_min:', df_resultdir_filled_mean_of_min) 
print('df_resultdir_filled_mean_of_max:', df_resultdir_filled_mean_of_max) 
print('df_resultdir_filled_mean_of_count:', df_resultdir_filled_mean_of_count)
print('###############################')

#### df_resultdir_n에서 찾은 Median값을 np.nan으로 대체 함
df_resultdir_filled_median = df_resultdir_n.copy()
df_resultdir_filled_median[df_resultdir_filled_median.isnull()] = df_resultdir_n_median

df_resultdir_filled_median_of_mean = df_resultdir_filled_median.mean()
df_resultdir_filled_median_of_median = df_resultdir_filled_median.median()
df_resultdir_filled_median_of_min = df_resultdir_filled_median.min()
df_resultdir_filled_median_of_max = df_resultdir_filled_median.max()
df_resultdir_filled_median_of_count = len(df_resultdir_filled_median)

print('df_resultdir_filled_median_of_mean:', df_resultdir_filled_median_of_mean)
print('df_resultdir_filled_median_of_median:', df_resultdir_filled_median_of_median) 
print('df_resultdir_filled_median_of_min:', df_resultdir_filled_median_of_min) 
print('df_resultdir_filled_median_of_max:', df_resultdir_filled_median_of_max) 
print('df_resultdir_filled_median_of_count:', df_resultdir_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4497054
# Total 이상값: 26085
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4497054
# Total_n 이상값: 26085
# Total_n 정상값 - 이상값: 0
# ###############################
# df_resultdir_n_mean: 18.307227131361998
# df_resultdir_n_median: 18.0
# df_resultdir_n_min: 1.0
# df_resultdir_n_max: 36.0
# df_resultdir_n_count: 4523139
# ###############################
# df_resultdir_filled_mean_of_mean: 18.30722713136665
# df_resultdir_filled_mean_of_median: 18.0
# df_resultdir_filled_mean_of_min: 1.0
# df_resultdir_filled_mean_of_max: 36.0
# df_resultdir_filled_mean_of_count: 4523139
# ###############################
# df_resultdir_filled_median_of_mean: 18.305455348597512
# df_resultdir_filled_median_of_median: 18.0
# df_resultdir_filled_median_of_min: 1.0
# df_resultdir_filled_median_of_max: 36.0
# df_resultdir_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# # 17. avgspeed

# %%
## Column 별로 Nan 값을 버린 후 => Median 계산한다.

## 먼저 1) 모든 Station 2) avgspeed 작업
df_avgspeed = df['avgspeed']

print('Total:', len(df_avgspeed))
print('Total 정상값:', (len(df_avgspeed[df_avgspeed != 'M'])))
print('Total 이상값:', (len(df_avgspeed[df_avgspeed == 'M']) | len(df_avgspeed[df_avgspeed == '  T'])))
print('Total - 정상값 - 이상값:', 
      len(df_avgspeed) - (len(df_avgspeed[df_avgspeed != 'M'])) - (len(df_avgspeed[df_avgspeed == 'M']) + len(df_avgspeed[df_avgspeed == '  T'])))
print('###############################')

### M값을 np.nan 값으로 변환

df_avgspeed_n = df_avgspeed.copy()
df_avgspeed_n = pd.to_numeric(df_avgspeed_n, errors = 'coerce')

print('Total_n:', len(df_avgspeed_n) )
print('Total_n 정상값:', len(df_avgspeed_n) - len(df_avgspeed_n[df_avgspeed_n.isnull()]))
print('Total_n 이상값:', len(df_avgspeed_n[df_avgspeed_n.isnull()]))
print('Total_n 정상값 - 이상값:', len(df_avgspeed_n) - (len(df_avgspeed_n) - len(df_avgspeed_n[df_avgspeed_n.isnull()])) - len(df_avgspeed_n[df_avgspeed_n.isnull()]))
print('###############################')

#### df_avgspeed_n 특징값 계산 (M이 빠졌으므로, n갯수에 영향이 있으므로 다를 것으로 예상됨)
df_avgspeed_n_mean = df_avgspeed_n.mean(); df_avgspeed_n_median = df_avgspeed_n.median(); df_avgspeed_n_min = df_avgspeed_n.min(); 
df_avgspeed_n_max = df_avgspeed_n.max();   df_avgspeed_n_count = len(df_avgspeed_n);
print('df_avgspeed_n_mean:', df_avgspeed_n_mean)
print('df_avgspeed_n_median:', df_avgspeed_n_median) 
print('df_avgspeed_n_min:', df_avgspeed_n_min) 
print('df_avgspeed_n_max:', df_avgspeed_n_max) 
print('df_avgspeed_n_count:', df_avgspeed_n_count)
print('###############################')

#### df_avgspeed_n에서 찾은 Mean값을 np.nan으로 대체 함
df_avgspeed_filled_mean = df_avgspeed_n.copy()
df_avgspeed_filled_mean[df_avgspeed_filled_mean.isnull()] = df_avgspeed_n_mean 

df_avgspeed_filled_mean_of_mean = df_avgspeed_filled_mean.mean()
df_avgspeed_filled_mean_of_median = df_avgspeed_filled_mean.median()
df_avgspeed_filled_mean_of_min = df_avgspeed_filled_mean.min()
df_avgspeed_filled_mean_of_max = df_avgspeed_filled_mean.max()
df_avgspeed_filled_mean_of_count = len(df_avgspeed_filled_mean)

print('df_avgspeed_filled_mean_of_mean:', df_avgspeed_filled_mean_of_mean)
print('df_avgspeed_filled_mean_of_median:', df_avgspeed_filled_mean_of_median) 
print('df_avgspeed_filled_mean_of_min:', df_avgspeed_filled_mean_of_min) 
print('df_avgspeed_filled_mean_of_max:', df_avgspeed_filled_mean_of_max) 
print('df_avgspeed_filled_mean_of_count:', df_avgspeed_filled_mean_of_count)
print('###############################')

#### df_avgspeed_n에서 찾은 Median값을 np.nan으로 대체 함
df_avgspeed_filled_median = df_avgspeed_n.copy()
df_avgspeed_filled_median[df_avgspeed_filled_median.isnull()] = df_avgspeed_n_median

df_avgspeed_filled_median_of_mean = df_avgspeed_filled_median.mean()
df_avgspeed_filled_median_of_median = df_avgspeed_filled_median.median()
df_avgspeed_filled_median_of_min = df_avgspeed_filled_median.min()
df_avgspeed_filled_median_of_max = df_avgspeed_filled_median.max()
df_avgspeed_filled_median_of_count = len(df_avgspeed_filled_median)

print('df_avgspeed_filled_median_of_mean:', df_avgspeed_filled_median_of_mean)
print('df_avgspeed_filled_median_of_median:', df_avgspeed_filled_median_of_median) 
print('df_avgspeed_filled_median_of_min:', df_avgspeed_filled_median_of_min) 
print('df_avgspeed_filled_median_of_max:', df_avgspeed_filled_median_of_max) 
print('df_avgspeed_filled_median_of_count:', df_avgspeed_filled_median_of_count)
print('###############################')
# Out:
# Total: 4523139
# Total 정상값: 4512816
# Total 이상값: 10323
# Total - 정상값 - 이상값: 0
# ###############################
# Total_n: 4523139
# Total_n 정상값: 4512816
# Total_n 이상값: 10323
# Total_n 정상값 - 이상값: 0
# ###############################
# df_avgspeed_n_mean: 8.037177784340805
# df_avgspeed_n_median: 7.3
# df_avgspeed_n_min: 0.0
# df_avgspeed_n_max: 28.7
# df_avgspeed_n_count: 4523139
# ###############################
# df_avgspeed_filled_mean_of_mean: 8.037177784336814
# df_avgspeed_filled_mean_of_median: 7.4
# df_avgspeed_filled_mean_of_min: 0.0
# df_avgspeed_filled_mean_of_max: 28.7
# df_avgspeed_filled_mean_of_count: 4523139
# ###############################
# df_avgspeed_filled_median_of_mean: 8.035495349581522
# df_avgspeed_filled_median_of_median: 7.3
# df_avgspeed_filled_median_of_min: 0.0
# df_avgspeed_filled_median_of_max: 28.7
# df_avgspeed_filled_median_of_count: 4523139
# ###############################

# %% [markdown]
# ## 결론
# ## 'M' 또는 '-' 값을 np.nan값으로 변환하여 거기에  Mean 값을 넣는 것이 특징값을 찾으면,
# ## 'M' 또는 '-' 값을 np.nan으로 변환하여 찾은 특징값과 가장 비슷하다.
# ## Median, Min, Max 값을 넣는 것은 바람직 하지 않다고 판별되었음
