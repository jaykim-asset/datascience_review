# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

data_key = pd.read_csv('key.csv')
data_key = data_key[data_key['station_nbr'] != 5]
data_weather = pd.read_csv('weather.csv')
data_weather = data_weather[data_weather['station_nbr'] != 5] ## Station 5번 제거한 나머지
data_train = pd.read_csv('train.csv')

df = pd.merge(data_weather, data_key)
station_nbr = df['station_nbr']
df.drop('station_nbr', axis=1, inplace=True)
df['station_nbr'] = station_nbr
df = pd.merge(df, data_train)
# Station 5번을 뺀 나머지 Merge 완성
# 'M'과 '-'을 np.nan으로 값을 변경하기 전에, '  T'값을 먼저 snowfall=0.05, preciptotal = 0.005로 변경하자 
df['snowfall'][df['snowfall'] == '  T'] = 0.05
df['preciptotal'][df['preciptotal'] == '  T'] = 0.005
df['snowfall'][df['snowfall'] == '  T'], df['preciptotal'][df['preciptotal'] == '  T']
# T 값 변경 완료. 이제, 19개 Station 별로 정리하기 (5번 Station 생략)
df['snowfall'][df['snowfall'] == '  T'] = 0.05
df['preciptotal'][df['preciptotal'] == '  T'] = 0.005
# T 값 변경 완료. 이제, 19개 Station 별로 정리하기 (5번 Station 생략)
df_s_1 = df[df['station_nbr'] == 1]; df_s_8 = df[df['station_nbr'] == 8]; df_s_15 = df[df['station_nbr'] == 15]
df_s_2 = df[df['station_nbr'] == 2]; df_s_9 = df[df['station_nbr'] == 9]; df_s_16 = df[df['station_nbr'] == 16]
df_s_3 = df[df['station_nbr'] == 3]; df_s_10 = df[df['station_nbr'] == 10]; df_s_17 = df[df['station_nbr'] == 17]
df_s_4 = df[df['station_nbr'] == 4]; df_s_11 = df[df['station_nbr'] == 11]; df_s_18 = df[df['station_nbr'] == 18]
df_s_5 = df[df['station_nbr'] == 5]; df_s_12 = df[df['station_nbr'] == 12]; df_s_19 = df[df['station_nbr'] == 19]
df_s_6 = df[df['station_nbr'] == 6]; df_s_13 = df[df['station_nbr'] == 13]; df_s_20 = df[df['station_nbr'] == 20]
df_s_7 = df[df['station_nbr'] == 7]; df_s_14 = df[df['station_nbr'] == 14]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# ...

# %%
# Each Station sunrise 의 M값 및 -값을 np.nan으로 변경
df_s_1_sunrise = df_s_1['sunrise'].copy(); df_s_1_sunrise = pd.to_numeric(df_s_1_sunrise, errors = 'coerce')
df_s_2_sunrise = df_s_2['sunrise'].copy(); df_s_2_sunrise = pd.to_numeric(df_s_2_sunrise, errors = 'coerce')
df_s_3_sunrise = df_s_3['sunrise'].copy(); df_s_3_sunrise = pd.to_numeric(df_s_3_sunrise, errors = 'coerce')
df_s_4_sunrise = df_s_4['sunrise'].copy(); df_s_4_sunrise = pd.to_numeric(df_s_4_sunrise, errors = 'coerce')
df_s_5_sunrise = df_s_5['sunrise'].copy(); df_s_5_sunrise = pd.to_numeric(df_s_5_sunrise, errors = 'coerce')
df_s_6_sunrise = df_s_6['sunrise'].copy(); df_s_6_sunrise = pd.to_numeric(df_s_6_sunrise, errors = 'coerce')
df_s_7_sunrise = df_s_7['sunrise'].copy(); df_s_7_sunrise = pd.to_numeric(df_s_7_sunrise, errors = 'coerce')
df_s_8_sunrise = df_s_8['sunrise'].copy(); df_s_8_sunrise = pd.to_numeric(df_s_8_sunrise, errors = 'coerce')
df_s_9_sunrise = df_s_9['sunrise'].copy(); df_s_9_sunrise = pd.to_numeric(df_s_9_sunrise, errors = 'coerce')
df_s_10_sunrise = df_s_10['sunrise'].copy(); df_s_10_sunrise = pd.to_numeric(df_s_10_sunrise, errors = 'coerce')
df_s_11_sunrise = df_s_11['sunrise'].copy(); df_s_11_sunrise = pd.to_numeric(df_s_11_sunrise, errors = 'coerce')
df_s_12_sunrise = df_s_12['sunrise'].copy(); df_s_12_sunrise = pd.to_numeric(df_s_12_sunrise, errors = 'coerce')
df_s_13_sunrise = df_s_13['sunrise'].copy(); df_s_13_sunrise = pd.to_numeric(df_s_13_sunrise, errors = 'coerce')
df_s_14_sunrise = df_s_14['sunrise'].copy(); df_s_14_sunrise = pd.to_numeric(df_s_14_sunrise, errors = 'coerce')
df_s_15_sunrise = df_s_15['sunrise'].copy(); df_s_15_sunrise = pd.to_numeric(df_s_15_sunrise, errors = 'coerce')
df_s_16_sunrise = df_s_16['sunrise'].copy(); df_s_16_sunrise = pd.to_numeric(df_s_16_sunrise, errors = 'coerce')
df_s_17_sunrise = df_s_17['sunrise'].copy(); df_s_17_sunrise = pd.to_numeric(df_s_17_sunrise, errors = 'coerce')
df_s_18_sunrise = df_s_18['sunrise'].copy(); df_s_18_sunrise = pd.to_numeric(df_s_18_sunrise, errors = 'coerce')
df_s_19_sunrise = df_s_19['sunrise'].copy(); df_s_19_sunrise = pd.to_numeric(df_s_19_sunrise, errors = 'coerce')
df_s_20_sunrise = df_s_20['sunrise'].copy(); df_s_20_sunrise = pd.to_numeric(df_s_20_sunrise, errors = 'coerce')

# 각 각의 Station의 Nan 값에, 위에서 구한 각각 station의 평균 값을 넣어서 NaN 값 뺏을 때와 비교할 것.
df_s_1_sunrise_with_mean = df_s_1_sunrise.copy(); df_s_1_sunrise_with_mean[df_s_1_sunrise_with_mean.isnull()] = df_s_1_sunrise.mean()
df_s_2_sunrise_with_mean = df_s_2_sunrise.copy(); df_s_2_sunrise_with_mean[df_s_2_sunrise_with_mean.isnull()] = df_s_2_sunrise.mean()
df_s_3_sunrise_with_mean = df_s_3_sunrise.copy(); df_s_3_sunrise_with_mean[df_s_3_sunrise_with_mean.isnull()] = df_s_3_sunrise.mean()
df_s_4_sunrise_with_mean = df_s_4_sunrise.copy(); df_s_4_sunrise_with_mean[df_s_4_sunrise_with_mean.isnull()] = df_s_4_sunrise.mean()
df_s_5_sunrise_with_mean = df_s_5_sunrise.copy(); df_s_5_sunrise_with_mean[df_s_5_sunrise_with_mean.isnull()] = df_s_5_sunrise.mean()
df_s_6_sunrise_with_mean = df_s_6_sunrise.copy(); df_s_6_sunrise_with_mean[df_s_6_sunrise_with_mean.isnull()] = df_s_6_sunrise.mean()
df_s_7_sunrise_with_mean = df_s_7_sunrise.copy(); df_s_7_sunrise_with_mean[df_s_7_sunrise_with_mean.isnull()] = df_s_7_sunrise.mean()
df_s_8_sunrise_with_mean = df_s_8_sunrise.copy(); df_s_8_sunrise_with_mean[df_s_8_sunrise_with_mean.isnull()] = df_s_8_sunrise.mean()
df_s_9_sunrise_with_mean = df_s_9_sunrise.copy(); df_s_9_sunrise_with_mean[df_s_9_sunrise_with_mean.isnull()] = df_s_9_sunrise.mean()
df_s_10_sunrise_with_mean = df_s_10_sunrise.copy(); df_s_10_sunrise_with_mean[df_s_10_sunrise_with_mean.isnull()] = df_s_10_sunrise.mean()
df_s_11_sunrise_with_mean = df_s_11_sunrise.copy(); df_s_11_sunrise_with_mean[df_s_11_sunrise_with_mean.isnull()] = df_s_11_sunrise.mean()
df_s_12_sunrise_with_mean = df_s_12_sunrise.copy(); df_s_12_sunrise_with_mean[df_s_12_sunrise_with_mean.isnull()] = df_s_12_sunrise.mean()
df_s_13_sunrise_with_mean = df_s_13_sunrise.copy(); df_s_13_sunrise_with_mean[df_s_13_sunrise_with_mean.isnull()] = df_s_13_sunrise.mean()
df_s_14_sunrise_with_mean = df_s_14_sunrise.copy(); df_s_14_sunrise_with_mean[df_s_14_sunrise_with_mean.isnull()] = df_s_14_sunrise.mean()
df_s_15_sunrise_with_mean = df_s_15_sunrise.copy(); df_s_15_sunrise_with_mean[df_s_15_sunrise_with_mean.isnull()] = df_s_15_sunrise.mean()
df_s_16_sunrise_with_mean = df_s_16_sunrise.copy(); df_s_16_sunrise_with_mean[df_s_16_sunrise_with_mean.isnull()] = df_s_16_sunrise.mean()
df_s_17_sunrise_with_mean = df_s_17_sunrise.copy(); df_s_17_sunrise_with_mean[df_s_17_sunrise_with_mean.isnull()] = df_s_17_sunrise.mean()
df_s_18_sunrise_with_mean = df_s_18_sunrise.copy(); df_s_18_sunrise_with_mean[df_s_18_sunrise_with_mean.isnull()] = df_s_18_sunrise.mean()
df_s_19_sunrise_with_mean = df_s_19_sunrise.copy(); df_s_19_sunrise_with_mean[df_s_19_sunrise_with_mean.isnull()] = df_s_19_sunrise.mean()
df_s_20_sunrise_with_mean = df_s_20_sunrise.copy(); df_s_20_sunrise_with_mean[df_s_20_sunrise_with_mean.isnull()] = df_s_20_sunrise.mean()

# 각 각의 Station 별로 sunrise의 값이 np.nan일 때, 즉, missing value를 뺏을 때의 전체 mean 값을 나타낸다. 
print('#station1_without_nan_mean:', round(df_s_1_sunrise.mean(),4), '#station1_without_nan_std:', round(df_s_1_sunrise.std(),4)); 
print('#station2_without_nan_mean:', round(df_s_2_sunrise.mean(),4), '#station2_without_nan_std:', round(df_s_2_sunrise.std(),4)); 
print('#station3_without_nan_mean:', round(df_s_3_sunrise.mean(),4), '#station3_without_nan_std:', round(df_s_3_sunrise.std(),4)); 
print('#station4_without_nan_mean:', round(df_s_4_sunrise.mean(),4), '#station4_without_nan_std:', round(df_s_4_sunrise.std(),4)); 
print('#station5_without_nan_mean:', round(df_s_5_sunrise.mean(),4), '#station5_without_nan_std:', round(df_s_5_sunrise.std(),4)); 
print('#station6_without_nan_mean:', round(df_s_6_sunrise.mean(),4), '#station6_without_nan_std:', round(df_s_6_sunrise.std(),4)); 
print('#station7_without_nan_mean:', round(df_s_7_sunrise.mean(),4), '#station7_without_nan_std:', round(df_s_7_sunrise.std(),4)); 
print('#station8_without_nan_mean:', round(df_s_8_sunrise.mean(),4), '#station8_without_nan_std:', round(df_s_8_sunrise.std(),4)); 
print('#station9_without_nan_mean:', round(df_s_9_sunrise.mean(),4), '#station9_without_nan_std:', round(df_s_9_sunrise.std(),4)); 
print('#station10_without_nan_mean:', round(df_s_10_sunrise.mean(),4), '#station10_without_nan_std:', round(df_s_10_sunrise.std(),4));  
print('#station11_without_nan_mean:', round(df_s_11_sunrise.mean(),4), '#station11_without_nan_std:', round(df_s_11_sunrise.std(),4)); 
print('#station12_without_nan_mean:', round(df_s_12_sunrise.mean(),4), '#station12_without_nan_std:', round(df_s_12_sunrise.std(),4)); 
print('#station13_without_nan_mean:', round(df_s_13_sunrise.mean(),4), '#station13_without_nan_std:', round(df_s_13_sunrise.std(),4)); 
print('#station14_without_nan_mean:', round(df_s_14_sunrise.mean(),4), '#station14_without_nan_std:', round(df_s_14_sunrise.std(),4)); 
print('#station15_without_nan_mean:', round(df_s_15_sunrise.mean(),4), '#station15_without_nan_std:', round(df_s_15_sunrise.std(),4)); 
print('#station16_without_nan_mean:', round(df_s_16_sunrise.mean(),4), '#station16_without_nan_std:', round(df_s_16_sunrise.std(),4)); 
print('#station17_without_nan_mean:', round(df_s_17_sunrise.mean(),4), '#station17_without_nan_std:', round(df_s_17_sunrise.std(),4)); 
print('#station18_without_nan_mean:', round(df_s_18_sunrise.mean(),4), '#station18_without_nan_std:', round(df_s_18_sunrise.std(),4)); 
print('#station19_without_nan_mean:', round(df_s_19_sunrise.mean(),4), '#station19_without_nan_std:', round(df_s_19_sunrise.std(),4)); 
print('#station20_without_nan_mean:', round(df_s_20_sunrise.mean(),4), '#station20_without_nan_std:', round(df_s_20_sunrise.std(),4)); 

print('stat1_nan_as_mean:',round(df_s_1_sunrise_with_mean.mean(),4),'#stat1_nan_as_std:', round(df_s_1_sunrise_with_mean.std(),4));
print('stat2_nan_as_mean:',round(df_s_2_sunrise_with_mean.mean(),4),'#stat2_nan_as_std:', round(df_s_2_sunrise_with_mean.std(),4));
print('stat3_nan_as_mean:',round(df_s_3_sunrise_with_mean.mean(),4),'#stat3_nan_as_std:', round(df_s_3_sunrise_with_mean.std(),4));
print('stat4_nan_as_mean:',round(df_s_4_sunrise_with_mean.mean(),4),'#stat4_nan_as_std:', round(df_s_4_sunrise_with_mean.std(),4));
print('stat5_nan_as_mean:',round(df_s_5_sunrise_with_mean.mean(),4),'#stat5_nan_as_std:', round(df_s_5_sunrise_with_mean.std(),4));
print('stat6_nan_as_mean:',round(df_s_6_sunrise_with_mean.mean(),4),'#stat6_nan_as_std:', round(df_s_6_sunrise_with_mean.std(),4));
print('stat7_nan_as_mean:',round(df_s_7_sunrise_with_mean.mean(),4),'#stat7_nan_as_std:', round(df_s_7_sunrise_with_mean.std(),4));
print('stat8_nan_as_mean:',round(df_s_8_sunrise_with_mean.mean(),4),'#stat8_nan_as_std:', round(df_s_8_sunrise_with_mean.std(),4));
print('stat9_nan_as_mean:',round(df_s_9_sunrise_with_mean.mean(),4),'#stat9_nan_as_std:', round(df_s_9_sunrise_with_mean.std(),4));
print('stat10_nan_as_mean:',round(df_s_10_sunrise_with_mean.mean(),4),'#stat10_nan_as_std:', round(df_s_10_sunrise_with_mean.std(),4));
print('stat11_nan_as_mean:',round(df_s_11_sunrise_with_mean.mean(),4),'#stat11_nan_as_std:', round(df_s_11_sunrise_with_mean.std(),4));
print('stat12_nan_as_mean:',round(df_s_12_sunrise_with_mean.mean(),4),'#stat12_nan_as_std:', round(df_s_12_sunrise_with_mean.std(),4));
print('stat13_nan_as_mean:',round(df_s_13_sunrise_with_mean.mean(),4),'#stat13_nan_as_std:', round(df_s_13_sunrise_with_mean.std(),4));
print('stat14_nan_as_mean:',round(df_s_14_sunrise_with_mean.mean(),4),'#stat14_nan_as_std:', round(df_s_14_sunrise_with_mean.std(),4));
print('stat15_nan_as_mean:',round(df_s_15_sunrise_with_mean.mean(),4),'#stat15_nan_as_std:', round(df_s_15_sunrise_with_mean.std(),4));
print('stat16_nan_as_mean:',round(df_s_16_sunrise_with_mean.mean(),4),'#stat16_nan_as_std:', round(df_s_16_sunrise_with_mean.std(),4));
print('stat17_nan_as_mean:',round(df_s_17_sunrise_with_mean.mean(),4),'#stat17_nan_as_std:', round(df_s_17_sunrise_with_mean.std(),4));
print('stat18_nan_as_mean:',round(df_s_18_sunrise_with_mean.mean(),4),'#stat18_nan_as_std:', round(df_s_18_sunrise_with_mean.std(),4));
print('stat19_nan_as_mean:',round(df_s_19_sunrise_with_mean.mean(),4),'#stat19_nan_as_std:', round(df_s_19_sunrise_with_mean.std(),4));
print('stat20_nan_as_mean:',round(df_s_20_sunrise_with_mean.mean(),4),'#stat20_nan_as_std:', round(df_s_20_sunrise_with_mean.std(),4));
# Out:
# #station1_without_nan_mean: nan #station1_without_nan_std: nan
# #station2_without_nan_mean: 539.2869 #station2_without_nan_std: 101.6747
# #station3_without_nan_mean: 605.4169 #station3_without_nan_std: 80.0553
# #station4_without_nan_mean: 619.2025 #station4_without_nan_std: 68.9326
# #station5_without_nan_mean: nan #station5_without_nan_std: nan
# #station6_without_nan_mean: 619.3263 #station6_without_nan_std: 69.1122
# #station7_without_nan_mean: nan #station7_without_nan_std: nan
# #station8_without_nan_mean: nan #station8_without_nan_std: nan
# #station9_without_nan_mean: nan #station9_without_nan_std: nan
# #station10_without_nan_mean: 611.2856 #station10_without_nan_std: 67.8115
# #station11_without_nan_mean: 612.7709 #station11_without_nan_std: 68.6983
# #station12_without_nan_mean: nan #station12_without_nan_std: nan
# #station13_without_nan_mean: nan #station13_without_nan_std: nan
# #station14_without_nan_mean: 622.1588 #station14_without_nan_std: 77.1503
# ...

# %%
y1 = np.array([df_s_1_sunrise.mean(), df_s_2_sunrise.mean(), df_s_3_sunrise.mean(), df_s_4_sunrise.mean(), df_s_5_sunrise.mean(),
             df_s_6_sunrise.mean(), df_s_7_sunrise.mean(), df_s_8_sunrise.mean(), df_s_9_sunrise.mean(), df_s_10_sunrise.mean(), 
             df_s_11_sunrise.mean(), df_s_12_sunrise.mean(), df_s_13_sunrise.mean(), df_s_14_sunrise.mean(), df_s_15_sunrise.mean(),
             df_s_16_sunrise.mean(), df_s_17_sunrise.mean(), df_s_18_sunrise.mean(), df_s_19_sunrise.mean(), df_s_20_sunrise.mean()])

y2 = np.array([df_s_1_sunrise_with_mean.mean(), df_s_2_sunrise_with_mean.mean(), df_s_3_sunrise_with_mean.mean(), df_s_4_sunrise_with_mean.mean()
             ,df_s_5_sunrise_with_mean.mean(), df_s_6_sunrise_with_mean.mean(), df_s_7_sunrise_with_mean.mean(), df_s_8_sunrise_with_mean.mean()
             ,df_s_9_sunrise_with_mean.mean(), df_s_10_sunrise_with_mean.mean(), df_s_11_sunrise_with_mean.mean(), df_s_12_sunrise_with_mean.mean()
             ,df_s_13_sunrise_with_mean.mean(), df_s_14_sunrise_with_mean.mean(), df_s_15_sunrise_with_mean.mean(), df_s_16_sunrise_with_mean.mean()
             ,df_s_17_sunrise_with_mean.mean(),df_s_18_sunrise_with_mean.mean(),df_s_19_sunrise_with_mean.mean(),df_s_20_sunrise_with_mean.mean()])

plt.figure(figsize=(10,5))
plt.plot()
x = range(1, 21)
plt.xlabel('Station Number')
plt.ylabel('sunrise')
plt.bar(x, y1, color='y')
plt.bar(x, y2, color='r')
plt.show()

#### sunrise 에서는
# 이 Graph가 나타내는 바는, y1과 y2가 차이가 거의 없다는 것. 그래프에는 r color와 y color이 있는데, 하나만 보인다는 것은
# 우리가 그래프에서 눈으로 보이지 않는 정도의 차이가 나온다는 것이다, 즉 차이가 극히 작다고 판단 할 수 있다.
# Missing Values를 np.nan으로 바꾸고, 거기서 Mean 값을 구하여 np.nan에 대입하여도, 
# 따라서, 여기서는 Missing Value에 Mean값을 적용하여 회귀 분석에 적용 할 수있다고 판단된다. 
plt.figure(figsize=(12,6))
xticks = range(1,21)
plt.plot(xticks, y1, 'ro-', label='stations_without_nan_mean')
plt.plot(xticks, y2, 'bd:', label='stations_nan_as_mean')
plt.legend(loc=0)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
