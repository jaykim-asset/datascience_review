# %%
data_weather = pd.read_csv('weather3_180703.csv')
data_test = pd.read_csv('test.csv')
data_sample = pd.read_csv('sampleSubmission.csv')
data_train = pd.read_csv('train.csv')

# %%
print('data_weather length:', len(data_weather))
print('data_test length:', len(data_test))
print('data_train length:', len(data_train))
# Out:
# data_weather length: 20517
# data_test length: 526917
# data_train length: 4617600

# %%
weather = data_weather[(data_weather['date'] >= '2013-04-01') & (data_weather['date'] <= '2014-10-26')]

# %%
print('weather length:', len(weather))
# Out:
# weather length: 11449

# %%
test = pd.merge(weather, data_test, )

# %%
test1 = pd.concat([weather, data_test], axis=1, join='inner')

# %%
len(test1)
# Out:
# 11449

# %%
test2 = pd.concat([weather, data_test], join='outer')

# %%
test3 = weather.merge(data_test, left_on="date", right_on="date")

# %%
len(test3)
# Out:
# 10510035

# %%
weather1 = weather.copy()

# %%
weather1['date'] = pd.to_datetime(weather['date'])

# %%
weather1['date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
test1 = test.copy()

# %%
test1['date'] = pd.to_datetime(test1['date'])

# %%
test5 = pd.merge([weather, data_test], left_on = 'date', right_on = 'date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-eeb1adcd2d13> in <module>()
# ----> 1 test5 = pd.merge([weather, data_test], left_on = 'date', right_on = 'date')
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
test4 = pd.merge(test1, weather1)

# %%
test4.head()
# Out:
#           station_nbr       date  tmax  tmin  tavg  depart  dewpoint  wetbulb  \
# 0                   1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# 1                   1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# 2                   1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# 3                   1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# 4                   1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# 5                   1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# 6                   1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# 7                   1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# 8                   1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# 9                   1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# 10                  1 2013-04-01  62.0  35.0  48.5     NaN      32.0     41.0
# ...

# %%
test5 = pd.merge([weather, data_test], left_on = 'date', right_on='date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-e6ab40023c32> in <module>()
# ----> 1 test5 = pd.merge([weather, data_test], left_on = 'date', right_on='date')
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
weather.merge(data_test, left_on='date', right_on='date', how='inner')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     667
#     668             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 669                                 show_dimensions=show_dimensions, notebook=True)
#     670         else:
#     671             return None
#
# ...
