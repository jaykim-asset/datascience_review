# %%
data_key = pd.read_csv('key.csv')
data_key = data_key[data_key['station_nbr'] != 5]
data_weather = pd.read_csv('weather.csv')
data_weather = data_weather[data_weather['station_nbr'] != 5] ## Station 5번 제거한 나머지
data_train = pd.read_csv('train.csv')

df = pd.merge(data_weather, data_key)
station_nbr = df['station_nbr']
df.drop('station_nbr', axis=1, inplace=True)
df['station_nbr'] = station_nbr
df = pd.merge(df, data_train)
df # Station 5번을 뺀 나머지 Merge 완성
# Out:
#                date tmax tmin tavg depart dewpoint wetbulb heat cool sunrise  \
# 0        2012-01-01   52   31   42      M       36      40   23    0       -
# 1        2012-01-01   52   31   42      M       36      40   23    0       -
# 2        2012-01-01   52   31   42      M       36      40   23    0       -
# 3        2012-01-01   52   31   42      M       36      40   23    0       -
# 4        2012-01-01   52   31   42      M       36      40   23    0       -
# 5        2012-01-01   52   31   42      M       36      40   23    0       -
# 6        2012-01-01   52   31   42      M       36      40   23    0       -
# 7        2012-01-01   52   31   42      M       36      40   23    0       -
# 8        2012-01-01   52   31   42      M       36      40   23    0       -
# 9        2012-01-01   52   31   42      M       36      40   23    0       -
# 10       2012-01-01   52   31   42      M       36      40   23    0       -
# ...

# %%
# 'M'과 '-'을 np.nan으로 값을 변경하기 전에, '  T'값을 먼저 snowfall=0.05, preciptotal = 0.005로 변경하자 
df['snowfall'][df['snowfall'] == '  T'] = 0.05
df['preciptotal'][df['preciptotal'] == '  T'] = 0.005

df['snowfall'][df['snowfall'] == '  T'], df['preciptotal'][df['preciptotal'] == '  T']
# T 값 변경 완료. 이제, 19개 Station 별로 정리하기 (5번 Station 생략)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# (Series([], Name: snowfall, dtype: object),
#  Series([], Name: preciptotal, dtype: object))

# %%
df_s_1 = df[df['station_nbr'] == 1]; df_s_8 = df[df['station_nbr'] == 8]; df_s_15 = df[df['station_nbr'] == 15]
df_s_2 = df[df['station_nbr'] == 2]; df_s_9 = df[df['station_nbr'] == 9]; df_s_16 = df[df['station_nbr'] == 16]
df_s_3 = df[df['station_nbr'] == 3]; df_s_10 = df[df['station_nbr'] == 10]; df_s_17 = df[df['station_nbr'] == 17]
df_s_4 = df[df['station_nbr'] == 4]; df_s_11 = df[df['station_nbr'] == 11]; df_s_18 = df[df['station_nbr'] == 18]
df_s_5 = df[df['station_nbr'] == 5]; df_s_12 = df[df['station_nbr'] == 12]; df_s_19 = df[df['station_nbr'] == 19]
df_s_6 = df[df['station_nbr'] == 6]; df_s_13 = df[df['station_nbr'] == 13]; df_s_20 = df[df['station_nbr'] == 20]
df_s_7 = df[df['station_nbr'] == 7]; df_s_14 = df[df['station_nbr'] == 14]

# %% [markdown]
# # Station

# %% [markdown]
# ### Station _Tmax

# %%
# Each Station Tmax 의 M값을 np.nan으로 변경
df_s_1_tmax = df_s_1['tmax'].copy(); df_s_1_tmax = pd.to_numeric(df_s_1_tmax, errors = 'coerce')
df_s_2_tmax = df_s_2['tmax'].copy(); df_s_2_tmax = pd.to_numeric(df_s_2_tmax, errors = 'coerce')
df_s_3_tmax = df_s_3['tmax'].copy(); df_s_3_tmax = pd.to_numeric(df_s_3_tmax, errors = 'coerce')
df_s_4_tmax = df_s_4['tmax'].copy(); df_s_4_tmax = pd.to_numeric(df_s_4_tmax, errors = 'coerce')
df_s_5_tmax = df_s_5['tmax'].copy(); df_s_5_tmax = pd.to_numeric(df_s_5_tmax, errors = 'coerce')
df_s_6_tmax = df_s_6['tmax'].copy(); df_s_6_tmax = pd.to_numeric(df_s_6_tmax, errors = 'coerce')
df_s_7_tmax = df_s_7['tmax'].copy(); df_s_7_tmax = pd.to_numeric(df_s_7_tmax, errors = 'coerce')
df_s_8_tmax = df_s_8['tmax'].copy(); df_s_8_tmax = pd.to_numeric(df_s_8_tmax, errors = 'coerce')
df_s_9_tmax = df_s_9['tmax'].copy(); df_s_9_tmax = pd.to_numeric(df_s_9_tmax, errors = 'coerce')
df_s_10_tmax = df_s_10['tmax'].copy(); df_s_10_tmax = pd.to_numeric(df_s_10_tmax, errors = 'coerce')
df_s_11_tmax = df_s_11['tmax'].copy(); df_s_11_tmax = pd.to_numeric(df_s_11_tmax, errors = 'coerce')
df_s_12_tmax = df_s_12['tmax'].copy(); df_s_12_tmax = pd.to_numeric(df_s_12_tmax, errors = 'coerce')
df_s_13_tmax = df_s_13['tmax'].copy(); df_s_13_tmax = pd.to_numeric(df_s_13_tmax, errors = 'coerce')
df_s_14_tmax = df_s_14['tmax'].copy(); df_s_14_tmax = pd.to_numeric(df_s_14_tmax, errors = 'coerce')
df_s_15_tmax = df_s_15['tmax'].copy(); df_s_15_tmax = pd.to_numeric(df_s_15_tmax, errors = 'coerce')
df_s_16_tmax = df_s_16['tmax'].copy(); df_s_16_tmax = pd.to_numeric(df_s_16_tmax, errors = 'coerce')
df_s_17_tmax = df_s_17['tmax'].copy(); df_s_17_tmax = pd.to_numeric(df_s_17_tmax, errors = 'coerce')
df_s_18_tmax = df_s_18['tmax'].copy(); df_s_18_tmax = pd.to_numeric(df_s_18_tmax, errors = 'coerce')
df_s_19_tmax = df_s_19['tmax'].copy(); df_s_19_tmax = pd.to_numeric(df_s_19_tmax, errors = 'coerce')
df_s_20_tmax = df_s_20['tmax'].copy(); df_s_20_tmax = pd.to_numeric(df_s_20_tmax, errors = 'coerce')

# 각 각의 Station의 Nan 값에, 위에서 구한 각각 station의 평균 값을 넣어서 NaN 값 뺏을 때와 비교할 것.
df_s_1_tmax_with_mean = df_s_1_tmax.copy(); df_s_1_tmax_with_mean[df_s_1_tmax_with_mean.isnull()] = df_s_1_tmax.mean()
df_s_2_tmax_with_mean = df_s_2_tmax.copy(); df_s_2_tmax_with_mean[df_s_2_tmax_with_mean.isnull()] = df_s_2_tmax.mean()
df_s_3_tmax_with_mean = df_s_3_tmax.copy(); df_s_3_tmax_with_mean[df_s_3_tmax_with_mean.isnull()] = df_s_3_tmax.mean()
df_s_4_tmax_with_mean = df_s_4_tmax.copy(); df_s_4_tmax_with_mean[df_s_4_tmax_with_mean.isnull()] = df_s_4_tmax.mean()
df_s_5_tmax_with_mean = df_s_5_tmax.copy(); df_s_5_tmax_with_mean[df_s_5_tmax_with_mean.isnull()] = df_s_5_tmax.mean()
df_s_6_tmax_with_mean = df_s_6_tmax.copy(); df_s_6_tmax_with_mean[df_s_6_tmax_with_mean.isnull()] = df_s_6_tmax.mean()
df_s_7_tmax_with_mean = df_s_7_tmax.copy(); df_s_7_tmax_with_mean[df_s_7_tmax_with_mean.isnull()] = df_s_7_tmax.mean()
df_s_8_tmax_with_mean = df_s_8_tmax.copy(); df_s_8_tmax_with_mean[df_s_8_tmax_with_mean.isnull()] = df_s_8_tmax.mean()
df_s_9_tmax_with_mean = df_s_9_tmax.copy(); df_s_9_tmax_with_mean[df_s_9_tmax_with_mean.isnull()] = df_s_9_tmax.mean()
df_s_10_tmax_with_mean = df_s_10_tmax.copy(); df_s_10_tmax_with_mean[df_s_10_tmax_with_mean.isnull()] = df_s_10_tmax.mean()
df_s_11_tmax_with_mean = df_s_11_tmax.copy(); df_s_11_tmax_with_mean[df_s_11_tmax_with_mean.isnull()] = df_s_11_tmax.mean()
df_s_12_tmax_with_mean = df_s_12_tmax.copy(); df_s_12_tmax_with_mean[df_s_12_tmax_with_mean.isnull()] = df_s_12_tmax.mean()
df_s_13_tmax_with_mean = df_s_13_tmax.copy(); df_s_13_tmax_with_mean[df_s_13_tmax_with_mean.isnull()] = df_s_13_tmax.mean()
df_s_14_tmax_with_mean = df_s_14_tmax.copy(); df_s_14_tmax_with_mean[df_s_14_tmax_with_mean.isnull()] = df_s_14_tmax.mean()
df_s_15_tmax_with_mean = df_s_15_tmax.copy(); df_s_15_tmax_with_mean[df_s_15_tmax_with_mean.isnull()] = df_s_15_tmax.mean()
df_s_16_tmax_with_mean = df_s_16_tmax.copy(); df_s_16_tmax_with_mean[df_s_16_tmax_with_mean.isnull()] = df_s_16_tmax.mean()
df_s_17_tmax_with_mean = df_s_17_tmax.copy(); df_s_17_tmax_with_mean[df_s_17_tmax_with_mean.isnull()] = df_s_17_tmax.mean()
df_s_18_tmax_with_mean = df_s_18_tmax.copy(); df_s_18_tmax_with_mean[df_s_18_tmax_with_mean.isnull()] = df_s_18_tmax.mean()
df_s_19_tmax_with_mean = df_s_19_tmax.copy(); df_s_19_tmax_with_mean[df_s_19_tmax_with_mean.isnull()] = df_s_19_tmax.mean()
df_s_20_tmax_with_mean = df_s_20_tmax.copy(); df_s_20_tmax_with_mean[df_s_20_tmax_with_mean.isnull()] = df_s_20_tmax.mean()

# %%
# 각 각의 Station 별로 tmax의 값이 np.nan일 때, 즉, missing value를 뺏을 때의 전체 mean 값을 나타낸다. 
print('#station1_without_nan_mean:', round(df_s_1_tmax.mean(),4), '#station1_without_nan_std:', round(df_s_1_tmax.std(),4)); 
print('#station2_without_nan_mean:', round(df_s_2_tmax.mean(),4), '#station2_without_nan_std:', round(df_s_2_tmax.std(),4)); 
print('#station3_without_nan_mean:', round(df_s_3_tmax.mean(),4), '#station3_without_nan_std:', round(df_s_3_tmax.std(),4)); 
print('#station4_without_nan_mean:', round(df_s_4_tmax.mean(),4), '#station4_without_nan_std:', round(df_s_4_tmax.std(),4)); 
print('#station5_without_nan_mean:', round(df_s_5_tmax.mean(),4), '#station5_without_nan_std:', round(df_s_5_tmax.std(),4)); 
print('#station6_without_nan_mean:', round(df_s_6_tmax.mean(),4), '#station6_without_nan_std:', round(df_s_6_tmax.std(),4)); 
print('#station7_without_nan_mean:', round(df_s_7_tmax.mean(),4), '#station7_without_nan_std:', round(df_s_7_tmax.std(),4)); 
print('#station8_without_nan_mean:', round(df_s_8_tmax.mean(),4), '#station8_without_nan_std:', round(df_s_8_tmax.std(),4)); 
print('#station9_without_nan_mean:', round(df_s_9_tmax.mean(),4), '#station9_without_nan_std:', round(df_s_9_tmax.std(),4)); 
print('#station10_without_nan_mean:', round(df_s_10_tmax.mean(),4), '#station10_without_nan_std:', round(df_s_10_tmax.std(),4));  
print('#station11_without_nan_mean:', round(df_s_11_tmax.mean(),4), '#station11_without_nan_std:', round(df_s_11_tmax.std(),4)); 
print('#station12_without_nan_mean:', round(df_s_12_tmax.mean(),4), '#station12_without_nan_std:', round(df_s_12_tmax.std(),4)); 
print('#station13_without_nan_mean:', round(df_s_13_tmax.mean(),4), '#station13_without_nan_std:', round(df_s_13_tmax.std(),4)); 
print('#station14_without_nan_mean:', round(df_s_14_tmax.mean(),4), '#station14_without_nan_std:', round(df_s_14_tmax.std(),4)); 
print('#station15_without_nan_mean:', round(df_s_15_tmax.mean(),4), '#station15_without_nan_std:', round(df_s_15_tmax.std(),4)); 
print('#station16_without_nan_mean:', round(df_s_16_tmax.mean(),4), '#station16_without_nan_std:', round(df_s_16_tmax.std(),4)); 
print('#station17_without_nan_mean:', round(df_s_17_tmax.mean(),4), '#station17_without_nan_std:', round(df_s_17_tmax.std(),4)); 
print('#station18_without_nan_mean:', round(df_s_18_tmax.mean(),4), '#station18_without_nan_std:', round(df_s_18_tmax.std(),4)); 
print('#station19_without_nan_mean:', round(df_s_19_tmax.mean(),4), '#station19_without_nan_std:', round(df_s_19_tmax.std(),4)); 
print('#station20_without_nan_mean:', round(df_s_20_tmax.mean(),4), '#station20_without_nan_std:', round(df_s_20_tmax.std(),4));
# Out:
# #station1_without_nan_mean: 60.6419 #station1_without_nan_std: 18.9759
# #station2_without_nan_mean: 58.3353 #station2_without_nan_std: 18.4264
# #station3_without_nan_mean: 73.4178 #station3_without_nan_std: 18.3567
# #station4_without_nan_mean: 82.1449 #station4_without_nan_std: 14.9476
# #station5_without_nan_mean: nan #station5_without_nan_std: nan
# #station6_without_nan_mean: 81.2576 #station6_without_nan_std: 14.917
# #station7_without_nan_mean: 72.9896 #station7_without_nan_std: 18.897
# #station8_without_nan_mean: 81.2239 #station8_without_nan_std: 14.2313
# #station9_without_nan_mean: 55.3134 #station9_without_nan_std: 24.3126
# #station10_without_nan_mean: 81.3396 #station10_without_nan_std: 11.0606
# #station11_without_nan_mean: 80.0418 #station11_without_nan_std: 10.788
# #station12_without_nan_mean: 80.0699 #station12_without_nan_std: 10.7348
# #station13_without_nan_mean: 64.9713 #station13_without_nan_std: 19.3347
# ...

# %%
print('stat1_nan_as_mean:',round(df_s_1_tmax_with_mean.mean(),4),'#stat1_nan_as_std:', round(df_s_1_tmax_with_mean.std(),4));
print('stat2_nan_as_mean:',round(df_s_2_tmax_with_mean.mean(),4),'#stat2_nan_as_std:', round(df_s_2_tmax_with_mean.std(),4));
print('stat3_nan_as_mean:',round(df_s_3_tmax_with_mean.mean(),4),'#stat3_nan_as_std:', round(df_s_3_tmax_with_mean.std(),4));
print('stat4_nan_as_mean:',round(df_s_4_tmax_with_mean.mean(),4),'#stat4_nan_as_std:', round(df_s_4_tmax_with_mean.std(),4));
print('stat5_nan_as_mean:',round(df_s_5_tmax_with_mean.mean(),4),'#stat5_nan_as_std:', round(df_s_5_tmax_with_mean.std(),4));
print('stat6_nan_as_mean:',round(df_s_6_tmax_with_mean.mean(),4),'#stat6_nan_as_std:', round(df_s_6_tmax_with_mean.std(),4));
print('stat7_nan_as_mean:',round(df_s_7_tmax_with_mean.mean(),4),'#stat7_nan_as_std:', round(df_s_7_tmax_with_mean.std(),4));
print('stat8_nan_as_mean:',round(df_s_8_tmax_with_mean.mean(),4),'#stat8_nan_as_std:', round(df_s_8_tmax_with_mean.std(),4));
print('stat9_nan_as_mean:',round(df_s_9_tmax_with_mean.mean(),4),'#stat9_nan_as_std:', round(df_s_9_tmax_with_mean.std(),4));
print('stat10_nan_as_mean:',round(df_s_10_tmax_with_mean.mean(),4),'#stat10_nan_as_std:', round(df_s_10_tmax_with_mean.std(),4));
print('stat11_nan_as_mean:',round(df_s_11_tmax_with_mean.mean(),4),'#stat11_nan_as_std:', round(df_s_11_tmax_with_mean.std(),4));
print('stat12_nan_as_mean:',round(df_s_12_tmax_with_mean.mean(),4),'#stat12_nan_as_std:', round(df_s_12_tmax_with_mean.std(),4));
print('stat13_nan_as_mean:',round(df_s_13_tmax_with_mean.mean(),4),'#stat13_nan_as_std:', round(df_s_13_tmax_with_mean.std(),4));
print('stat14_nan_as_mean:',round(df_s_14_tmax_with_mean.mean(),4),'#stat14_nan_as_std:', round(df_s_14_tmax_with_mean.std(),4));
print('stat15_nan_as_mean:',round(df_s_15_tmax_with_mean.mean(),4),'#stat15_nan_as_std:', round(df_s_15_tmax_with_mean.std(),4));
print('stat16_nan_as_mean:',round(df_s_16_tmax_with_mean.mean(),4),'#stat16_nan_as_std:', round(df_s_16_tmax_with_mean.std(),4));
print('stat17_nan_as_mean:',round(df_s_17_tmax_with_mean.mean(),4),'#stat17_nan_as_std:', round(df_s_17_tmax_with_mean.std(),4));
print('stat18_nan_as_mean:',round(df_s_18_tmax_with_mean.mean(),4),'#stat18_nan_as_std:', round(df_s_18_tmax_with_mean.std(),4));
print('stat19_nan_as_mean:',round(df_s_19_tmax_with_mean.mean(),4),'#stat19_nan_as_std:', round(df_s_19_tmax_with_mean.std(),4));
print('stat20_nan_as_mean:',round(df_s_20_tmax_with_mean.mean(),4),'#stat20_nan_as_std:', round(df_s_20_tmax_with_mean.std(),4));
# Out:
# stat1_nan_as_mean: 60.6419 #stat1_nan_as_std: 18.9555
# stat2_nan_as_mean: 58.3353 #stat2_nan_as_std: 18.4157
# stat3_nan_as_mean: 73.4178 #stat3_nan_as_std: 18.3366
# stat4_nan_as_mean: 82.1449 #stat4_nan_as_std: 14.9314
# stat5_nan_as_mean: nan #stat5_nan_as_std: nan
# stat6_nan_as_mean: 81.2576 #stat6_nan_as_std: 14.9009
# stat7_nan_as_mean: 72.9896 #stat7_nan_as_std: 18.5458
# stat8_nan_as_mean: 81.2239 #stat8_nan_as_std: 14.1295
# stat9_nan_as_mean: 55.3134 #stat9_nan_as_std: 24.2365
# stat10_nan_as_mean: 81.3396 #stat10_nan_as_std: 11.0606
# stat11_nan_as_mean: 80.0418 #stat11_nan_as_std: 10.7821
# stat12_nan_as_mean: 80.0699 #stat12_nan_as_std: 10.7287
# stat13_nan_as_mean: 64.9713 #stat13_nan_as_std: 19.3251
# stat14_nan_as_mean: 73.5647 #stat14_nan_as_std: 18.1573
# stat15_nan_as_mean: 60.4287 #stat15_nan_as_std: 19.5737
# stat16_nan_as_mean: 59.7738 #stat16_nan_as_std: 17.8969
# stat17_nan_as_mean: 73.4884 #stat17_nan_as_std: 18.7995
# ...

# %%
# 위 두개의 평균 값에 대한 차이값을 알아보자 

# 여기는, d
# %matplotlib inline
x = range(1,21)
y = np.array([df_s_1_tmax.mean(), df_s_2_tmax.mean(), df_s_3_tmax.mean(), df_s_4_tmax.mean(), df_s_5_tmax.mean(),
             df_s_6_tmax.mean(), df_s_7_tmax.mean(), df_s_8_tmax.mean(), df_s_9_tmax.mean(), df_s_10_tmax.mean(), 
             df_s_11_tmax.mean(), df_s_12_tmax.mean(), df_s_13_tmax.mean(), df_s_14_tmax.mean(), df_s_15_tmax.mean(),
             df_s_16_tmax.mean(), df_s_17_tmax.mean(), df_s_18_tmax.mean(), df_s_19_tmax.mean(), df_s_20_tmax.mean()])

plt.figure(figsize=(12,4))
plt.bar(x,y)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# %matplotlib inline
x = range(1,21)
y = np.array([df_s_1_tmax_with_mean.mean(), df_s_2_tmax_with_mean.mean(), df_s_3_tmax_with_mean.mean(), df_s_4_tmax_with_mean.mean()
             ,df_s_5_tmax_with_mean.mean(), df_s_6_tmax_with_mean.mean(), df_s_7_tmax_with_mean.mean(), df_s_8_tmax_with_mean.mean()
             ,df_s_9_tmax_with_mean.mean(), df_s_10_tmax_with_mean.mean(), df_s_11_tmax_with_mean.mean(), df_s_12_tmax_with_mean.mean()
             ,df_s_13_tmax_with_mean.mean(), df_s_14_tmax_with_mean.mean(), df_s_15_tmax_with_mean.mean(), df_s_16_tmax_with_mean.mean()
             ,df_s_17_tmax_with_mean.mean(),df_s_18_tmax_with_mean.mean(),df_s_19_tmax_with_mean.mean(),df_s_20_tmax_with_mean.mean()])

plt.figure(figsize=(12,4))
plt.bar(x,y)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
y1 = np.array([df_s_1_tmax.mean(), df_s_2_tmax.mean(), df_s_3_tmax.mean(), df_s_4_tmax.mean(), df_s_5_tmax.mean(),
             df_s_6_tmax.mean(), df_s_7_tmax.mean(), df_s_8_tmax.mean(), df_s_9_tmax.mean(), df_s_10_tmax.mean(), 
             df_s_11_tmax.mean(), df_s_12_tmax.mean(), df_s_13_tmax.mean(), df_s_14_tmax.mean(), df_s_15_tmax.mean(),
             df_s_16_tmax.mean(), df_s_17_tmax.mean(), df_s_18_tmax.mean(), df_s_19_tmax.mean(), df_s_20_tmax.mean()])

y2 = np.array([df_s_1_tmax_with_mean.mean(), df_s_2_tmax_with_mean.mean(), df_s_3_tmax_with_mean.mean(), df_s_4_tmax_with_mean.mean()
             ,df_s_5_tmax_with_mean.mean(), df_s_6_tmax_with_mean.mean(), df_s_7_tmax_with_mean.mean(), df_s_8_tmax_with_mean.mean()
             ,df_s_9_tmax_with_mean.mean(), df_s_10_tmax_with_mean.mean(), df_s_11_tmax_with_mean.mean(), df_s_12_tmax_with_mean.mean()
             ,df_s_13_tmax_with_mean.mean(), df_s_14_tmax_with_mean.mean(), df_s_15_tmax_with_mean.mean(), df_s_16_tmax_with_mean.mean()
             ,df_s_17_tmax_with_mean.mean(),df_s_18_tmax_with_mean.mean(),df_s_19_tmax_with_mean.mean(),df_s_20_tmax_with_mean.mean()])
plt.figure(figsize=(10,5))
plt.plot()
x = range(1, 21)
plt.xlabel('Station Number')
plt.ylabel('tmax')
plt.bar(x, y1, color='r')
plt.bar(x, y2, color='y')
plt.show()

#### Tmax 에서는
# 이 Graph가 나타내는 바는, y1과 y2가 차이가 거의 없다는 것. 그래프에는 r color와 y color이 있는데, 하나만 보인다는 것은
# 우리가 그래프에서 눈으로 보이지 않는 정도의 차이가 나온다는 것이다, 즉 차이가 극히 작다고 판단 할 수 있다.
# Missing Values를 np.nan으로 바꾸고, 거기서 Mean 값을 구하여 np.nan에 대입하여도, 
# 따라서, 여기서는 Missing Value에 Mean값을 적용하여 회귀 분석에 적용 할 수있다고 판단된다.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
