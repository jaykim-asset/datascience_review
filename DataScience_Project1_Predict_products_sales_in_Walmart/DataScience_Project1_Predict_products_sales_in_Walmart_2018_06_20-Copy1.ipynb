# %%
# key.csv 파일에서 분석 가능한 내용
# 1) 어떤 기지국(station)이 가장 많이 사용되었는지
# 2) 어떤 기지국(station)이 가장 적게 사용되었는지
# 따라서, 어떤 기주국(station)의 영향력이 가장 셀지 적을지 볼 수 있음
data_key = pd.read_csv('key.csv')
data_weather = pd.read_csv('weather.csv')
data_train = pd.read_csv('train.csv')

# %%
df = pd.merge(data_weather, data_key)
station_nbr = df['station_nbr']
df.drop('station_nbr', axis=1, inplace=True)
df['station_nbr'] = station_nbr
df = pd.merge(df, data_train)
df.dtypes
df
# Out:
#                date tmax tmin tavg depart dewpoint wetbulb heat cool sunrise  \
# 0        2012-01-01   52   31   42      M       36      40   23    0       -
# 1        2012-01-01   52   31   42      M       36      40   23    0       -
# 2        2012-01-01   52   31   42      M       36      40   23    0       -
# 3        2012-01-01   52   31   42      M       36      40   23    0       -
# 4        2012-01-01   52   31   42      M       36      40   23    0       -
# 5        2012-01-01   52   31   42      M       36      40   23    0       -
# 6        2012-01-01   52   31   42      M       36      40   23    0       -
# 7        2012-01-01   52   31   42      M       36      40   23    0       -
# 8        2012-01-01   52   31   42      M       36      40   23    0       -
# 9        2012-01-01   52   31   42      M       36      40   23    0       -
# 10       2012-01-01   52   31   42      M       36      40   23    0       -
# ...

# %%
new_0 = pd.to_numeric(df.iloc[:, 0], errors = 'coerce')
new_1 = pd.to_numeric(df.iloc[:, 1], errors = 'coerce')
new_2 = pd.to_numeric(df.iloc[:, 2], errors = 'coerce')
new_3 = pd.to_numeric(df.iloc[:, 3], errors = 'coerce')
new_4 = pd.to_numeric(df.iloc[:, 4], errors = 'coerce')
new_5 = pd.to_numeric(df.iloc[:, 5], errors = 'coerce')
new_6 = pd.to_numeric(df.iloc[:, 6], errors = 'coerce')
new_7 = pd.to_numeric(df.iloc[:, 7], errors = 'coerce')
new_8 = pd.to_numeric(df.iloc[:, 8], errors = 'coerce')
new_12 = pd.to_numeric(df.iloc[:, 12], errors = 'coerce')
new_13 = pd.to_numeric(df.iloc[:, 13], errors = 'coerce')
new_14 = pd.to_numeric(df.iloc[:, 14], errors = 'coerce')
new_15 = pd.to_numeric(df.iloc[:, 15], errors = 'coerce')
new_16 = pd.to_numeric(df.iloc[:, 16], errors = 'coerce')
new_17 = pd.to_numeric(df.iloc[:, 17], errors = 'coerce')
new_18 = pd.to_numeric(df.iloc[:, 18], errors = 'coerce')
new_19 = pd.to_numeric(df.iloc[:, 19], errors = 'coerce')
new_20 = pd.to_numeric(df.iloc[:, 20], errors = 'coerce')
new_21 = pd.to_numeric(df.iloc[:, 21], errors = 'coerce')
new_22 = pd.to_numeric(df.iloc[:, 22], errors = 'coerce')

df['date'] = new_0.combine_first(df.iloc[:, 0])
df['tmax'] = new_1.combine_first(df.iloc[:, 1])
df['tmin'] = new_2.combine_first(df.iloc[:, 2])
df['tavg'] = new_3.combine_first(df.iloc[:, 3])
df['depart'] = new_4.combine_first(df.iloc[:, 4])
df['dewpoint'] = new_5.combine_first(df.iloc[:, 5])
df['wetbulb'] = new_6.combine_first(df.iloc[:, 6])
df['heat'] = new_7.combine_first(df.iloc[:, 7])
df['cool'] = new_8.combine_first(df.iloc[:, 8])

# df['sunrise'] = df['sunrise'].combine_first(df.iloc[:, 0])
# df['sunset'] = df['sunset'].combine_first(df.iloc[:, 0])
# df['codesum'] = df['comdesum'].combine_first(df.iloc[:, 0])

df['snowfall'] = new_12.combine_first(df.iloc[:, 12])
df['preciptotal'] = new_13.combine_first(df.iloc[:, 13])
df['stnpressure'] = new_14.combine_first(df.iloc[:, 14])
df['sealevel'] = new_15.combine_first(df.iloc[:, 15])
df['resultspeed'] = new_16.combine_first(df.iloc[:, 16])
df['resultdir'] = new_17.combine_first(df.iloc[:, 17])
df['avgspeed'] = new_18.combine_first(df.iloc[:, 18])

# df['store_nbr'] = df['store_nbr'].combine_first(df.iloc[:, 0])
# df['station_nbr'] = df['station_nbr'].combine_first(df.iloc[:, 0])
# df['item_nbr'] = df['item_nbr'].combine_first(df.iloc[:, 0])
# df['units'] = df['units'].combine_first(df.iloc[:, 0])

# %%
data_weather
# Out:
#        station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat  \
# 0                1  2012-01-01   52   31   42      M       36      40   23
# 1                2  2012-01-01   48   33   41     16       37      39   24
# 2                3  2012-01-01   55   34   45      9       24      36   20
# 3                4  2012-01-01   63   47   55      4       28      43   10
# 4                6  2012-01-01   63   34   49      0       31      43   16
# 5                7  2012-01-01   50   33   42      M       26      35   23
# 6                8  2012-01-01   66   45    M      M       34      46    M
# 7                9  2012-01-01   34   19   27      M       17      23   38
# 8               10  2012-01-01   73   53   63      M       55      58    2
# 9               11  2012-01-01   72   48   60      7       54      56    5
# 10              12  2012-01-01   72   48   60      M       54      57    5
# ...

# %%
# # tmax mean
# max_avg = data_weather['tmax'][data_weather['tmax'] != 'M'].mean().round(2)
# # tmin mean
# min_avg = data_weather['tmin'][data_weather['tmin'] != 'M'].mean().round(2)
# # tavg mean
# avg_avg = data_weather['tavg'][data_weather['tavg'] != 'M'].mean().round(2)
# # depart mean
# depart_avg = data_weather['depart'][data_weather['depart'] != 'M'].mean().round(2)
# # dewpoint mean
# dewpoint_avg = data_weather['dewpoint'][data_weather['dewpoint'] != 'M'].mean().round(2)
# # wetbulb mean
# wetbulb_avg = data_weather['wetbulb'][data_weather['wetbulb'] != 'M'].mean().round(2)
# # heat mean
# heat_avg = data_weather['heat'][data_weather['heat'] != 'M'].mean().round(2)
# # cool mean
# cool_avg = data_weather['cool'][data_weather['cool'] != 'M'].mean().round(2)
# # snowfall mean
# snowfall_avg = data_weather['snowfall'][(data_weather['snowfall'] != 'M') & (data_weather['snowfall'] != '  T')].mean().round(2)
# # preciptotal mean
# preciptotal_avg = data_weather['preciptotal'][(data_weather['preciptotal'] != 'M') & (data_weather['preciptotal'] != '  T')].mean().round(2)
# # stnpressure mean
# stnpressure_avg = data_weather['stnpressure'][data_weather['stnpressure'] != 'M'].mean().round(2)
# # sealevel mean
# sealevel_avg = data_weather['sealevel'][data_weather['sealevel'] != 'M'].mean().round(2)
# # resultspeed mean
# resultspeed_avg = data_weather['resultspeed'][data_weather['resultspeed'] != 'M'].mean().round(2)
# # resultdi mean
# resultdir_avg = data_weather['resultdir'][data_weather['resultdir'] != 'M'].mean().round(2)
# # avgspeed mean
# avgspeed_avg = data_weather['avgspeed'][data_weather['avgspeed'] != 'M'].mean().round(2)

# %%
# print('max_mavg:{}'.format(max_avg),
#       'min_avg:{}'.format(min_avg), 
#       'avg_avg:{}'.format(avg_avg), 
#       'depart_avg:{}'.format(depart_avg), 
#       'dewpoint_avg:{} '.format(dewpoint_avg), 
#       'wetbulb_avg:{} '.format(wetbulb_avg),
#       'heat_avg:{} '.format(heat_avg),
#       'coll_avg:{} '.format(cool_avg),
#       'snowfall_avg:{} '.format(snowfall_avg),
#       'preciptotal_avg:{} '.format(preciptotal_avg),
#       'stnpressure_avg:{} '.format(stnpressure_avg), 
#       'sealevel_avg:{} '.format(sealevel_avg), 
#       'resultspeed_avg:{} '.format(resultspeed_avg),
#       'resultdir_avg:{} '.format(resultdir_avg),
#       'avgspeed_avg:{} '.format(avgspeed_avg))
# Out:
# max_mavg:71.62 min_avg:50.65 avg_avg:61.24 depart_avg:1.36 dewpoint_avg:47.27  wetbulb_avg:53.89  heat_avg:9.7  coll_avg:5.94  snowfall_avg:0.04  preciptotal_avg:0.11  stnpressure_avg:29.16  sealevel_avg:30.01  resultspeed_avg:6.47  resultdir_avg:18.73  avgspeed_avg:7.91

# %%
data_weather_nan = data_weather.copy()
data_weather_nan
# Out:
#        station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat  \
# 0                1  2012-01-01   52   31   42      M       36      40   23
# 1                2  2012-01-01   48   33   41     16       37      39   24
# 2                3  2012-01-01   55   34   45      9       24      36   20
# 3                4  2012-01-01   63   47   55      4       28      43   10
# 4                6  2012-01-01   63   34   49      0       31      43   16
# 5                7  2012-01-01   50   33   42      M       26      35   23
# 6                8  2012-01-01   66   45    M      M       34      46    M
# 7                9  2012-01-01   34   19   27      M       17      23   38
# 8               10  2012-01-01   73   53   63      M       55      58    2
# 9               11  2012-01-01   72   48   60      7       54      56    5
# 10              12  2012-01-01   72   48   60      M       54      57    5
# ...

# %%
new_0 = pd.to_numeric(data_weather_nan['tmax'], errors = 'coerce')
new_1 = pd.to_numeric(data_weather_nan['tmin'], errors = 'coerce')
new_2 = pd.to_numeric(data_weather_nan['tavg'], errors = 'coerce')
new_3 = pd.to_numeric(data_weather_nan['depart'], errors = 'coerce')
new_4 = pd.to_numeric(data_weather_nan['dewpoint'], errors = 'coerce')
new_5 = pd.to_numeric(data_weather_nan['wetbulb'], errors = 'coerce')
new_6 = pd.to_numeric(data_weather_nan['heat'], errors = 'coerce')
new_7 = pd.to_numeric(data_weather_nan['cool'], errors = 'coerce')
new_8 = pd.to_numeric(data_weather_nan['snowfall'], errors = 'coerce')
new_9 = pd.to_numeric(data_weather_nan['preciptotal'], errors = 'coerce')
new_10 = pd.to_numeric(data_weather_nan['stnpressure'], errors = 'coerce')
new_11 = pd.to_numeric(data_weather_nan['sealevel'], errors = 'coerce')
new_12 = pd.to_numeric(data_weather_nan['resultspeed'], errors = 'coerce')
new_13 = pd.to_numeric(data_weather_nan['resultdir'], errors = 'coerce')
new_14 = pd.to_numeric(data_weather_nan['avgspeed'], errors = 'coerce')

# %%
data_weather_nan['tmax'] = new_0
data_weather_nan['tmin'] = new_1
data_weather_nan['tavg'] = new_2
data_weather_nan['depart'] = new_3
data_weather_nan['dewpoint'] = new_4
data_weather_nan['wetbulb'] = new_5
data_weather_nan['heat'] = new_6
data_weather_nan['cool'] = new_7
data_weather_nan['snowfall'] = new_8
data_weather_nan['preciptotal'] = new_9
data_weather_nan['stnpressure'] = new_10
data_weather_nan['sealevel'] = new_11
data_weather_nan['resultspeed'] = new_12
data_weather_nan['resultdir'] = new_13
data_weather_nan['avgspeed'] = new_14

# %%
result_df_nan = round(data_weather_nan.groupby('station_nbr').agg(['median', 'mean', 'min', 'max']),2)

# %%
result_df_nan['tmax']
# Out:
#              median   mean   min    max
# station_nbr
# 1              63.0  61.50  14.0   97.0
# 2              61.0  57.82   9.0   93.0
# 3              76.0  73.68  17.0  112.0
# 4              85.0  82.30  31.0  109.0
# 5              70.0  71.70  60.0   93.0
# 6              84.0  81.70  31.0  107.0
# 7              77.0  74.10  16.0  112.0
# 8              84.0  81.64  33.0  109.0
# 9              60.0  56.66 -11.0  102.0
# 10             83.0  81.18  41.0  102.0
# 11             82.0  79.95  39.0   99.0
# 12             83.0  80.41  41.0   98.0
# 13             67.0  65.26   2.0  100.0
# 14             77.0  74.28  18.0  113.0
# 15             62.0  59.54   7.0   96.0
# 16             62.0  60.29  14.0   96.0
# 17             77.0  74.54  19.0  114.0
# 18             82.0  79.47  24.0  108.0
# 19             59.0  57.18  -4.0  103.0
# 20             82.0  79.37  25.0  108.0

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'} #retina 및 png압축

# %%
data1 = result_df_nan['tmax']['median']
data2 = result_df_nan['tmax']['mean']
data3 = result_df_nan['tmax']['min']
data4 = result_df_nan['tmax']['max']

plt.figure(figsize=(12,7))

# plt.figure(figsize=(20,10)) # Size 20 , 4 -> 가로확대 그림
# plt.subplot(2,2,1) # 2x2 행렬의 1번째 그림
# plt.xlim(0, 20) # x축값 0 ~ 20 으로 제한
# plt.ylim(50, 90) # y축값 0 ~ 20 으로 제한
# plt.xticks(range(20+1)) # x ticks 0 ~ 19까지
# plt.yticks(range(20+1)) # y ticks 0 ~ 19까지
# plt.xlabel('price1') # x축 이름: price1
# plt.ylabel('quantity1') # y축 이름: quantity 1
# plt.title('KRX1') # 제목: KRX1
# plt.legend(loc=0) # legend best fit 설정
plt.plot(data1, 'r--') # 빨간 -- 선으로 그림

# plt.figure(figsize=(20,10))
# plt.subplot(2,2,2)
# plt.xlim(0, 10)
# plt.ylim(0, 10)
# plt.xticks(range(10+1))
# plt.yticks(range(10+1)) # Range로 설정
# plt.xlabel('price2')
# plt.ylabel('quantity2')
# plt.title('KRX2')
# plt.legend(loc=0)
plt.plot(data2, 'b:')

# plt.figure(figsize=(20,10))
# plt.subplot(2,2,3)
# plt.xlim(0, 15)
# plt.ylim(0, 15)
# plt.xticks(range(15+1))
# plt.yticks(range(15+1))
# plt.xlabel('price3')
# plt.ylabel('quantity3')
# plt.title('KRX3')
# plt.legend(loc=0)
plt.plot(data3, 'g--')

# plt.figure(figsize=(20,10))
# plt.subplot(2,2,4)
# plt.xlim(0, 20)
# plt.ylim(0, 20)
# plt.xticks(range(20+1))
# plt.yticks(range(20+1))
# plt.xlabel('price4')
# plt.ylabel('quantity4')
# plt.title('KRX4')
# plt.legend(loc=0)
plt.plot(data4, 'p-')

# plt.plot(data1, label='data1')
# plt.plot(data2, label='data2')

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
result_df_nan['tmax'].iloc[0]
# Out:
# median    63.0
# mean      61.5
# min       14.0
# max       97.0
# Name: 1, dtype: float64

# %%
result_df_nan['tmax']
# Out:
#              median   mean   min    max
# station_nbr
# 1              63.0  61.50  14.0   97.0
# 2              61.0  57.82   9.0   93.0
# 3              76.0  73.68  17.0  112.0
# 4              85.0  82.30  31.0  109.0
# 5              70.0  71.70  60.0   93.0
# 6              84.0  81.70  31.0  107.0
# 7              77.0  74.10  16.0  112.0
# 8              84.0  81.64  33.0  109.0
# 9              60.0  56.66 -11.0  102.0
# 10             83.0  81.18  41.0  102.0
# 11             82.0  79.95  39.0   99.0
# 12             83.0  80.41  41.0   98.0
# 13             67.0  65.26   2.0  100.0
# 14             77.0  74.28  18.0  113.0
# 15             62.0  59.54   7.0   96.0
# 16             62.0  60.29  14.0   96.0
# 17             77.0  74.54  19.0  114.0
# 18             82.0  79.47  24.0  108.0
# 19             59.0  57.18  -4.0  103.0
# 20             82.0  79.37  25.0  108.0

# %%
new_0 = pd.to_numeric(data_weather['tmax'], errors = 'coerce')
new_1 = pd.to_numeric(data_weather['tmin'], errors = 'coerce')
new_2 = pd.to_numeric(data_weather['tavg'], errors = 'coerce')
new_3 = pd.to_numeric(data_weather['depart'], errors = 'coerce')
new_4 = pd.to_numeric(data_weather['dewpoint'], errors = 'coerce')
new_5 = pd.to_numeric(data_weather['wetbulb'], errors = 'coerce')
new_6 = pd.to_numeric(data_weather['heat'], errors = 'coerce')
new_7 = pd.to_numeric(data_weather['cool'], errors = 'coerce')
new_8 = pd.to_numeric(data_weather['snowfall'], errors = 'coerce')
new_9 = pd.to_numeric(data_weather['preciptotal'], errors = 'coerce')
new_10 = pd.to_numeric(data_weather['stnpressure'], errors = 'coerce')
new_11 = pd.to_numeric(data_weather['sealevel'], errors = 'coerce')
new_12 = pd.to_numeric(data_weather['resultspeed'], errors = 'coerce')
new_13 = pd.to_numeric(data_weather['resultdir'], errors = 'coerce')
new_14 = pd.to_numeric(data_weather['avgspeed'], errors = 'coerce')

data_weather['tmax'] = new_0.combine_first(data_weather['tmax'])
data_weather['tmin'] = new_1.combine_first(data_weather['tmin'])
data_weather['tavg'] = new_2.combine_first(data_weather['tavg'])
data_weather['depart'] = new_3.combine_first(data_weather['depart'])
data_weather['dewpoint'] = new_4.combine_first(data_weather['dewpoint'])
data_weather['wetbulb'] = new_5.combine_first(data_weather['wetbulb'])
data_weather['heat'] = new_6.combine_first(data_weather['heat'])
data_weather['cool'] = new_7.combine_first(data_weather['cool'])
data_weather['snowfall'] = new_8.combine_first(data_weather['snowfall'])
data_weather['preciptotal'] = new_9.combine_first(data_weather['preciptotal'])
data_weather['stnpressure'] = new_10.combine_first(data_weather['stnpressure'])
data_weather['sealevel'] = new_11.combine_first(data_weather['sealevel'])
data_weather['resultspeed'] = new_12.combine_first(data_weather['resultspeed'])
data_weather['resultdir'] = new_13.combine_first(data_weather['resultdir'])
data_weather['avgspeed'] = new_14.combine_first(data_weather['avgspeed'])

# %%
# result_df = round(data_weather.groupby('station_nbr').agg(['median', 'mean', 'min', 'max']),2)

# %%
data_weather['tmax'][data_weather['tmax'] == 'M'] = result_df_nan['tmax'].iloc[1]['median']
# Out:
# 2887     M
# 2892     M
# 2912     M
# 2932     M
# 2952     M
# 2972     M
# 2992     M
# 3012     M
# 3032     M
# 3052     M
# 3072     M
# 3092     M
# 3112     M
# 3132     M
# 3152     M
# 3172     M
# 3192     M
# 3212     M
# 3232     M
# 3252     M
# 3272     M
# 3292     M
# 3312     M
# 3332     M
# 3352     M
# 3372     M
# 3392     M
# 3412     M
# 3432     M
# 3452     M
#         ..
# 19921    M
# 19941    M
# 19961    M
# 19981    M
# 20001    M
# 20021    M
# 20041    M
# 20061    M
# 20081    M
# 20101    M
# 20121    M
# 20141    M
# 20161    M
# 20181    M
# 20201    M
# 20221    M
# 20241    M
# 20261    M
# 20281    M
# 20301    M
# 20321    M
# 20341    M
# 20361    M
# 20381    M
# 20401    M
# 20421    M
# 20441    M
# 20461    M
# 20481    M
# 20501    M
# Name: tmax, Length: 906, dtype: object

# %%
result_df_nan['tmax'].iloc[1]['median']
# Out:
# 57.82

# %%
data_weather_2 = data_weather.copy()

# %%
# nan 값을 넣었을 때, 구한 Median 값을 original data의 M으로 대체 할 경우
data_weather_station_1 = data_weather[data_weather['station_nbr'] == 1]
data_weather_station_1['tmax'][data_weather_station_1['tmax'] == 'M'] = result_df_nan['tmax'].iloc[1]['median']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5984: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2910: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data_weather_station_1['tmax'].astype(int)
data_weather_station_1['tmax']
# Out:
# 0        52
# 19       50
# 38       32
# 57       28
# 76       38
# 95       46
# 114      57
# 133      45
# 152      39
# 171      47
# 190      39
# 209      40
# 228      50
# 247      35
# 266      16
# 285      32
# 304      46
# 323      50
# 342      31
# 361      31
# 380      20
# 399      28
# 418      48
# 437      55
# 456      42
# 475      43
# 494      45
# 513      48
# 532      43
# 551      39
#          ..
# 19917    57
# 19937    62
# 19957    63
# 19977    61
# 19997    67
# 20017    74
# 20037    72
# 20057    64
# 20077    62
# 20097    52
# 20117    60
# 20137    61
# 20157    77
# 20177    81
# 20197    71
# 20217    71
# 20237    70
# 20257    55
# 20277    57
# 20297    62
# 20317    53
# 20337    53
# 20357    53
# 20377    65
# 20397    58
# 20417    61
# 20437    65
# 20457    66
# 20477    57
# 20497    53
# Name: tmax, Length: 1035, dtype: object
