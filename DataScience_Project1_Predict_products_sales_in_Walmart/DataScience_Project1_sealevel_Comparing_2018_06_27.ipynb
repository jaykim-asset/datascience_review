# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

data_key = pd.read_csv('key.csv')
data_key = data_key[data_key['station_nbr'] != 5]
data_weather = pd.read_csv('weather.csv')
data_weather = data_weather[data_weather['station_nbr'] != 5] ## Station 5번 제거한 나머지
data_train = pd.read_csv('train.csv')

df = pd.merge(data_weather, data_key)
station_nbr = df['station_nbr']
df.drop('station_nbr', axis=1, inplace=True)
df['station_nbr'] = station_nbr
df = pd.merge(df, data_train)
# Station 5번을 뺀 나머지 Merge 완성
# 'M'과 '-'을 np.nan으로 값을 변경하기 전에, '  T'값을 먼저 snowfall=0.05, preciptotal = 0.005로 변경하자 
df['snowfall'][df['snowfall'] == '  T'] = 0.05
df['preciptotal'][df['preciptotal'] == '  T'] = 0.005
df['snowfall'][df['snowfall'] == '  T'], df['preciptotal'][df['preciptotal'] == '  T']
# T 값 변경 완료. 이제, 19개 Station 별로 정리하기 (5번 Station 생략)
df['snowfall'][df['snowfall'] == '  T'] = 0.05
df['preciptotal'][df['preciptotal'] == '  T'] = 0.005
# T 값 변경 완료. 이제, 19개 Station 별로 정리하기 (5번 Station 생략)
df_s_1 = df[df['station_nbr'] == 1]; df_s_8 = df[df['station_nbr'] == 8]; df_s_15 = df[df['station_nbr'] == 15]
df_s_2 = df[df['station_nbr'] == 2]; df_s_9 = df[df['station_nbr'] == 9]; df_s_16 = df[df['station_nbr'] == 16]
df_s_3 = df[df['station_nbr'] == 3]; df_s_10 = df[df['station_nbr'] == 10]; df_s_17 = df[df['station_nbr'] == 17]
df_s_4 = df[df['station_nbr'] == 4]; df_s_11 = df[df['station_nbr'] == 11]; df_s_18 = df[df['station_nbr'] == 18]
df_s_5 = df[df['station_nbr'] == 5]; df_s_12 = df[df['station_nbr'] == 12]; df_s_19 = df[df['station_nbr'] == 19]
df_s_6 = df[df['station_nbr'] == 6]; df_s_13 = df[df['station_nbr'] == 13]; df_s_20 = df[df['station_nbr'] == 20]
df_s_7 = df[df['station_nbr'] == 7]; df_s_14 = df[df['station_nbr'] == 14]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# ...

# %%
# Each Station sealevel 의 M값을 np.nan으로 변경
df_s_1_sealevel = df_s_1['sealevel'].copy(); df_s_1_sealevel = pd.to_numeric(df_s_1_sealevel, errors = 'coerce')
df_s_2_sealevel = df_s_2['sealevel'].copy(); df_s_2_sealevel = pd.to_numeric(df_s_2_sealevel, errors = 'coerce')
df_s_3_sealevel = df_s_3['sealevel'].copy(); df_s_3_sealevel = pd.to_numeric(df_s_3_sealevel, errors = 'coerce')
df_s_4_sealevel = df_s_4['sealevel'].copy(); df_s_4_sealevel = pd.to_numeric(df_s_4_sealevel, errors = 'coerce')
df_s_5_sealevel = df_s_5['sealevel'].copy(); df_s_5_sealevel = pd.to_numeric(df_s_5_sealevel, errors = 'coerce')
df_s_6_sealevel = df_s_6['sealevel'].copy(); df_s_6_sealevel = pd.to_numeric(df_s_6_sealevel, errors = 'coerce')
df_s_7_sealevel = df_s_7['sealevel'].copy(); df_s_7_sealevel = pd.to_numeric(df_s_7_sealevel, errors = 'coerce')
df_s_8_sealevel = df_s_8['sealevel'].copy(); df_s_8_sealevel = pd.to_numeric(df_s_8_sealevel, errors = 'coerce')
df_s_9_sealevel = df_s_9['sealevel'].copy(); df_s_9_sealevel = pd.to_numeric(df_s_9_sealevel, errors = 'coerce')
df_s_10_sealevel = df_s_10['sealevel'].copy(); df_s_10_sealevel = pd.to_numeric(df_s_10_sealevel, errors = 'coerce')
df_s_11_sealevel = df_s_11['sealevel'].copy(); df_s_11_sealevel = pd.to_numeric(df_s_11_sealevel, errors = 'coerce')
df_s_12_sealevel = df_s_12['sealevel'].copy(); df_s_12_sealevel = pd.to_numeric(df_s_12_sealevel, errors = 'coerce')
df_s_13_sealevel = df_s_13['sealevel'].copy(); df_s_13_sealevel = pd.to_numeric(df_s_13_sealevel, errors = 'coerce')
df_s_14_sealevel = df_s_14['sealevel'].copy(); df_s_14_sealevel = pd.to_numeric(df_s_14_sealevel, errors = 'coerce')
df_s_15_sealevel = df_s_15['sealevel'].copy(); df_s_15_sealevel = pd.to_numeric(df_s_15_sealevel, errors = 'coerce')
df_s_16_sealevel = df_s_16['sealevel'].copy(); df_s_16_sealevel = pd.to_numeric(df_s_16_sealevel, errors = 'coerce')
df_s_17_sealevel = df_s_17['sealevel'].copy(); df_s_17_sealevel = pd.to_numeric(df_s_17_sealevel, errors = 'coerce')
df_s_18_sealevel = df_s_18['sealevel'].copy(); df_s_18_sealevel = pd.to_numeric(df_s_18_sealevel, errors = 'coerce')
df_s_19_sealevel = df_s_19['sealevel'].copy(); df_s_19_sealevel = pd.to_numeric(df_s_19_sealevel, errors = 'coerce')
df_s_20_sealevel = df_s_20['sealevel'].copy(); df_s_20_sealevel = pd.to_numeric(df_s_20_sealevel, errors = 'coerce')

# 각 각의 Station의 Nan 값에, 위에서 구한 각각 station의 평균 값을 넣어서 NaN 값 뺏을 때와 비교할 것.
df_s_1_sealevel_with_mean = df_s_1_sealevel.copy(); df_s_1_sealevel_with_mean[df_s_1_sealevel_with_mean.isnull()] = df_s_1_sealevel.mean()
df_s_2_sealevel_with_mean = df_s_2_sealevel.copy(); df_s_2_sealevel_with_mean[df_s_2_sealevel_with_mean.isnull()] = df_s_2_sealevel.mean()
df_s_3_sealevel_with_mean = df_s_3_sealevel.copy(); df_s_3_sealevel_with_mean[df_s_3_sealevel_with_mean.isnull()] = df_s_3_sealevel.mean()
df_s_4_sealevel_with_mean = df_s_4_sealevel.copy(); df_s_4_sealevel_with_mean[df_s_4_sealevel_with_mean.isnull()] = df_s_4_sealevel.mean()
df_s_5_sealevel_with_mean = df_s_5_sealevel.copy(); df_s_5_sealevel_with_mean[df_s_5_sealevel_with_mean.isnull()] = df_s_5_sealevel.mean()
df_s_6_sealevel_with_mean = df_s_6_sealevel.copy(); df_s_6_sealevel_with_mean[df_s_6_sealevel_with_mean.isnull()] = df_s_6_sealevel.mean()
df_s_7_sealevel_with_mean = df_s_7_sealevel.copy(); df_s_7_sealevel_with_mean[df_s_7_sealevel_with_mean.isnull()] = df_s_7_sealevel.mean()
df_s_8_sealevel_with_mean = df_s_8_sealevel.copy(); df_s_8_sealevel_with_mean[df_s_8_sealevel_with_mean.isnull()] = df_s_8_sealevel.mean()
df_s_9_sealevel_with_mean = df_s_9_sealevel.copy(); df_s_9_sealevel_with_mean[df_s_9_sealevel_with_mean.isnull()] = df_s_9_sealevel.mean()
df_s_10_sealevel_with_mean = df_s_10_sealevel.copy(); df_s_10_sealevel_with_mean[df_s_10_sealevel_with_mean.isnull()] = df_s_10_sealevel.mean()
df_s_11_sealevel_with_mean = df_s_11_sealevel.copy(); df_s_11_sealevel_with_mean[df_s_11_sealevel_with_mean.isnull()] = df_s_11_sealevel.mean()
df_s_12_sealevel_with_mean = df_s_12_sealevel.copy(); df_s_12_sealevel_with_mean[df_s_12_sealevel_with_mean.isnull()] = df_s_12_sealevel.mean()
df_s_13_sealevel_with_mean = df_s_13_sealevel.copy(); df_s_13_sealevel_with_mean[df_s_13_sealevel_with_mean.isnull()] = df_s_13_sealevel.mean()
df_s_14_sealevel_with_mean = df_s_14_sealevel.copy(); df_s_14_sealevel_with_mean[df_s_14_sealevel_with_mean.isnull()] = df_s_14_sealevel.mean()
df_s_15_sealevel_with_mean = df_s_15_sealevel.copy(); df_s_15_sealevel_with_mean[df_s_15_sealevel_with_mean.isnull()] = df_s_15_sealevel.mean()
df_s_16_sealevel_with_mean = df_s_16_sealevel.copy(); df_s_16_sealevel_with_mean[df_s_16_sealevel_with_mean.isnull()] = df_s_16_sealevel.mean()
df_s_17_sealevel_with_mean = df_s_17_sealevel.copy(); df_s_17_sealevel_with_mean[df_s_17_sealevel_with_mean.isnull()] = df_s_17_sealevel.mean()
df_s_18_sealevel_with_mean = df_s_18_sealevel.copy(); df_s_18_sealevel_with_mean[df_s_18_sealevel_with_mean.isnull()] = df_s_18_sealevel.mean()
df_s_19_sealevel_with_mean = df_s_19_sealevel.copy(); df_s_19_sealevel_with_mean[df_s_19_sealevel_with_mean.isnull()] = df_s_19_sealevel.mean()
df_s_20_sealevel_with_mean = df_s_20_sealevel.copy(); df_s_20_sealevel_with_mean[df_s_20_sealevel_with_mean.isnull()] = df_s_20_sealevel.mean()

# 각 각의 Station 별로 sealevel의 값이 np.nan일 때, 즉, missing value를 뺏을 때의 전체 mean 값을 나타낸다. 
print('#station1_without_nan_mean:', round(df_s_1_sealevel.mean(),4), '#station1_without_nan_std:', round(df_s_1_sealevel.std(),4)); 
print('#station2_without_nan_mean:', round(df_s_2_sealevel.mean(),4), '#station2_without_nan_std:', round(df_s_2_sealevel.std(),4)); 
print('#station3_without_nan_mean:', round(df_s_3_sealevel.mean(),4), '#station3_without_nan_std:', round(df_s_3_sealevel.std(),4)); 
print('#station4_without_nan_mean:', round(df_s_4_sealevel.mean(),4), '#station4_without_nan_std:', round(df_s_4_sealevel.std(),4)); 
print('#station5_without_nan_mean:', round(df_s_5_sealevel.mean(),4), '#station5_without_nan_std:', round(df_s_5_sealevel.std(),4)); 
print('#station6_without_nan_mean:', round(df_s_6_sealevel.mean(),4), '#station6_without_nan_std:', round(df_s_6_sealevel.std(),4)); 
print('#station7_without_nan_mean:', round(df_s_7_sealevel.mean(),4), '#station7_without_nan_std:', round(df_s_7_sealevel.std(),4)); 
print('#station8_without_nan_mean:', round(df_s_8_sealevel.mean(),4), '#station8_without_nan_std:', round(df_s_8_sealevel.std(),4)); 
print('#station9_without_nan_mean:', round(df_s_9_sealevel.mean(),4), '#station9_without_nan_std:', round(df_s_9_sealevel.std(),4)); 
print('#station10_without_nan_mean:', round(df_s_10_sealevel.mean(),4), '#station10_without_nan_std:', round(df_s_10_sealevel.std(),4));  
print('#station11_without_nan_mean:', round(df_s_11_sealevel.mean(),4), '#station11_without_nan_std:', round(df_s_11_sealevel.std(),4)); 
print('#station12_without_nan_mean:', round(df_s_12_sealevel.mean(),4), '#station12_without_nan_std:', round(df_s_12_sealevel.std(),4)); 
print('#station13_without_nan_mean:', round(df_s_13_sealevel.mean(),4), '#station13_without_nan_std:', round(df_s_13_sealevel.std(),4)); 
print('#station14_without_nan_mean:', round(df_s_14_sealevel.mean(),4), '#station14_without_nan_std:', round(df_s_14_sealevel.std(),4)); 
print('#station15_without_nan_mean:', round(df_s_15_sealevel.mean(),4), '#station15_without_nan_std:', round(df_s_15_sealevel.std(),4)); 
print('#station16_without_nan_mean:', round(df_s_16_sealevel.mean(),4), '#station16_without_nan_std:', round(df_s_16_sealevel.std(),4)); 
print('#station17_without_nan_mean:', round(df_s_17_sealevel.mean(),4), '#station17_without_nan_std:', round(df_s_17_sealevel.std(),4)); 
print('#station18_without_nan_mean:', round(df_s_18_sealevel.mean(),4), '#station18_without_nan_std:', round(df_s_18_sealevel.std(),4)); 
print('#station19_without_nan_mean:', round(df_s_19_sealevel.mean(),4), '#station19_without_nan_std:', round(df_s_19_sealevel.std(),4)); 
print('#station20_without_nan_mean:', round(df_s_20_sealevel.mean(),4), '#station20_without_nan_std:', round(df_s_20_sealevel.std(),4)); 

print('stat1_nan_as_mean:',round(df_s_1_sealevel_with_mean.mean(),4),'#stat1_nan_as_std:', round(df_s_1_sealevel_with_mean.std(),4));
print('stat2_nan_as_mean:',round(df_s_2_sealevel_with_mean.mean(),4),'#stat2_nan_as_std:', round(df_s_2_sealevel_with_mean.std(),4));
print('stat3_nan_as_mean:',round(df_s_3_sealevel_with_mean.mean(),4),'#stat3_nan_as_std:', round(df_s_3_sealevel_with_mean.std(),4));
print('stat4_nan_as_mean:',round(df_s_4_sealevel_with_mean.mean(),4),'#stat4_nan_as_std:', round(df_s_4_sealevel_with_mean.std(),4));
print('stat5_nan_as_mean:',round(df_s_5_sealevel_with_mean.mean(),4),'#stat5_nan_as_std:', round(df_s_5_sealevel_with_mean.std(),4));
print('stat6_nan_as_mean:',round(df_s_6_sealevel_with_mean.mean(),4),'#stat6_nan_as_std:', round(df_s_6_sealevel_with_mean.std(),4));
print('stat7_nan_as_mean:',round(df_s_7_sealevel_with_mean.mean(),4),'#stat7_nan_as_std:', round(df_s_7_sealevel_with_mean.std(),4));
print('stat8_nan_as_mean:',round(df_s_8_sealevel_with_mean.mean(),4),'#stat8_nan_as_std:', round(df_s_8_sealevel_with_mean.std(),4));
print('stat9_nan_as_mean:',round(df_s_9_sealevel_with_mean.mean(),4),'#stat9_nan_as_std:', round(df_s_9_sealevel_with_mean.std(),4));
print('stat10_nan_as_mean:',round(df_s_10_sealevel_with_mean.mean(),4),'#stat10_nan_as_std:', round(df_s_10_sealevel_with_mean.std(),4));
print('stat11_nan_as_mean:',round(df_s_11_sealevel_with_mean.mean(),4),'#stat11_nan_as_std:', round(df_s_11_sealevel_with_mean.std(),4));
print('stat12_nan_as_mean:',round(df_s_12_sealevel_with_mean.mean(),4),'#stat12_nan_as_std:', round(df_s_12_sealevel_with_mean.std(),4));
print('stat13_nan_as_mean:',round(df_s_13_sealevel_with_mean.mean(),4),'#stat13_nan_as_std:', round(df_s_13_sealevel_with_mean.std(),4));
print('stat14_nan_as_mean:',round(df_s_14_sealevel_with_mean.mean(),4),'#stat14_nan_as_std:', round(df_s_14_sealevel_with_mean.std(),4));
print('stat15_nan_as_mean:',round(df_s_15_sealevel_with_mean.mean(),4),'#stat15_nan_as_std:', round(df_s_15_sealevel_with_mean.std(),4));
print('stat16_nan_as_mean:',round(df_s_16_sealevel_with_mean.mean(),4),'#stat16_nan_as_std:', round(df_s_16_sealevel_with_mean.std(),4));
print('stat17_nan_as_mean:',round(df_s_17_sealevel_with_mean.mean(),4),'#stat17_nan_as_std:', round(df_s_17_sealevel_with_mean.std(),4));
print('stat18_nan_as_mean:',round(df_s_18_sealevel_with_mean.mean(),4),'#stat18_nan_as_std:', round(df_s_18_sealevel_with_mean.std(),4));
print('stat19_nan_as_mean:',round(df_s_19_sealevel_with_mean.mean(),4),'#stat19_nan_as_std:', round(df_s_19_sealevel_with_mean.std(),4));
print('stat20_nan_as_mean:',round(df_s_20_sealevel_with_mean.mean(),4),'#stat20_nan_as_std:', round(df_s_20_sealevel_with_mean.std(),4));
# Out:
# #station1_without_nan_mean: 30.016 #station1_without_nan_std: 0.2277
# #station2_without_nan_mean: 30.0136 #station2_without_nan_std: 0.217
# #station3_without_nan_mean: 30.001 #station3_without_nan_std: 0.1936
# #station4_without_nan_mean: 30.0092 #station4_without_nan_std: 0.1695
# #station5_without_nan_mean: nan #station5_without_nan_std: nan
# #station6_without_nan_mean: 30.0051 #station6_without_nan_std: 0.1706
# #station7_without_nan_mean: 30.003 #station7_without_nan_std: 0.201
# #station8_without_nan_mean: nan #station8_without_nan_std: nan
# #station9_without_nan_mean: 30.0016 #station9_without_nan_std: 0.2146
# #station10_without_nan_mean: 30.0522 #station10_without_nan_std: 0.13
# #station11_without_nan_mean: 30.0638 #station11_without_nan_std: 0.1291
# #station12_without_nan_mean: 30.0623 #station12_without_nan_std: 0.1327
# #station13_without_nan_mean: 29.9715 #station13_without_nan_std: 0.2089
# #station14_without_nan_mean: 30.0007 #station14_without_nan_std: 0.192
# ...

# %%
y1 = np.array([df_s_1_sealevel.mean(), df_s_2_sealevel.mean(), df_s_3_sealevel.mean(), df_s_4_sealevel.mean(), df_s_5_sealevel.mean(),
             df_s_6_sealevel.mean(), df_s_7_sealevel.mean(), df_s_8_sealevel.mean(), df_s_9_sealevel.mean(), df_s_10_sealevel.mean(), 
             df_s_11_sealevel.mean(), df_s_12_sealevel.mean(), df_s_13_sealevel.mean(), df_s_14_sealevel.mean(), df_s_15_sealevel.mean(),
             df_s_16_sealevel.mean(), df_s_17_sealevel.mean(), df_s_18_sealevel.mean(), df_s_19_sealevel.mean(), df_s_20_sealevel.mean()])

y2 = np.array([df_s_1_sealevel_with_mean.mean(), df_s_2_sealevel_with_mean.mean(), df_s_3_sealevel_with_mean.mean(), df_s_4_sealevel_with_mean.mean()
             ,df_s_5_sealevel_with_mean.mean(), df_s_6_sealevel_with_mean.mean(), df_s_7_sealevel_with_mean.mean(), df_s_8_sealevel_with_mean.mean()
             ,df_s_9_sealevel_with_mean.mean(), df_s_10_sealevel_with_mean.mean(), df_s_11_sealevel_with_mean.mean(), df_s_12_sealevel_with_mean.mean()
             ,df_s_13_sealevel_with_mean.mean(), df_s_14_sealevel_with_mean.mean(), df_s_15_sealevel_with_mean.mean(), df_s_16_sealevel_with_mean.mean()
             ,df_s_17_sealevel_with_mean.mean(),df_s_18_sealevel_with_mean.mean(),df_s_19_sealevel_with_mean.mean(),df_s_20_sealevel_with_mean.mean()])

plt.figure(figsize=(10,5))
plt.plot()
x = range(1, 21)
plt.xlabel('Station Number')
plt.ylabel('sealevel')
plt.bar(x, y1, color='y')
plt.bar(x, y2, color='r')
plt.show()

#### sealevel 에서는
# 이 Graph가 나타내는 바는, y1과 y2가 차이가 거의 없다는 것. 그래프에는 r color와 y color이 있는데, 하나만 보인다는 것은
# 우리가 그래프에서 눈으로 보이지 않는 정도의 차이가 나온다는 것이다, 즉 차이가 극히 작다고 판단 할 수 있다.
# Missing Values를 np.nan으로 바꾸고, 거기서 Mean 값을 구하여 np.nan에 대입하여도, 
# 따라서, 여기서는 Missing Value에 Mean값을 적용하여 회귀 분석에 적용 할 수있다고 판단된다. 
plt.figure(figsize=(12,6))
xticks = range(1,21)
plt.plot(xticks, y1, 'ro-', label='stations_without_nan_mean')
plt.plot(xticks, y2, 'bd:', label='stations_nan_as_mean')
plt.legend(loc=0)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
y3 = np.array([df_s_1_sealevel.std(), df_s_2_sealevel.std(), df_s_3_sealevel.std(), df_s_4_sealevel.std(), df_s_5_sealevel.std(),
             df_s_6_sealevel.std(), df_s_7_sealevel.std(), df_s_8_sealevel.std(), df_s_9_sealevel.std(), df_s_10_sealevel.std(), 
             df_s_11_sealevel.std(), df_s_12_sealevel.std(), df_s_13_sealevel.std(), df_s_14_sealevel.std(), df_s_15_sealevel.std(),
             df_s_16_sealevel.std(), df_s_17_sealevel.std(), df_s_18_sealevel.std(), df_s_19_sealevel.std(), df_s_20_sealevel.std()])

y4 = np.array([df_s_1_sealevel_with_mean.std(), df_s_2_sealevel_with_mean.std(), df_s_3_sealevel_with_mean.std(), df_s_4_sealevel_with_mean.std()
             ,df_s_5_sealevel_with_mean.std(), df_s_6_sealevel_with_mean.std(), df_s_7_sealevel_with_mean.std(), df_s_8_sealevel_with_mean.std()
             ,df_s_9_sealevel_with_mean.std(), df_s_10_sealevel_with_mean.std(), df_s_11_sealevel_with_mean.std(), df_s_12_sealevel_with_mean.std()
             ,df_s_13_sealevel_with_mean.std(), df_s_14_sealevel_with_mean.std(), df_s_15_sealevel_with_mean.std(), df_s_16_sealevel_with_mean.std()
             ,df_s_17_sealevel_with_mean.std(),df_s_18_sealevel_with_mean.std(),df_s_19_sealevel_with_mean.std(),df_s_20_sealevel_with_mean.std()])

plt.figure(figsize=(10,5))
plt.plot()
x = range(1, 21)
plt.xlabel('Station Number')
plt.ylabel('sealevel')
plt.bar(x, y3, color='r')
plt.bar(x, y4, color='g')
plt.show()

plt.figure(figsize=(12,6))
xticks = range(1,21)
plt.plot(xticks, y3, 'ro-', label='stations_without_nan_std')
plt.plot(xticks, y4, 'bd:', label='stations_nan_as_std')
plt.legend(loc=0)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
