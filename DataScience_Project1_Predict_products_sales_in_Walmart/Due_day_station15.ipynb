# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import KFold
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
weather = pd.read_csv("weather3_180703.csv")
weather['date'] = pd.to_datetime(weather["date"])
station = weather[weather['station_nbr'] == 15]

# %%
station['date'].count()
# Out:
# 1035

# %%
# ls == 모든 값이 0인 것

ls = []
ls1 = []
for i in station.columns:
    if station[i].count() == 0:
        ls.append(i)
    if station[i].isna().sum() != 0:
        ls1.append(i)
ls, ls1
# Out:
# ([], ['depart', 'sunrise', 'sunset', 'resultdir', 'daytime'])

# %%
for i in station.columns:
    count_null = station[i].isna().sum()
    print(i, ":", count_null, "(",round((count_null / len(station) * 100),2),"%",")")
# Out:
# station_nbr : 0 ( 0.0 % )
# date : 0 ( 0.0 % )
# tmax : 0 ( 0.0 % )
# tmin : 0 ( 0.0 % )
# tavg : 0 ( 0.0 % )
# depart : 31 ( 3.0 % )
# dewpoint : 0 ( 0.0 % )
# wetbulb : 0 ( 0.0 % )
# heat : 0 ( 0.0 % )
# cool : 0 ( 0.0 % )
# sunrise : 31 ( 3.0 % )
# sunset : 31 ( 3.0 % )
# codesum : 0 ( 0.0 % )
# snowfall : 0 ( 0.0 % )
# preciptotal : 0 ( 0.0 % )
# stnpressure : 0 ( 0.0 % )
# sealevel : 0 ( 0.0 % )
# resultspeed : 0 ( 0.0 % )
# resultdir : 6 ( 0.58 % )
# avgspeed : 0 ( 0.0 % )
# year : 0 ( 0.0 % )
# month : 0 ( 0.0 % )
# day : 0 ( 0.0 % )
# relative_humility : 0 ( 0.0 % )
# windchill : 0 ( 0.0 % )
# daytime : 31 ( 3.0 % )
# week7 : 0 ( 0.0 % )
# weekend : 0 ( 0.0 % )
# code_change : 0 ( 0.0 % )
# rainY : 0 ( 0.0 % )
# otherY : 0 ( 0.0 % )
# nothing : 0 ( 0.0 % )

# %%
train = pd.read_csv("train.csv")
train.date = pd.to_datetime(train.date)
train.tail()
# Out:
#               date  store_nbr  item_nbr  units
# 4617595 2014-10-31         45       107      0
# 4617596 2014-10-31         45       108      0
# 4617597 2014-10-31         45       109      0
# 4617598 2014-10-31         45       110      0
# 4617599 2014-10-31         45       111      0

# %%
key = pd.read_csv("key.csv")
station = station.merge(key)

# %%
station = station.merge(train)
station.tail()
# Out:
#        station_nbr       date  tmax  tmin  tavg  depart  dewpoint  wetbulb  \
# 97453           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 97454           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 97455           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 97456           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 97457           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
#
#        heat  cool  ...    daytime  week7 weekend  code_change  rainY  otherY  \
# 97453  24.0   0.0  ...      10.35      4       0            0      0       0
# 97454  24.0   0.0  ...      10.35      4       0            0      0       0
# 97455  24.0   0.0  ...      10.35      4       0            0      0       0
# 97456  24.0   0.0  ...      10.35      4       0            0      0       0
# 97457  24.0   0.0  ...      10.35      4       0            0      0       0
#
#        nothing  store_nbr  item_nbr  units
# 97453        1         19       107      0
# 97454        1         19       108      0
# 97455        1         19       109      0
# 97456        1         19       110      0
# 97457        1         19       111      0
#
# [5 rows x 35 columns]

# %%
station['log1p_units'] = np.log1p(station.units)

# %%
target1 = station['units']
target2 = station['log1p_units']

station.drop(columns=['units','log1p_units'],inplace=True)
station.tail()
# Out:
#        station_nbr       date  tmax  tmin  tavg  depart  dewpoint  wetbulb  \
# 97453           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 97454           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 97455           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 97456           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 97457           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
#
#        heat  cool    ...     windchill  daytime week7  weekend  code_change  \
# 97453  24.0   0.0    ...     44.429124    10.35     4        0            0
# 97454  24.0   0.0    ...     44.429124    10.35     4        0            0
# 97455  24.0   0.0    ...     44.429124    10.35     4        0            0
# 97456  24.0   0.0    ...     44.429124    10.35     4        0            0
# 97457  24.0   0.0    ...     44.429124    10.35     4        0            0
#
#        rainY  otherY  nothing  store_nbr  item_nbr
# 97453      0       0        1         19       107
# 97454      0       0        1         19       108
# 97455      0       0        1         19       109
# 97456      0       0        1         19       110
# 97457      0       0        1         19       111
#
# [5 rows x 34 columns]

# %%
df1 = pd.concat([station,target1], axis=1)
df2 = pd.concat([station,target2], axis=1)

# %%
df2.to_csv('station15.csv', sep=',', index=False)

# %%
if df2.columns.tolist() and ls:
    print('공통 변수 있음')
    print(df2.columns.tolist() and ls)
else:
    print('공통 변수 없음')
# Out:
# 공통 변수 없음

# %%
df2.columns
# Out:
# Index(['station_nbr', 'date', 'tmax', 'tmin', 'tavg', 'depart', 'dewpoint',
#        'wetbulb', 'heat', 'cool', 'sunrise', 'sunset', 'codesum', 'snowfall',
#        'preciptotal', 'stnpressure', 'sealevel', 'resultspeed', 'resultdir',
#        'avgspeed', 'year', 'month', 'day', 'relative_humility', 'windchill',
#        'daytime', 'week7', 'weekend', 'code_change', 'rainY', 'otherY',
#        'nothing', 'store_nbr', 'item_nbr', 'log1p_units'],
#       dtype='object')

# %%
ls, ls1
# Out:
# ([], ['depart', 'sunrise', 'sunset', 'resultdir', 'daytime'])

# %% [markdown]
# ### 1. 변수변환: df2 (log1p_units)

# %%
all_var = 'log1p_units ~ scale(tmax) + scale(tmin) + scale(tavg) + scale(depart) + scale(dewpoint) + scale(wetbulb) + scale(heat) + scale(cool)\
                            + scale(sunrise) + scale(sunset) + scale(snowfall) + scale(preciptotal) + scale(stnpressure) + scale(sealevel) + scale(resultspeed)  \
                            + C(resultdir) + scale(avgspeed) + C(year) + C(month) + scale(relative_humility) + scale(windchill) + C(weekend) \
                            + C(rainY) + C(store_nbr) + C(item_nbr) + C(daytime) + 0'

# %%
model2 = sm.OLS.from_formula('log1p_units ~ scale(tmax) + scale(tmin) + scale(tavg) + scale(dewpoint) + scale(wetbulb) + scale(heat) + scale(cool)\
                            + scale(snowfall) + scale(preciptotal) + scale(stnpressure) + scale(sealevel) + scale(resultspeed)  \
                          + scale(avgspeed) + C(year) + C(month) + scale(relative_humility) + scale(windchill) + C(weekend) \
                            + C(rainY) + C(store_nbr) + C(item_nbr) + 0', data = df2)
result2 = model2.fit()
print(result2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log1p_units   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     3871.
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:47:09   Log-Likelihood:                 47966.
# No. Observations:               97458   AIC:                        -9.565e+04
# Df Residuals:                   97318   BIC:                        -9.432e+04
# Df Model:                         139
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# C(year)[2012]                0.0007      0.006      0.117      0.907      -0.010       0.012
# C(year)[2013]                0.0010      0.006      0.178      0.858      -0.010       0.012
# C(year)[2014]               -0.0126      0.006     -2.197      0.028      -0.024      -0.001
# C(month)[T.2]                0.0006      0.002      0.260      0.795      -0.004       0.005
# C(month)[T.3]               -0.0075      0.002     -3.033      0.002      -0.012      -0.003
# C(month)[T.4]               -0.0088      0.003     -3.053      0.002      -0.014      -0.003
# C(month)[T.5]               -0.0047      0.003     -1.407      0.160      -0.011       0.002
# C(month)[T.6]                0.0002      0.004      0.060      0.952      -0.007       0.008
# C(month)[T.7]               -0.0029      0.004     -0.692      0.489      -0.011       0.005
# C(month)[T.8]                0.0036      0.004      0.902      0.367      -0.004       0.011
# C(month)[T.9]                0.0019      0.004      0.543      0.587      -0.005       0.009
# C(month)[T.10]              -0.0046      0.003     -1.504      0.133      -0.011       0.001
# C(month)[T.11]              -0.0071      0.003     -2.545      0.011      -0.013      -0.002
# C(month)[T.12]               0.0013      0.003      0.497      0.619      -0.004       0.007
# C(weekend)[T.1]              0.0104      0.001      9.873      0.000       0.008       0.012
# C(rainY)[T.1]                0.0031      0.001      2.536      0.011       0.001       0.005
# C(item_nbr)[T.2]          2.501e-15      0.007   3.54e-13      1.000      -0.014       0.014
# C(item_nbr)[T.3]          3.222e-15      0.007   4.56e-13      1.000      -0.014       0.014
# C(item_nbr)[T.4]          5.069e-15      0.007   7.18e-13      1.000      -0.014       0.014
# C(item_nbr)[T.5]         -3.671e-15      0.007   -5.2e-13      1.000      -0.014       0.014
# C(item_nbr)[T.6]           4.34e-15      0.007   6.14e-13      1.000      -0.014       0.014
# C(item_nbr)[T.7]         -4.724e-15      0.007  -6.69e-13      1.000      -0.014       0.014
# C(item_nbr)[T.8]         -7.337e-16      0.007  -1.04e-13      1.000      -0.014       0.014
# C(item_nbr)[T.9]          3.591e-15      0.007   5.08e-13      1.000      -0.014       0.014
# C(item_nbr)[T.10]         7.944e-15      0.007   1.12e-12      1.000      -0.014       0.014
# C(item_nbr)[T.11]         3.089e-15      0.007   4.37e-13      1.000      -0.014       0.014
# C(item_nbr)[T.12]         9.221e-16      0.007   1.31e-13      1.000      -0.014       0.014
# C(item_nbr)[T.13]         1.436e-15      0.007   2.03e-13      1.000      -0.014       0.014
# C(item_nbr)[T.14]         1.856e-15      0.007   2.63e-13      1.000      -0.014       0.014
# C(item_nbr)[T.15]            0.2620      0.007     37.081      0.000       0.248       0.276
# C(item_nbr)[T.16]            2.8635      0.007    405.327      0.000       2.850       2.877
# C(item_nbr)[T.17]          3.25e-15      0.007    4.6e-13      1.000      -0.014       0.014
# C(item_nbr)[T.18]         1.959e-15      0.007   2.77e-13      1.000      -0.014       0.014
# C(item_nbr)[T.19]         9.291e-16      0.007   1.32e-13      1.000      -0.014       0.014
# C(item_nbr)[T.20]        -5.338e-16      0.007  -7.56e-14      1.000      -0.014       0.014
# C(item_nbr)[T.21]           1.2e-15      0.007    1.7e-13      1.000      -0.014       0.014
# C(item_nbr)[T.22]         2.757e-15      0.007    3.9e-13      1.000      -0.014       0.014
# C(item_nbr)[T.23]        -5.392e-16      0.007  -7.63e-14      1.000      -0.014       0.014
# C(item_nbr)[T.24]        -3.251e-16      0.007   -4.6e-14      1.000      -0.014       0.014
# C(item_nbr)[T.25]        -1.218e-15      0.007  -1.72e-13      1.000      -0.014       0.014
# C(item_nbr)[T.26]          2.04e-15      0.007   2.89e-13      1.000      -0.014       0.014
# C(item_nbr)[T.27]        -6.679e-15      0.007  -9.45e-13      1.000      -0.014       0.014
# C(item_nbr)[T.28]         1.066e-15      0.007   1.51e-13      1.000      -0.014       0.014
# C(item_nbr)[T.29]         1.728e-15      0.007   2.45e-13      1.000      -0.014       0.014
# C(item_nbr)[T.30]         2.894e-15      0.007    4.1e-13      1.000      -0.014       0.014
# C(item_nbr)[T.31]         1.719e-16      0.007   2.43e-14      1.000      -0.014       0.014
# C(item_nbr)[T.32]         1.558e-15      0.007    2.2e-13      1.000      -0.014       0.014
# C(item_nbr)[T.33]        -5.368e-15      0.007   -7.6e-13      1.000      -0.014       0.014
# C(item_nbr)[T.34]        -1.006e-15      0.007  -1.42e-13      1.000      -0.014       0.014
# C(item_nbr)[T.35]        -8.896e-16      0.007  -1.26e-13      1.000      -0.014       0.014
# C(item_nbr)[T.36]         1.672e-15      0.007   2.37e-13      1.000      -0.014       0.014
# C(item_nbr)[T.37]        -4.039e-16      0.007  -5.72e-14      1.000      -0.014       0.014
# C(item_nbr)[T.38]        -1.945e-15      0.007  -2.75e-13      1.000      -0.014       0.014
# C(item_nbr)[T.39]            0.1216      0.007     17.207      0.000       0.108       0.135
# C(item_nbr)[T.40]         1.645e-15      0.007   2.33e-13      1.000      -0.014       0.014
# C(item_nbr)[T.41]         9.567e-16      0.007   1.35e-13      1.000      -0.014       0.014
# C(item_nbr)[T.42]         3.088e-15      0.007   4.37e-13      1.000      -0.014       0.014
# C(item_nbr)[T.43]        -3.481e-16      0.007  -4.93e-14      1.000      -0.014       0.014
# C(item_nbr)[T.44]         8.741e-16      0.007   1.24e-13      1.000      -0.014       0.014
# C(item_nbr)[T.45]        -1.321e-16      0.007  -1.87e-14      1.000      -0.014       0.014
# C(item_nbr)[T.46]        -1.832e-15      0.007  -2.59e-13      1.000      -0.014       0.014
# C(item_nbr)[T.47]         1.072e-15      0.007   1.52e-13      1.000      -0.014       0.014
# C(item_nbr)[T.48]         1.641e-15      0.007   2.32e-13      1.000      -0.014       0.014
# C(item_nbr)[T.49]         1.001e-15      0.007   1.42e-13      1.000      -0.014       0.014
# C(item_nbr)[T.50]        -3.809e-15      0.007  -5.39e-13      1.000      -0.014       0.014
# C(item_nbr)[T.51]         5.325e-16      0.007   7.54e-14      1.000      -0.014       0.014
# C(item_nbr)[T.52]        -6.239e-16      0.007  -8.83e-14      1.000      -0.014       0.014
# C(item_nbr)[T.53]         1.425e-15      0.007   2.02e-13      1.000      -0.014       0.014
# C(item_nbr)[T.54]          9.82e-16      0.007   1.39e-13      1.000      -0.014       0.014
# C(item_nbr)[T.55]        -5.388e-16      0.007  -7.63e-14      1.000      -0.014       0.014
# C(item_nbr)[T.56]        -7.402e-16      0.007  -1.05e-13      1.000      -0.014       0.014
# C(item_nbr)[T.57]         8.041e-16      0.007   1.14e-13      1.000      -0.014       0.014
# C(item_nbr)[T.58]         2.515e-15      0.007   3.56e-13      1.000      -0.014       0.014
# C(item_nbr)[T.59]         -3.83e-16      0.007  -5.42e-14      1.000      -0.014       0.014
# C(item_nbr)[T.60]          4.72e-17      0.007   6.68e-15      1.000      -0.014       0.014
# C(item_nbr)[T.61]         1.459e-15      0.007   2.07e-13      1.000      -0.014       0.014
# C(item_nbr)[T.62]         1.267e-15      0.007   1.79e-13      1.000      -0.014       0.014
# C(item_nbr)[T.63]         2.399e-15      0.007    3.4e-13      1.000      -0.014       0.014
# C(item_nbr)[T.64]         1.871e-15      0.007   2.65e-13      1.000      -0.014       0.014
# C(item_nbr)[T.65]         2.683e-15      0.007    3.8e-13      1.000      -0.014       0.014
# C(item_nbr)[T.66]        -1.423e-15      0.007  -2.01e-13      1.000      -0.014       0.014
# C(item_nbr)[T.67]        -6.308e-16      0.007  -8.93e-14      1.000      -0.014       0.014
# C(item_nbr)[T.68]         1.096e-15      0.007   1.55e-13      1.000      -0.014       0.014
# C(item_nbr)[T.69]            0.5403      0.007     76.485      0.000       0.526       0.554
# C(item_nbr)[T.70]         1.586e-16      0.007   2.25e-14      1.000      -0.014       0.014
# C(item_nbr)[T.71]         1.366e-15      0.007   1.93e-13      1.000      -0.014       0.014
# C(item_nbr)[T.72]        -2.106e-15      0.007  -2.98e-13      1.000      -0.014       0.014
# C(item_nbr)[T.73]        -7.475e-16      0.007  -1.06e-13      1.000      -0.014       0.014
# C(item_nbr)[T.74]         3.697e-16      0.007   5.23e-14      1.000      -0.014       0.014
# C(item_nbr)[T.75]            0.2948      0.007     41.722      0.000       0.281       0.309
# C(item_nbr)[T.76]        -7.911e-16      0.007  -1.12e-13      1.000      -0.014       0.014
# C(item_nbr)[T.77]        -3.969e-16      0.007  -5.62e-14      1.000      -0.014       0.014
# C(item_nbr)[T.78]         5.017e-17      0.007    7.1e-15      1.000      -0.014       0.014
# C(item_nbr)[T.79]         5.466e-16      0.007   7.74e-14      1.000      -0.014       0.014
# C(item_nbr)[T.80]        -1.083e-15      0.007  -1.53e-13      1.000      -0.014       0.014
# C(item_nbr)[T.81]         2.421e-17      0.007   3.43e-15      1.000      -0.014       0.014
# C(item_nbr)[T.82]         2.827e-16      0.007      4e-14      1.000      -0.014       0.014
# C(item_nbr)[T.83]            2.2519      0.007    318.757      0.000       2.238       2.266
# C(item_nbr)[T.84]        -9.928e-16      0.007  -1.41e-13      1.000      -0.014       0.014
# C(item_nbr)[T.85]         5.442e-16      0.007    7.7e-14      1.000      -0.014       0.014
# C(item_nbr)[T.86]         1.007e-15      0.007   1.43e-13      1.000      -0.014       0.014
# C(item_nbr)[T.87]        -9.284e-16      0.007  -1.31e-13      1.000      -0.014       0.014
# C(item_nbr)[T.88]            0.0838      0.007     11.867      0.000       0.070       0.098
# C(item_nbr)[T.89]        -3.772e-16      0.007  -5.34e-14      1.000      -0.014       0.014
# C(item_nbr)[T.90]        -8.374e-16      0.007  -1.19e-13      1.000      -0.014       0.014
# C(item_nbr)[T.91]          6.42e-16      0.007   9.09e-14      1.000      -0.014       0.014
# C(item_nbr)[T.92]        -5.968e-16      0.007  -8.45e-14      1.000      -0.014       0.014
# C(item_nbr)[T.93]            0.2867      0.007     40.588      0.000       0.273       0.301
# C(item_nbr)[T.94]         8.289e-17      0.007   1.17e-14      1.000      -0.014       0.014
# C(item_nbr)[T.95]        -1.167e-15      0.007  -1.65e-13      1.000      -0.014       0.014
# C(item_nbr)[T.96]         7.851e-16      0.007   1.11e-13      1.000      -0.014       0.014
# C(item_nbr)[T.97]         1.253e-15      0.007   1.77e-13      1.000      -0.014       0.014
# C(item_nbr)[T.98]         4.244e-17      0.007   6.01e-15      1.000      -0.014       0.014
# C(item_nbr)[T.99]        -1.362e-15      0.007  -1.93e-13      1.000      -0.014       0.014
# C(item_nbr)[T.100]       -6.794e-16      0.007  -9.62e-14      1.000      -0.014       0.014
# C(item_nbr)[T.101]        2.792e-16      0.007   3.95e-14      1.000      -0.014       0.014
# C(item_nbr)[T.102]       -1.402e-15      0.007  -1.98e-13      1.000      -0.014       0.014
# C(item_nbr)[T.103]       -4.356e-16      0.007  -6.17e-14      1.000      -0.014       0.014
# C(item_nbr)[T.104]       -7.379e-16      0.007  -1.04e-13      1.000      -0.014       0.014
# C(item_nbr)[T.105]        2.525e-16      0.007   3.57e-14      1.000      -0.014       0.014
# C(item_nbr)[T.106]        6.067e-16      0.007   8.59e-14      1.000      -0.014       0.014
# C(item_nbr)[T.107]        4.345e-16      0.007   6.15e-14      1.000      -0.014       0.014
# C(item_nbr)[T.108]       -2.029e-17      0.007  -2.87e-15      1.000      -0.014       0.014
# C(item_nbr)[T.109]       -3.268e-16      0.007  -4.63e-14      1.000      -0.014       0.014
# C(item_nbr)[T.110]       -6.395e-16      0.007  -9.05e-14      1.000      -0.014       0.014
# C(item_nbr)[T.111]       -1.063e-15      0.007   -1.5e-13      1.000      -0.014       0.014
# scale(tmax)                 -0.0053      0.007     -0.760      0.447      -0.019       0.008
# scale(tmin)                  0.0012      0.006      0.213      0.832      -0.010       0.012
# scale(tavg)                 -0.0023      0.006     -0.361      0.718      -0.015       0.010
# scale(dewpoint)             -0.0022      0.011     -0.201      0.841      -0.023       0.019
# scale(wetbulb)               0.0255      0.009      2.852      0.004       0.008       0.043
# scale(heat)                  0.0149      0.006      2.619      0.009       0.004       0.026
# scale(cool)                 -0.0019      0.001     -1.773      0.076      -0.004       0.000
# scale(snowfall)             -0.0013      0.001     -2.349      0.019      -0.002      -0.000
# scale(preciptotal)           0.0007      0.001      1.219      0.223      -0.000       0.002
# scale(stnpressure)           0.0012      0.004      0.296      0.767      -0.007       0.009
# scale(sealevel)             -0.0007      0.004     -0.179      0.858      -0.008       0.007
# scale(resultspeed)           0.0004      0.002      0.190      0.850      -0.003       0.004
# scale(avgspeed)             -0.0015      0.002     -0.631      0.528      -0.006       0.003
# scale(relative_humility)    -0.0036      0.004     -0.988      0.323      -0.011       0.004
# scale(windchill)            -0.0062      0.009     -0.680      0.496      -0.024       0.012
# ==============================================================================
# Omnibus:                   137997.879   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         97782031.597
# Skew:                           8.100   Prob(JB):                         0.00
# Kurtosis:                     157.329   Cond. No.                     2.25e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.45e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### 2. 변수변환 : df2 (log1p_units) + 아웃라이어 제거

# %%
# 아웃라이어 제거
# Cook's distance > 2 인 값 제거
influence = result2.get_influence()
cooks_d2, pvals = influence.cooks_distance
fox_cr = 4 / (len(df2) - 2)
idx_outlier = np.where(cooks_d2 > fox_cr)[0]
len(idx_outlier)
# Out:
# 2648

# %%
idx = list(set(range(len(df2))).difference(idx_outlier))
df2_1 = df2.iloc[idx, :].reset_index(drop=True)
df2_1
# Out:
#        station_nbr       date  tmax  tmin  tavg  depart  dewpoint  wetbulb  \
# 0               15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 1               15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 2               15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 3               15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 4               15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 5               15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 6               15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 7               15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 8               15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 9               15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 10              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 11              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 12              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 13              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 14              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 15              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 16              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 17              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 18              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 19              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 20              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 21              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 22              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 23              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 24              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 25              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 26              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 27              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 28              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# 29              15 2012-01-01  48.0  26.0  37.0    16.0      35.0     38.0
# ...            ...        ...   ...   ...   ...     ...       ...      ...
# 94780           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94781           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94782           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94783           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94784           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94785           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94786           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94787           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94788           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94789           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94790           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94791           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94792           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94793           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94794           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94795           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94796           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94797           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94798           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94799           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94800           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94801           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94802           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94803           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94804           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94805           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94806           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94807           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94808           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
# 94809           15 2014-10-31  50.0  32.0  41.0    -2.0      34.0     38.0
#
#        heat  cool     ...       daytime  week7 weekend  code_change  rainY  \
# 0      28.0   0.0     ...          9.05      6       1            2      1
# 1      28.0   0.0     ...          9.05      6       1            2      1
# 2      28.0   0.0     ...          9.05      6       1            2      1
# 3      28.0   0.0     ...          9.05      6       1            2      1
# 4      28.0   0.0     ...          9.05      6       1            2      1
# 5      28.0   0.0     ...          9.05      6       1            2      1
# 6      28.0   0.0     ...          9.05      6       1            2      1
# 7      28.0   0.0     ...          9.05      6       1            2      1
# 8      28.0   0.0     ...          9.05      6       1            2      1
# 9      28.0   0.0     ...          9.05      6       1            2      1
# 10     28.0   0.0     ...          9.05      6       1            2      1
# 11     28.0   0.0     ...          9.05      6       1            2      1
# 12     28.0   0.0     ...          9.05      6       1            2      1
# 13     28.0   0.0     ...          9.05      6       1            2      1
# 14     28.0   0.0     ...          9.05      6       1            2      1
# 15     28.0   0.0     ...          9.05      6       1            2      1
# 16     28.0   0.0     ...          9.05      6       1            2      1
# 17     28.0   0.0     ...          9.05      6       1            2      1
# 18     28.0   0.0     ...          9.05      6       1            2      1
# 19     28.0   0.0     ...          9.05      6       1            2      1
# 20     28.0   0.0     ...          9.05      6       1            2      1
# 21     28.0   0.0     ...          9.05      6       1            2      1
# 22     28.0   0.0     ...          9.05      6       1            2      1
# 23     28.0   0.0     ...          9.05      6       1            2      1
# 24     28.0   0.0     ...          9.05      6       1            2      1
# 25     28.0   0.0     ...          9.05      6       1            2      1
# 26     28.0   0.0     ...          9.05      6       1            2      1
# 27     28.0   0.0     ...          9.05      6       1            2      1
# 28     28.0   0.0     ...          9.05      6       1            2      1
# 29     28.0   0.0     ...          9.05      6       1            2      1
# ...     ...   ...     ...           ...    ...     ...          ...    ...
# 94780  24.0   0.0     ...         10.35      4       0            0      0
# 94781  24.0   0.0     ...         10.35      4       0            0      0
# 94782  24.0   0.0     ...         10.35      4       0            0      0
# 94783  24.0   0.0     ...         10.35      4       0            0      0
# 94784  24.0   0.0     ...         10.35      4       0            0      0
# 94785  24.0   0.0     ...         10.35      4       0            0      0
# 94786  24.0   0.0     ...         10.35      4       0            0      0
# 94787  24.0   0.0     ...         10.35      4       0            0      0
# 94788  24.0   0.0     ...         10.35      4       0            0      0
# 94789  24.0   0.0     ...         10.35      4       0            0      0
# 94790  24.0   0.0     ...         10.35      4       0            0      0
# 94791  24.0   0.0     ...         10.35      4       0            0      0
# 94792  24.0   0.0     ...         10.35      4       0            0      0
# 94793  24.0   0.0     ...         10.35      4       0            0      0
# 94794  24.0   0.0     ...         10.35      4       0            0      0
# 94795  24.0   0.0     ...         10.35      4       0            0      0
# 94796  24.0   0.0     ...         10.35      4       0            0      0
# 94797  24.0   0.0     ...         10.35      4       0            0      0
# 94798  24.0   0.0     ...         10.35      4       0            0      0
# 94799  24.0   0.0     ...         10.35      4       0            0      0
# 94800  24.0   0.0     ...         10.35      4       0            0      0
# 94801  24.0   0.0     ...         10.35      4       0            0      0
# 94802  24.0   0.0     ...         10.35      4       0            0      0
# 94803  24.0   0.0     ...         10.35      4       0            0      0
# 94804  24.0   0.0     ...         10.35      4       0            0      0
# 94805  24.0   0.0     ...         10.35      4       0            0      0
# 94806  24.0   0.0     ...         10.35      4       0            0      0
# 94807  24.0   0.0     ...         10.35      4       0            0      0
# 94808  24.0   0.0     ...         10.35      4       0            0      0
# 94809  24.0   0.0     ...         10.35      4       0            0      0
#
#        otherY  nothing  store_nbr  item_nbr  log1p_units
# 0           1        0         19         1     0.000000
# 1           1        0         19         2     0.000000
# 2           1        0         19         3     0.000000
# 3           1        0         19         4     0.000000
# 4           1        0         19         5     0.000000
# 5           1        0         19         6     0.000000
# 6           1        0         19         7     0.000000
# 7           1        0         19         8     0.000000
# 8           1        0         19         9     0.000000
# 9           1        0         19        10     0.000000
# 10          1        0         19        11     0.000000
# 11          1        0         19        12     0.000000
# 12          1        0         19        13     0.000000
# 13          1        0         19        14     0.000000
# 14          1        0         19        15     0.000000
# 15          1        0         19        16     3.091042
# 16          1        0         19        17     0.000000
# 17          1        0         19        18     0.000000
# 18          1        0         19        19     0.000000
# 19          1        0         19        20     0.000000
# 20          1        0         19        21     0.000000
# 21          1        0         19        22     0.000000
# 22          1        0         19        23     0.000000
# 23          1        0         19        24     0.000000
# 24          1        0         19        25     0.000000
# 25          1        0         19        26     0.000000
# 26          1        0         19        27     0.000000
# 27          1        0         19        28     0.000000
# 28          1        0         19        29     0.000000
# 29          1        0         19        30     0.000000
# ...       ...      ...        ...       ...          ...
# 94780       0        1         19        81     0.000000
# 94781       0        1         19        82     0.000000
# 94782       0        1         19        84     0.000000
# 94783       0        1         19        85     0.000000
# 94784       0        1         19        86     0.000000
# 94785       0        1         19        87     0.000000
# 94786       0        1         19        88     0.000000
# 94787       0        1         19        89     0.000000
# 94788       0        1         19        90     0.000000
# 94789       0        1         19        91     0.000000
# 94790       0        1         19        92     0.000000
# 94791       0        1         19        93     0.000000
# 94792       0        1         19        94     0.000000
# 94793       0        1         19        95     0.000000
# 94794       0        1         19        96     0.000000
# 94795       0        1         19        97     0.000000
# 94796       0        1         19        98     0.000000
# 94797       0        1         19        99     0.000000
# 94798       0        1         19       100     0.000000
# 94799       0        1         19       101     0.000000
# 94800       0        1         19       102     0.000000
# 94801       0        1         19       103     0.000000
# 94802       0        1         19       104     0.000000
# 94803       0        1         19       105     0.000000
# 94804       0        1         19       106     0.000000
# 94805       0        1         19       107     0.000000
# 94806       0        1         19       108     0.000000
# 94807       0        1         19       109     0.000000
# 94808       0        1         19       110     0.000000
# 94809       0        1         19       111     0.000000
#
# [94810 rows x 35 columns]

# %%
# OLS - df2_1
model2_1 = sm.OLS.from_formula('log1p_units ~ scale(tmax) + scale(tmin) + scale(tavg) + scale(dewpoint) + scale(wetbulb) + scale(heat) + scale(cool)\
                            + scale(snowfall) + scale(preciptotal) + scale(stnpressure) + scale(sealevel) + scale(resultspeed)  \
                          + scale(avgspeed) + C(year) + C(month) + scale(relative_humility) + scale(windchill) + C(weekend) \
                            + C(rainY) + C(store_nbr) + C(item_nbr) + 0', data = df2_1)
result2_1 = model2_1.fit()
print(result2_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log1p_units   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 1.560e+05
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):               0.00
# Time:                        12:20:05   Log-Likelihood:             2.5785e+05
# No. Observations:               94810   AIC:                        -5.154e+05
# Df Residuals:                   94670   BIC:                        -5.141e+05
# Df Model:                         139
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# C(year)[2012]                0.0003      0.001      0.542      0.588      -0.001       0.002
# C(year)[2013]                0.0002      0.001      0.304      0.761      -0.001       0.001
# C(year)[2014]               -0.0001      0.001     -0.208      0.835      -0.001       0.001
# C(month)[T.2]               -0.0004      0.000     -1.341      0.180      -0.001       0.000
# C(month)[T.3]               -0.0005      0.000     -1.731      0.084      -0.001    6.22e-05
# C(month)[T.4]               -0.0007      0.000     -2.206      0.027      -0.001   -7.73e-05
# C(month)[T.5]               -0.0008      0.000     -2.107      0.035      -0.001   -5.38e-05
# C(month)[T.6]               -0.0006      0.000     -1.521      0.128      -0.001       0.000
# C(month)[T.7]               -0.0008      0.000     -1.768      0.077      -0.002    8.65e-05
# C(month)[T.8]             -6.91e-05      0.000     -0.158      0.874      -0.001       0.001
# C(month)[T.9]            -5.111e-05      0.000     -0.133      0.894      -0.001       0.001
# C(month)[T.10]              -0.0006      0.000     -1.829      0.067      -0.001     4.4e-05
# C(month)[T.11]              -0.0002      0.000     -0.694      0.487      -0.001       0.000
# C(month)[T.12]              -0.0002      0.000     -0.627      0.531      -0.001       0.000
# C(weekend)[T.1]              0.0006      0.000      5.000      0.000       0.000       0.001
# C(rainY)[T.1]                0.0001      0.000      1.128      0.259      -0.000       0.000
# C(item_nbr)[T.2]          -4.11e-16      0.001   -5.4e-13      1.000      -0.001       0.001
# C(item_nbr)[T.3]         -1.072e-15      0.001  -1.41e-12      1.000      -0.001       0.001
# C(item_nbr)[T.4]         -8.614e-16      0.001  -1.13e-12      1.000      -0.001       0.001
# C(item_nbr)[T.5]         -1.118e-15      0.001  -1.47e-12      1.000      -0.001       0.001
# C(item_nbr)[T.6]         -6.362e-16      0.001  -8.35e-13      1.000      -0.001       0.001
# C(item_nbr)[T.7]          -8.39e-16      0.001   -1.1e-12      1.000      -0.001       0.001
# C(item_nbr)[T.8]         -3.065e-16      0.001  -4.02e-13      1.000      -0.001       0.001
# C(item_nbr)[T.9]         -1.084e-15      0.001  -1.42e-12      1.000      -0.001       0.001
# C(item_nbr)[T.10]        -7.032e-16      0.001  -9.23e-13      1.000      -0.001       0.001
# C(item_nbr)[T.11]        -1.261e-15      0.001  -1.66e-12      1.000      -0.001       0.001
# C(item_nbr)[T.12]        -1.441e-15      0.001  -1.89e-12      1.000      -0.001       0.001
# C(item_nbr)[T.13]        -2.275e-15      0.001  -2.99e-12      1.000      -0.001       0.001
# C(item_nbr)[T.14]        -1.625e-15      0.001  -2.13e-12      1.000      -0.001       0.001
# C(item_nbr)[T.15]         5.101e-05      0.001      0.064      0.949      -0.002       0.002
# C(item_nbr)[T.16]            2.8483      0.001   3013.181      0.000       2.846       2.850
# C(item_nbr)[T.17]        -8.323e-16      0.001  -1.09e-12      1.000      -0.001       0.001
# C(item_nbr)[T.18]        -1.407e-15      0.001  -1.85e-12      1.000      -0.001       0.001
# C(item_nbr)[T.19]         -1.17e-15      0.001  -1.54e-12      1.000      -0.001       0.001
# C(item_nbr)[T.20]        -3.243e-16      0.001  -4.26e-13      1.000      -0.001       0.001
# C(item_nbr)[T.21]         3.392e-16      0.001   4.45e-13      1.000      -0.001       0.001
# C(item_nbr)[T.22]        -8.427e-16      0.001  -1.11e-12      1.000      -0.001       0.001
# C(item_nbr)[T.23]        -9.541e-16      0.001  -1.25e-12      1.000      -0.001       0.001
# C(item_nbr)[T.24]        -7.319e-16      0.001  -9.61e-13      1.000      -0.001       0.001
# C(item_nbr)[T.25]        -6.819e-16      0.001  -8.95e-13      1.000      -0.001       0.001
# C(item_nbr)[T.26]        -5.775e-16      0.001  -7.58e-13      1.000      -0.001       0.001
# C(item_nbr)[T.27]        -8.389e-16      0.001   -1.1e-12      1.000      -0.001       0.001
# C(item_nbr)[T.28]        -8.572e-16      0.001  -1.13e-12      1.000      -0.001       0.001
# C(item_nbr)[T.29]        -7.198e-16      0.001  -9.45e-13      1.000      -0.001       0.001
# C(item_nbr)[T.30]        -6.094e-16      0.001     -8e-13      1.000      -0.001       0.001
# C(item_nbr)[T.31]         -2.29e-17      0.001  -3.01e-14      1.000      -0.001       0.001
# C(item_nbr)[T.32]        -5.677e-16      0.001  -7.45e-13      1.000      -0.001       0.001
# C(item_nbr)[T.33]        -8.539e-16      0.001  -1.12e-12      1.000      -0.001       0.001
# C(item_nbr)[T.34]        -9.116e-16      0.001   -1.2e-12      1.000      -0.001       0.001
# C(item_nbr)[T.35]        -7.183e-16      0.001  -9.43e-13      1.000      -0.001       0.001
# C(item_nbr)[T.36]        -4.197e-16      0.001  -5.51e-13      1.000      -0.001       0.001
# C(item_nbr)[T.37]        -9.993e-16      0.001  -1.31e-12      1.000      -0.001       0.001
# C(item_nbr)[T.38]        -7.855e-16      0.001  -1.03e-12      1.000      -0.001       0.001
# C(item_nbr)[T.39]         4.175e-05      0.001      0.053      0.957      -0.001       0.002
# C(item_nbr)[T.40]        -5.853e-16      0.001  -7.69e-13      1.000      -0.001       0.001
# C(item_nbr)[T.41]        -8.924e-16      0.001  -1.17e-12      1.000      -0.001       0.001
# C(item_nbr)[T.42]        -5.464e-16      0.001  -7.17e-13      1.000      -0.001       0.001
# C(item_nbr)[T.43]        -9.187e-16      0.001  -1.21e-12      1.000      -0.001       0.001
# C(item_nbr)[T.44]        -8.942e-16      0.001  -1.17e-12      1.000      -0.001       0.001
# C(item_nbr)[T.45]        -7.261e-16      0.001  -9.53e-13      1.000      -0.001       0.001
# C(item_nbr)[T.46]        -6.194e-16      0.001  -8.13e-13      1.000      -0.001       0.001
# C(item_nbr)[T.47]        -7.927e-16      0.001  -1.04e-12      1.000      -0.001       0.001
# C(item_nbr)[T.48]         -6.82e-16      0.001  -8.95e-13      1.000      -0.001       0.001
# C(item_nbr)[T.49]        -7.712e-16      0.001  -1.01e-12      1.000      -0.001       0.001
# C(item_nbr)[T.50]        -9.413e-16      0.001  -1.24e-12      1.000      -0.001       0.001
# C(item_nbr)[T.51]        -8.551e-16      0.001  -1.12e-12      1.000      -0.001       0.001
# C(item_nbr)[T.52]        -1.047e-15      0.001  -1.37e-12      1.000      -0.001       0.001
# C(item_nbr)[T.53]        -7.148e-16      0.001  -9.39e-13      1.000      -0.001       0.001
# C(item_nbr)[T.54]        -7.152e-16      0.001  -9.39e-13      1.000      -0.001       0.001
# C(item_nbr)[T.55]        -5.683e-16      0.001  -7.46e-13      1.000      -0.001       0.001
# C(item_nbr)[T.56]        -8.625e-16      0.001  -1.13e-12      1.000      -0.001       0.001
# C(item_nbr)[T.57]        -8.925e-16      0.001  -1.17e-12      1.000      -0.001       0.001
# C(item_nbr)[T.58]        -6.204e-16      0.001  -8.15e-13      1.000      -0.001       0.001
# C(item_nbr)[T.59]        -7.389e-16      0.001   -9.7e-13      1.000      -0.001       0.001
# C(item_nbr)[T.60]        -8.093e-16      0.001  -1.06e-12      1.000      -0.001       0.001
# C(item_nbr)[T.61]        -9.652e-16      0.001  -1.27e-12      1.000      -0.001       0.001
# C(item_nbr)[T.62]        -5.619e-16      0.001  -7.38e-13      1.000      -0.001       0.001
# C(item_nbr)[T.63]        -6.496e-16      0.001  -8.53e-13      1.000      -0.001       0.001
# C(item_nbr)[T.64]        -7.532e-16      0.001  -9.89e-13      1.000      -0.001       0.001
# C(item_nbr)[T.65]        -6.117e-16      0.001  -8.03e-13      1.000      -0.001       0.001
# C(item_nbr)[T.66]        -6.019e-16      0.001   -7.9e-13      1.000      -0.001       0.001
# C(item_nbr)[T.67]        -6.806e-16      0.001  -8.94e-13      1.000      -0.001       0.001
# C(item_nbr)[T.68]        -6.595e-16      0.001  -8.66e-13      1.000      -0.001       0.001
# C(item_nbr)[T.69]            0.6930      0.001    520.636      0.000       0.690       0.696
# C(item_nbr)[T.70]        -6.195e-16      0.001  -8.13e-13      1.000      -0.001       0.001
# C(item_nbr)[T.71]        -7.776e-16      0.001  -1.02e-12      1.000      -0.001       0.001
# C(item_nbr)[T.72]         -8.17e-16      0.001  -1.07e-12      1.000      -0.001       0.001
# C(item_nbr)[T.73]        -7.148e-16      0.001  -9.39e-13      1.000      -0.001       0.001
# C(item_nbr)[T.74]        -7.382e-16      0.001  -9.69e-13      1.000      -0.001       0.001
# C(item_nbr)[T.75]            0.0002      0.001      0.228      0.820      -0.002       0.002
# C(item_nbr)[T.76]         -6.35e-16      0.001  -8.34e-13      1.000      -0.001       0.001
# C(item_nbr)[T.77]        -5.722e-16      0.001  -7.51e-13      1.000      -0.001       0.001
# C(item_nbr)[T.78]        -7.805e-16      0.001  -1.02e-12      1.000      -0.001       0.001
# C(item_nbr)[T.79]        -9.026e-16      0.001  -1.19e-12      1.000      -0.001       0.001
# C(item_nbr)[T.80]        -6.436e-16      0.001  -8.45e-13      1.000      -0.001       0.001
# C(item_nbr)[T.81]        -6.571e-16      0.001  -8.63e-13      1.000      -0.001       0.001
# C(item_nbr)[T.82]        -6.586e-16      0.001  -8.65e-13      1.000      -0.001       0.001
# C(item_nbr)[T.83]            2.2664      0.001   2360.184      0.000       2.265       2.268
# C(item_nbr)[T.84]         -7.04e-16      0.001  -9.24e-13      1.000      -0.001       0.001
# C(item_nbr)[T.85]        -9.332e-16      0.001  -1.23e-12      1.000      -0.001       0.001
# C(item_nbr)[T.86]        -6.734e-16      0.001  -8.84e-13      1.000      -0.001       0.001
# C(item_nbr)[T.87]        -8.858e-16      0.001  -1.16e-12      1.000      -0.001       0.001
# C(item_nbr)[T.88]         8.543e-06      0.001      0.011      0.991      -0.002       0.002
# C(item_nbr)[T.89]        -6.254e-16      0.001  -8.21e-13      1.000      -0.001       0.001
# C(item_nbr)[T.90]        -6.087e-16      0.001  -7.99e-13      1.000      -0.001       0.001
# C(item_nbr)[T.91]        -7.375e-16      0.001  -9.68e-13      1.000      -0.001       0.001
# C(item_nbr)[T.92]        -7.943e-16      0.001  -1.04e-12      1.000      -0.001       0.001
# C(item_nbr)[T.93]            0.0001      0.001      0.159      0.874      -0.002       0.002
# C(item_nbr)[T.94]        -7.517e-16      0.001  -9.87e-13      1.000      -0.001       0.001
# C(item_nbr)[T.95]        -7.476e-16      0.001  -9.82e-13      1.000      -0.001       0.001
# C(item_nbr)[T.96]         -7.05e-16      0.001  -9.26e-13      1.000      -0.001       0.001
# C(item_nbr)[T.97]        -6.797e-16      0.001  -8.92e-13      1.000      -0.001       0.001
# C(item_nbr)[T.98]        -7.976e-16      0.001  -1.05e-12      1.000      -0.001       0.001
# C(item_nbr)[T.99]         -8.08e-16      0.001  -1.06e-12      1.000      -0.001       0.001
# C(item_nbr)[T.100]       -7.505e-16      0.001  -9.85e-13      1.000      -0.001       0.001
# C(item_nbr)[T.101]       -8.349e-16      0.001   -1.1e-12      1.000      -0.001       0.001
# C(item_nbr)[T.102]       -7.126e-16      0.001  -9.36e-13      1.000      -0.001       0.001
# C(item_nbr)[T.103]       -7.312e-16      0.001   -9.6e-13      1.000      -0.001       0.001
# C(item_nbr)[T.104]       -7.177e-16      0.001  -9.42e-13      1.000      -0.001       0.001
# C(item_nbr)[T.105]       -8.484e-16      0.001  -1.11e-12      1.000      -0.001       0.001
# C(item_nbr)[T.106]       -7.288e-16      0.001  -9.57e-13      1.000      -0.001       0.001
# C(item_nbr)[T.107]       -8.884e-16      0.001  -1.17e-12      1.000      -0.001       0.001
# C(item_nbr)[T.108]       -7.225e-16      0.001  -9.49e-13      1.000      -0.001       0.001
# C(item_nbr)[T.109]       -8.159e-16      0.001  -1.07e-12      1.000      -0.001       0.001
# C(item_nbr)[T.110]       -7.914e-16      0.001  -1.04e-12      1.000      -0.001       0.001
# C(item_nbr)[T.111]       -9.374e-16      0.001  -1.23e-12      1.000      -0.001       0.001
# scale(tmax)                 -0.0004      0.001     -0.587      0.557      -0.002       0.001
# scale(tmin)                 -0.0004      0.001     -0.656      0.512      -0.002       0.001
# scale(tavg)                 -0.0004      0.001     -0.629      0.529      -0.002       0.001
# scale(dewpoint)             -0.0007      0.001     -0.572      0.567      -0.003       0.002
# scale(wetbulb)               0.0019      0.001      1.954      0.051   -5.94e-06       0.004
# scale(heat)                  0.0007      0.001      1.184      0.236      -0.000       0.002
# scale(cool)              -9.885e-05      0.000     -0.841      0.400      -0.000       0.000
# scale(snowfall)          -2.041e-05   5.83e-05     -0.350      0.726      -0.000    9.38e-05
# scale(preciptotal)        3.281e-05   6.55e-05      0.501      0.617   -9.57e-05       0.000
# scale(stnpressure)          -0.0002      0.000     -0.523      0.601      -0.001       0.001
# scale(sealevel)              0.0003      0.000      0.683      0.494      -0.001       0.001
# scale(resultspeed)           0.0002      0.000      1.096      0.273      -0.000       0.001
# scale(avgspeed)             -0.0001      0.000     -0.480      0.632      -0.001       0.000
# scale(relative_humility) -6.685e-05      0.000     -0.169      0.865      -0.001       0.001
# scale(windchill)             0.0008      0.001      0.844      0.399      -0.001       0.003
# ==============================================================================
# Omnibus:                    66336.343   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        194591365.002
# Skew:                          -1.753   Prob(JB):                         0.00
# Kurtosis:                     224.915   Cond. No.                     5.21e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.63e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
ls1
# Out:
# ['depart', 'sunrise', 'sunset', 'resultdir', 'daytime']

# %% [markdown]
# ### 3. VIF 확인

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# all_cols = ['tmax','tmin','tavg','dewpoint','wetbulb','heat','cool','preciptotal',\
#         'stnpressure','sealevel','resultspeed','avgspeed','relative_humility',\
#         'windchill', 'depart', 'sunrise', 'sunset', 'snowfall' ]
cols = ['tmax','tmin','tavg','dewpoint','wetbulb','heat','cool','preciptotal',\
        'stnpressure','sealevel','resultspeed','avgspeed','relative_humility',\
        'windchill', 'snowfall' ]

y = df2_1.loc[:,cols]
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(y.values, i) for i in range(y.shape[1])]
vif["features"] = y.columns
vif = vif.sort_values("VIF Factor", ascending=False).reset_index(drop=True)
vif
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:167: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#       VIF Factor           features
# 0            inf               tmax
# 1            inf               tmin
# 2            inf               tavg
# 3   1.201633e+06        stnpressure
# 4   1.181739e+06           sealevel
# 5   2.477163e+03            wetbulb
# 6   2.350348e+03           dewpoint
# 7   1.995123e+03          windchill
# 8   1.065378e+03  relative_humility
# 9   2.541173e+02               heat
# 10  7.604035e+01           avgspeed
# 11  4.174595e+01        resultspeed
# 12  5.444235e+00               cool
# 13  1.764345e+00        preciptotal
# 14  1.221594e+00           snowfall

# %% [markdown]
# ### 4. VIF 근거, 빼고 다시 Model 돌림.

# %%
# OLS - df2_1
model2_1 = sm.OLS.from_formula('log1p_units ~ scale(cool)\
                            + scale(snowfall) + scale(preciptotal) + scale(resultspeed)  \
                          + scale(avgspeed) + C(year) + C(month) + C(weekend) \
                            + C(rainY) + C(store_nbr) + C(item_nbr) + 0', data = df2_1)
result2_1 = model2_1.fit()
print(result2_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log1p_units   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 1.669e+05
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):               0.00
# Time:                        13:02:14   Log-Likelihood:             2.5784e+05
# No. Observations:               94810   AIC:                        -5.154e+05
# Df Residuals:                   94679   BIC:                        -5.142e+05
# Df Model:                         130
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(year)[2012]          0.0004      0.001      0.707      0.480      -0.001       0.002
# C(year)[2013]          0.0003      0.001      0.498      0.619      -0.001       0.001
# C(year)[2014]      -3.388e-05      0.001     -0.058      0.953      -0.001       0.001
# C(month)[T.2]         -0.0004      0.000     -1.366      0.172      -0.001       0.000
# C(month)[T.3]         -0.0005      0.000     -1.990      0.047      -0.001   -7.62e-06
# C(month)[T.4]         -0.0007      0.000     -2.930      0.003      -0.001      -0.000
# C(month)[T.5]         -0.0009      0.000     -3.633      0.000      -0.001      -0.000
# C(month)[T.6]         -0.0007      0.000     -2.780      0.005      -0.001      -0.000
# C(month)[T.7]         -0.0008      0.000     -2.884      0.004      -0.001      -0.000
# C(month)[T.8]         -0.0001      0.000     -0.475      0.635      -0.001       0.000
# C(month)[T.9]         -0.0001      0.000     -0.462      0.644      -0.001       0.000
# C(month)[T.10]        -0.0007      0.000     -2.723      0.006      -0.001      -0.000
# C(month)[T.11]        -0.0002      0.000     -0.897      0.370      -0.001       0.000
# C(month)[T.12]        -0.0002      0.000     -0.755      0.450      -0.001       0.000
# C(weekend)[T.1]        0.0006      0.000      4.951      0.000       0.000       0.001
# C(rainY)[T.1]       7.904e-05      0.000      0.689      0.491      -0.000       0.000
# C(item_nbr)[T.2]   -3.263e-15      0.001  -4.28e-12      1.000      -0.001       0.001
# C(item_nbr)[T.3]   -4.047e-15      0.001  -5.31e-12      1.000      -0.001       0.001
# C(item_nbr)[T.4]   -4.966e-16      0.001  -6.52e-13      1.000      -0.001       0.001
# C(item_nbr)[T.5]   -1.038e-15      0.001  -1.36e-12      1.000      -0.001       0.001
# C(item_nbr)[T.6]   -1.898e-15      0.001  -2.49e-12      1.000      -0.001       0.001
# C(item_nbr)[T.7]    1.553e-16      0.001   2.04e-13      1.000      -0.001       0.001
# C(item_nbr)[T.8]    -1.65e-15      0.001  -2.17e-12      1.000      -0.001       0.001
# C(item_nbr)[T.9]   -2.092e-15      0.001  -2.75e-12      1.000      -0.001       0.001
# C(item_nbr)[T.10]  -1.435e-15      0.001  -1.88e-12      1.000      -0.001       0.001
# C(item_nbr)[T.11]  -2.024e-15      0.001  -2.66e-12      1.000      -0.001       0.001
# C(item_nbr)[T.12]   8.888e-16      0.001   1.17e-12      1.000      -0.001       0.001
# C(item_nbr)[T.13]  -2.818e-15      0.001   -3.7e-12      1.000      -0.001       0.001
# C(item_nbr)[T.14]  -1.108e-15      0.001  -1.46e-12      1.000      -0.001       0.001
# C(item_nbr)[T.15]   4.131e-05      0.001      0.052      0.958      -0.002       0.002
# C(item_nbr)[T.16]      2.8483      0.001   3013.262      0.000       2.846       2.850
# C(item_nbr)[T.17]  -1.218e-15      0.001   -1.6e-12      1.000      -0.001       0.001
# C(item_nbr)[T.18]  -9.359e-16      0.001  -1.23e-12      1.000      -0.001       0.001
# C(item_nbr)[T.19]  -1.024e-15      0.001  -1.34e-12      1.000      -0.001       0.001
# C(item_nbr)[T.20]  -1.109e-15      0.001  -1.46e-12      1.000      -0.001       0.001
# C(item_nbr)[T.21]   -1.05e-15      0.001  -1.38e-12      1.000      -0.001       0.001
# C(item_nbr)[T.22]   -1.03e-15      0.001  -1.35e-12      1.000      -0.001       0.001
# C(item_nbr)[T.23]  -1.199e-15      0.001  -1.57e-12      1.000      -0.001       0.001
# C(item_nbr)[T.24]  -9.207e-16      0.001  -1.21e-12      1.000      -0.001       0.001
# C(item_nbr)[T.25]  -1.013e-15      0.001  -1.33e-12      1.000      -0.001       0.001
# C(item_nbr)[T.26]  -1.052e-15      0.001  -1.38e-12      1.000      -0.001       0.001
# C(item_nbr)[T.27]  -1.214e-15      0.001  -1.59e-12      1.000      -0.001       0.001
# C(item_nbr)[T.28]  -1.104e-15      0.001  -1.45e-12      1.000      -0.001       0.001
# C(item_nbr)[T.29]  -1.023e-15      0.001  -1.34e-12      1.000      -0.001       0.001
# C(item_nbr)[T.30]  -8.208e-16      0.001  -1.08e-12      1.000      -0.001       0.001
# C(item_nbr)[T.31]  -3.644e-16      0.001  -4.78e-13      1.000      -0.001       0.001
# C(item_nbr)[T.32]  -6.609e-16      0.001  -8.68e-13      1.000      -0.001       0.001
# C(item_nbr)[T.33]  -9.701e-16      0.001  -1.27e-12      1.000      -0.001       0.001
# C(item_nbr)[T.34]  -1.024e-15      0.001  -1.34e-12      1.000      -0.001       0.001
# C(item_nbr)[T.35]  -1.146e-15      0.001  -1.51e-12      1.000      -0.001       0.001
# C(item_nbr)[T.36]  -8.353e-16      0.001   -1.1e-12      1.000      -0.001       0.001
# C(item_nbr)[T.37]  -8.871e-16      0.001  -1.16e-12      1.000      -0.001       0.001
# C(item_nbr)[T.38]   -9.25e-16      0.001  -1.21e-12      1.000      -0.001       0.001
# C(item_nbr)[T.39]   4.027e-05      0.001      0.051      0.959      -0.001       0.002
# C(item_nbr)[T.40]  -9.486e-16      0.001  -1.25e-12      1.000      -0.001       0.001
# C(item_nbr)[T.41]  -1.004e-15      0.001  -1.32e-12      1.000      -0.001       0.001
# C(item_nbr)[T.42]  -9.534e-16      0.001  -1.25e-12      1.000      -0.001       0.001
# C(item_nbr)[T.43]  -1.071e-15      0.001  -1.41e-12      1.000      -0.001       0.001
# C(item_nbr)[T.44]  -9.978e-16      0.001  -1.31e-12      1.000      -0.001       0.001
# C(item_nbr)[T.45]  -8.495e-16      0.001  -1.12e-12      1.000      -0.001       0.001
# C(item_nbr)[T.46]  -1.051e-15      0.001  -1.38e-12      1.000      -0.001       0.001
# C(item_nbr)[T.47]  -9.027e-16      0.001  -1.19e-12      1.000      -0.001       0.001
# C(item_nbr)[T.48]  -1.077e-15      0.001  -1.41e-12      1.000      -0.001       0.001
# C(item_nbr)[T.49]  -9.274e-16      0.001  -1.22e-12      1.000      -0.001       0.001
# C(item_nbr)[T.50]  -9.582e-16      0.001  -1.26e-12      1.000      -0.001       0.001
# C(item_nbr)[T.51]  -9.394e-16      0.001  -1.23e-12      1.000      -0.001       0.001
# C(item_nbr)[T.52]  -8.976e-16      0.001  -1.18e-12      1.000      -0.001       0.001
# C(item_nbr)[T.53]  -1.038e-15      0.001  -1.36e-12      1.000      -0.001       0.001
# C(item_nbr)[T.54]  -1.065e-15      0.001   -1.4e-12      1.000      -0.001       0.001
# C(item_nbr)[T.55]  -1.029e-15      0.001  -1.35e-12      1.000      -0.001       0.001
# C(item_nbr)[T.56]  -9.896e-16      0.001   -1.3e-12      1.000      -0.001       0.001
# C(item_nbr)[T.57]   -1.01e-15      0.001  -1.33e-12      1.000      -0.001       0.001
# C(item_nbr)[T.58]  -9.896e-16      0.001   -1.3e-12      1.000      -0.001       0.001
# C(item_nbr)[T.59]   -9.14e-16      0.001   -1.2e-12      1.000      -0.001       0.001
# C(item_nbr)[T.60]  -1.016e-15      0.001  -1.33e-12      1.000      -0.001       0.001
# C(item_nbr)[T.61]  -8.932e-16      0.001  -1.17e-12      1.000      -0.001       0.001
# C(item_nbr)[T.62]  -9.388e-16      0.001  -1.23e-12      1.000      -0.001       0.001
# C(item_nbr)[T.63]  -1.035e-15      0.001  -1.36e-12      1.000      -0.001       0.001
# C(item_nbr)[T.64]  -1.054e-15      0.001  -1.38e-12      1.000      -0.001       0.001
# C(item_nbr)[T.65]  -1.032e-15      0.001  -1.35e-12      1.000      -0.001       0.001
# C(item_nbr)[T.66]  -1.028e-15      0.001  -1.35e-12      1.000      -0.001       0.001
# C(item_nbr)[T.67]  -1.039e-15      0.001  -1.36e-12      1.000      -0.001       0.001
# C(item_nbr)[T.68]  -9.534e-16      0.001  -1.25e-12      1.000      -0.001       0.001
# C(item_nbr)[T.69]      0.6930      0.001    520.662      0.000       0.690       0.696
# C(item_nbr)[T.70]  -9.933e-16      0.001   -1.3e-12      1.000      -0.001       0.001
# C(item_nbr)[T.71]  -1.003e-15      0.001  -1.32e-12      1.000      -0.001       0.001
# C(item_nbr)[T.72]  -9.005e-16      0.001  -1.18e-12      1.000      -0.001       0.001
# C(item_nbr)[T.73]  -9.509e-16      0.001  -1.25e-12      1.000      -0.001       0.001
# C(item_nbr)[T.74]  -9.908e-16      0.001   -1.3e-12      1.000      -0.001       0.001
# C(item_nbr)[T.75]      0.0002      0.001      0.202      0.840      -0.002       0.002
# C(item_nbr)[T.76]  -9.249e-16      0.001  -1.21e-12      1.000      -0.001       0.001
# C(item_nbr)[T.77]  -1.015e-15      0.001  -1.33e-12      1.000      -0.001       0.001
# C(item_nbr)[T.78]  -9.502e-16      0.001  -1.25e-12      1.000      -0.001       0.001
# C(item_nbr)[T.79]  -1.096e-15      0.001  -1.44e-12      1.000      -0.001       0.001
# C(item_nbr)[T.80]  -9.876e-16      0.001   -1.3e-12      1.000      -0.001       0.001
# C(item_nbr)[T.81]  -9.342e-16      0.001  -1.23e-12      1.000      -0.001       0.001
# C(item_nbr)[T.82]  -9.111e-16      0.001   -1.2e-12      1.000      -0.001       0.001
# C(item_nbr)[T.83]      2.2664      0.001   2360.224      0.000       2.265       2.268
# C(item_nbr)[T.84]  -9.228e-16      0.001  -1.21e-12      1.000      -0.001       0.001
# C(item_nbr)[T.85]  -9.886e-16      0.001   -1.3e-12      1.000      -0.001       0.001
# C(item_nbr)[T.86]  -7.995e-16      0.001  -1.05e-12      1.000      -0.001       0.001
# C(item_nbr)[T.87]  -1.027e-15      0.001  -1.35e-12      1.000      -0.001       0.001
# C(item_nbr)[T.88]   9.442e-06      0.001      0.012      0.990      -0.002       0.002
# C(item_nbr)[T.89]   -1.03e-15      0.001  -1.35e-12      1.000      -0.001       0.001
# C(item_nbr)[T.90]  -9.633e-16      0.001  -1.26e-12      1.000      -0.001       0.001
# C(item_nbr)[T.91]  -1.125e-15      0.001  -1.48e-12      1.000      -0.001       0.001
# C(item_nbr)[T.92]  -9.994e-16      0.001  -1.31e-12      1.000      -0.001       0.001
# C(item_nbr)[T.93]      0.0001      0.001      0.136      0.892      -0.002       0.002
# C(item_nbr)[T.94]   -1.01e-15      0.001  -1.33e-12      1.000      -0.001       0.001
# C(item_nbr)[T.95]  -1.082e-15      0.001  -1.42e-12      1.000      -0.001       0.001
# C(item_nbr)[T.96]  -1.031e-15      0.001  -1.35e-12      1.000      -0.001       0.001
# C(item_nbr)[T.97]  -1.102e-15      0.001  -1.45e-12      1.000      -0.001       0.001
# C(item_nbr)[T.98]  -1.052e-15      0.001  -1.38e-12      1.000      -0.001       0.001
# C(item_nbr)[T.99]  -1.027e-15      0.001  -1.35e-12      1.000      -0.001       0.001
# C(item_nbr)[T.100] -1.005e-15      0.001  -1.32e-12      1.000      -0.001       0.001
# C(item_nbr)[T.101] -1.183e-15      0.001  -1.55e-12      1.000      -0.001       0.001
# C(item_nbr)[T.102] -8.538e-16      0.001  -1.12e-12      1.000      -0.001       0.001
# C(item_nbr)[T.103] -1.082e-15      0.001  -1.42e-12      1.000      -0.001       0.001
# C(item_nbr)[T.104] -9.601e-16      0.001  -1.26e-12      1.000      -0.001       0.001
# C(item_nbr)[T.105] -8.828e-16      0.001  -1.16e-12      1.000      -0.001       0.001
# C(item_nbr)[T.106] -1.051e-15      0.001  -1.38e-12      1.000      -0.001       0.001
# C(item_nbr)[T.107] -1.152e-15      0.001  -1.51e-12      1.000      -0.001       0.001
# C(item_nbr)[T.108] -1.095e-15      0.001  -1.44e-12      1.000      -0.001       0.001
# C(item_nbr)[T.109] -1.087e-15      0.001  -1.43e-12      1.000      -0.001       0.001
# C(item_nbr)[T.110] -8.958e-16      0.001  -1.18e-12      1.000      -0.001       0.001
# C(item_nbr)[T.111] -8.665e-16      0.001  -1.14e-12      1.000      -0.001       0.001
# scale(cool)        -1.547e-06   6.76e-05     -0.023      0.982      -0.000       0.000
# scale(snowfall)    -3.295e-05   5.62e-05     -0.586      0.558      -0.000    7.73e-05
# scale(preciptotal)  2.588e-05   5.91e-05      0.438      0.662      -9e-05       0.000
# scale(resultspeed)     0.0003      0.000      1.289      0.197      -0.000       0.001
# scale(avgspeed)       -0.0002      0.000     -1.113      0.266      -0.001       0.000
# ==============================================================================
# Omnibus:                    66358.522   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        194658657.015
# Skew:                          -1.754   Prob(JB):                         0.00
# Kurtosis:                     224.953   Cond. No.                         159.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### 5. VIF 재확인

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# all_cols = ['tmax','tmin','tavg','dewpoint','wetbulb','heat','cool','preciptotal',\
#         'stnpressure','sealevel','resultspeed','avgspeed','relative_humility',\
#         'windchill', 'depart', 'sunrise', 'sunset', 'snowfall' ]
cols = ['cool', 'snowfall', 'preciptotal', 'resultspeed', 'avgspeed']

y = df2_1.loc[:,cols]
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(y.values, i) for i in range(y.shape[1])]
vif["features"] = y.columns
vif = vif.sort_values("VIF Factor", ascending=False).reset_index(drop=True)
vif
# Out:
#    VIF Factor     features
# 0   32.831723     avgspeed
# 1   31.697710  resultspeed
# 2    1.332211  preciptotal
# 3    1.129507     snowfall
# 4    1.087260         cool

# %% [markdown]
# ### 6. VIF 근거, stnpressure, sealevel, dewpoint, windchill, wetbulb, relative_humility, sunset제외하고  Model 돌림.

# %%
# OLS - df2_1
model2_1 = sm.OLS.from_formula('log1p_units ~ scale(cool)\
                            + scale(snowfall) + scale(preciptotal) + C(year) + C(month) + C(weekend) \
                            + C(rainY) + C(store_nbr) + C(item_nbr) + 0', data = df2_1)
result2_1 = model2_1.fit()
print(result2_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log1p_units   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 1.695e+05
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):               0.00
# Time:                        13:03:46   Log-Likelihood:             2.5784e+05
# No. Observations:               94810   AIC:                        -5.154e+05
# Df Residuals:                   94681   BIC:                        -5.142e+05
# Df Model:                         128
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(year)[2012]          0.0004      0.001      0.702      0.483      -0.001       0.002
# C(year)[2013]          0.0003      0.001      0.505      0.613      -0.001       0.001
# C(year)[2014]      -3.976e-05      0.001     -0.069      0.945      -0.001       0.001
# C(month)[T.2]         -0.0003      0.000     -1.279      0.201      -0.001       0.000
# C(month)[T.3]         -0.0005      0.000     -1.905      0.057      -0.001    1.37e-05
# C(month)[T.4]         -0.0007      0.000     -2.936      0.003      -0.001      -0.000
# C(month)[T.5]         -0.0009      0.000     -3.665      0.000      -0.001      -0.000
# C(month)[T.6]         -0.0007      0.000     -2.794      0.005      -0.001      -0.000
# C(month)[T.7]         -0.0008      0.000     -2.923      0.003      -0.001      -0.000
# C(month)[T.8]         -0.0001      0.000     -0.484      0.628      -0.001       0.000
# C(month)[T.9]         -0.0001      0.000     -0.487      0.626      -0.001       0.000
# C(month)[T.10]        -0.0007      0.000     -2.812      0.005      -0.001      -0.000
# C(month)[T.11]        -0.0002      0.000     -0.816      0.415      -0.001       0.000
# C(month)[T.12]        -0.0002      0.000     -0.693      0.488      -0.001       0.000
# C(weekend)[T.1]        0.0006      0.000      4.989      0.000       0.000       0.001
# C(rainY)[T.1]       7.286e-05      0.000      0.641      0.521      -0.000       0.000
# C(item_nbr)[T.2]   -1.479e-15      0.001  -1.94e-12      1.000      -0.001       0.001
# C(item_nbr)[T.3]    6.864e-16      0.001   9.01e-13      1.000      -0.001       0.001
# C(item_nbr)[T.4]    2.165e-16      0.001   2.84e-13      1.000      -0.001       0.001
# C(item_nbr)[T.5]   -6.228e-16      0.001  -8.18e-13      1.000      -0.001       0.001
# C(item_nbr)[T.6]   -3.988e-16      0.001  -5.24e-13      1.000      -0.001       0.001
# C(item_nbr)[T.7]   -1.767e-18      0.001  -2.32e-15      1.000      -0.001       0.001
# C(item_nbr)[T.8]   -4.303e-16      0.001  -5.65e-13      1.000      -0.001       0.001
# C(item_nbr)[T.9]   -2.206e-16      0.001   -2.9e-13      1.000      -0.001       0.001
# C(item_nbr)[T.10]    1.44e-15      0.001   1.89e-12      1.000      -0.001       0.001
# C(item_nbr)[T.11]  -3.994e-16      0.001  -5.24e-13      1.000      -0.001       0.001
# C(item_nbr)[T.12]    3.13e-16      0.001   4.11e-13      1.000      -0.001       0.001
# C(item_nbr)[T.13]   5.918e-17      0.001   7.77e-14      1.000      -0.001       0.001
# C(item_nbr)[T.14]  -9.654e-18      0.001  -1.27e-14      1.000      -0.001       0.001
# C(item_nbr)[T.15]    4.26e-05      0.001      0.054      0.957      -0.002       0.002
# C(item_nbr)[T.16]      2.8483      0.001   3013.265      0.000       2.846       2.850
# C(item_nbr)[T.17]  -1.522e-16      0.001     -2e-13      1.000      -0.001       0.001
# C(item_nbr)[T.18]     1.2e-16      0.001   1.58e-13      1.000      -0.001       0.001
# C(item_nbr)[T.19]    1.25e-16      0.001   1.64e-13      1.000      -0.001       0.001
# C(item_nbr)[T.20]   2.855e-16      0.001   3.75e-13      1.000      -0.001       0.001
# C(item_nbr)[T.21]   2.492e-17      0.001   3.27e-14      1.000      -0.001       0.001
# C(item_nbr)[T.22]   1.124e-16      0.001   1.48e-13      1.000      -0.001       0.001
# C(item_nbr)[T.23]  -1.995e-16      0.001  -2.62e-13      1.000      -0.001       0.001
# C(item_nbr)[T.24]    1.41e-16      0.001   1.85e-13      1.000      -0.001       0.001
# C(item_nbr)[T.25]   1.114e-16      0.001   1.46e-13      1.000      -0.001       0.001
# C(item_nbr)[T.26]    1.58e-16      0.001   2.07e-13      1.000      -0.001       0.001
# C(item_nbr)[T.27]  -1.733e-17      0.001  -2.27e-14      1.000      -0.001       0.001
# C(item_nbr)[T.28]   5.821e-18      0.001   7.64e-15      1.000      -0.001       0.001
# C(item_nbr)[T.29]   5.454e-17      0.001   7.16e-14      1.000      -0.001       0.001
# C(item_nbr)[T.30]   1.537e-16      0.001   2.02e-13      1.000      -0.001       0.001
# C(item_nbr)[T.31]   8.655e-16      0.001   1.14e-12      1.000      -0.001       0.001
# C(item_nbr)[T.32]   2.472e-16      0.001   3.25e-13      1.000      -0.001       0.001
# C(item_nbr)[T.33]    7.46e-17      0.001    9.8e-14      1.000      -0.001       0.001
# C(item_nbr)[T.34]   1.484e-16      0.001   1.95e-13      1.000      -0.001       0.001
# C(item_nbr)[T.35]   6.653e-17      0.001   8.74e-14      1.000      -0.001       0.001
# C(item_nbr)[T.36]   1.186e-16      0.001   1.56e-13      1.000      -0.001       0.001
# C(item_nbr)[T.37]   5.296e-17      0.001   6.95e-14      1.000      -0.001       0.001
# C(item_nbr)[T.38]   2.651e-17      0.001   3.48e-14      1.000      -0.001       0.001
# C(item_nbr)[T.39]   3.969e-05      0.001      0.051      0.960      -0.001       0.002
# C(item_nbr)[T.40]   6.781e-18      0.001    8.9e-15      1.000      -0.001       0.001
# C(item_nbr)[T.41]   1.639e-16      0.001   2.15e-13      1.000      -0.001       0.001
# C(item_nbr)[T.42]   1.181e-16      0.001   1.55e-13      1.000      -0.001       0.001
# C(item_nbr)[T.43]  -3.195e-17      0.001   -4.2e-14      1.000      -0.001       0.001
# C(item_nbr)[T.44]    8.82e-17      0.001   1.16e-13      1.000      -0.001       0.001
# C(item_nbr)[T.45]  -2.152e-17      0.001  -2.83e-14      1.000      -0.001       0.001
# C(item_nbr)[T.46]   1.507e-17      0.001   1.98e-14      1.000      -0.001       0.001
# C(item_nbr)[T.47]   1.193e-16      0.001   1.57e-13      1.000      -0.001       0.001
# C(item_nbr)[T.48]   1.058e-16      0.001   1.39e-13      1.000      -0.001       0.001
# C(item_nbr)[T.49]   3.245e-16      0.001   4.26e-13      1.000      -0.001       0.001
# C(item_nbr)[T.50]   1.657e-16      0.001   2.18e-13      1.000      -0.001       0.001
# C(item_nbr)[T.51]   1.667e-16      0.001   2.19e-13      1.000      -0.001       0.001
# C(item_nbr)[T.52]   1.323e-16      0.001   1.74e-13      1.000      -0.001       0.001
# C(item_nbr)[T.53]   1.078e-16      0.001   1.42e-13      1.000      -0.001       0.001
# C(item_nbr)[T.54]       7e-18      0.001   9.19e-15      1.000      -0.001       0.001
# C(item_nbr)[T.55]  -1.439e-17      0.001  -1.89e-14      1.000      -0.001       0.001
# C(item_nbr)[T.56]   9.794e-17      0.001   1.29e-13      1.000      -0.001       0.001
# C(item_nbr)[T.57]   1.029e-16      0.001   1.35e-13      1.000      -0.001       0.001
# C(item_nbr)[T.58]   1.394e-16      0.001   1.83e-13      1.000      -0.001       0.001
# C(item_nbr)[T.59]   1.218e-16      0.001    1.6e-13      1.000      -0.001       0.001
# C(item_nbr)[T.60]   1.369e-16      0.001    1.8e-13      1.000      -0.001       0.001
# C(item_nbr)[T.61]   2.038e-16      0.001   2.68e-13      1.000      -0.001       0.001
# C(item_nbr)[T.62]   1.574e-16      0.001   2.07e-13      1.000      -0.001       0.001
# C(item_nbr)[T.63]    3.36e-17      0.001   4.41e-14      1.000      -0.001       0.001
# C(item_nbr)[T.64]   6.384e-17      0.001   8.38e-14      1.000      -0.001       0.001
# C(item_nbr)[T.65]   2.006e-16      0.001   2.63e-13      1.000      -0.001       0.001
# C(item_nbr)[T.66]   2.483e-16      0.001   3.26e-13      1.000      -0.001       0.001
# C(item_nbr)[T.67]   2.732e-17      0.001   3.59e-14      1.000      -0.001       0.001
# C(item_nbr)[T.68]    1.73e-16      0.001   2.27e-13      1.000      -0.001       0.001
# C(item_nbr)[T.69]      0.6930      0.001    520.662      0.000       0.690       0.696
# C(item_nbr)[T.70]   1.205e-16      0.001   1.58e-13      1.000      -0.001       0.001
# C(item_nbr)[T.71]   1.388e-16      0.001   1.82e-13      1.000      -0.001       0.001
# C(item_nbr)[T.72]   1.367e-16      0.001   1.79e-13      1.000      -0.001       0.001
# C(item_nbr)[T.73]   8.616e-17      0.001   1.13e-13      1.000      -0.001       0.001
# C(item_nbr)[T.74]    8.96e-17      0.001   1.18e-13      1.000      -0.001       0.001
# C(item_nbr)[T.75]      0.0002      0.001      0.203      0.839      -0.002       0.002
# C(item_nbr)[T.76]   2.756e-16      0.001   3.62e-13      1.000      -0.001       0.001
# C(item_nbr)[T.77]   1.983e-16      0.001    2.6e-13      1.000      -0.001       0.001
# C(item_nbr)[T.78]   1.279e-16      0.001   1.68e-13      1.000      -0.001       0.001
# C(item_nbr)[T.79]   1.389e-16      0.001   1.82e-13      1.000      -0.001       0.001
# C(item_nbr)[T.80]   1.046e-16      0.001   1.37e-13      1.000      -0.001       0.001
# C(item_nbr)[T.81]     1.1e-16      0.001   1.44e-13      1.000      -0.001       0.001
# C(item_nbr)[T.82]   1.036e-16      0.001   1.36e-13      1.000      -0.001       0.001
# C(item_nbr)[T.83]      2.2664      0.001   2360.229      0.000       2.265       2.268
# C(item_nbr)[T.84]  -2.138e-17      0.001  -2.81e-14      1.000      -0.001       0.001
# C(item_nbr)[T.85]    1.36e-16      0.001   1.79e-13      1.000      -0.001       0.001
# C(item_nbr)[T.86]   2.383e-16      0.001   3.13e-13      1.000      -0.001       0.001
# C(item_nbr)[T.87]   8.739e-17      0.001   1.15e-13      1.000      -0.001       0.001
# C(item_nbr)[T.88]   8.484e-06      0.001      0.011      0.991      -0.002       0.002
# C(item_nbr)[T.89]   7.154e-17      0.001   9.39e-14      1.000      -0.001       0.001
# C(item_nbr)[T.90]   9.417e-17      0.001   1.24e-13      1.000      -0.001       0.001
# C(item_nbr)[T.91]  -3.399e-17      0.001  -4.46e-14      1.000      -0.001       0.001
# C(item_nbr)[T.92]   2.136e-17      0.001    2.8e-14      1.000      -0.001       0.001
# C(item_nbr)[T.93]      0.0001      0.001      0.136      0.892      -0.002       0.002
# C(item_nbr)[T.94]   7.556e-17      0.001   9.92e-14      1.000      -0.001       0.001
# C(item_nbr)[T.95]   5.821e-17      0.001   7.64e-14      1.000      -0.001       0.001
# C(item_nbr)[T.96]   7.664e-17      0.001   1.01e-13      1.000      -0.001       0.001
# C(item_nbr)[T.97]   4.121e-18      0.001   5.41e-15      1.000      -0.001       0.001
# C(item_nbr)[T.98]  -1.306e-17      0.001  -1.71e-14      1.000      -0.001       0.001
# C(item_nbr)[T.99]   2.454e-17      0.001   3.22e-14      1.000      -0.001       0.001
# C(item_nbr)[T.100]  7.955e-17      0.001   1.04e-13      1.000      -0.001       0.001
# C(item_nbr)[T.101]  3.144e-17      0.001   4.13e-14      1.000      -0.001       0.001
# C(item_nbr)[T.102] -2.102e-16      0.001  -2.76e-13      1.000      -0.001       0.001
# C(item_nbr)[T.103]  6.774e-17      0.001   8.89e-14      1.000      -0.001       0.001
# C(item_nbr)[T.104]  1.285e-16      0.001   1.69e-13      1.000      -0.001       0.001
# C(item_nbr)[T.105]  1.497e-16      0.001   1.97e-13      1.000      -0.001       0.001
# C(item_nbr)[T.106]  1.955e-16      0.001   2.57e-13      1.000      -0.001       0.001
# C(item_nbr)[T.107]  2.623e-16      0.001   3.44e-13      1.000      -0.001       0.001
# C(item_nbr)[T.108]  2.827e-16      0.001   3.71e-13      1.000      -0.001       0.001
# C(item_nbr)[T.109] -2.999e-17      0.001  -3.94e-14      1.000      -0.001       0.001
# C(item_nbr)[T.110]  7.061e-17      0.001   9.27e-14      1.000      -0.001       0.001
# C(item_nbr)[T.111]  1.067e-16      0.001    1.4e-13      1.000      -0.001       0.001
# scale(cool)         -1.18e-06   6.76e-05     -0.017      0.986      -0.000       0.000
# scale(snowfall)    -2.537e-05   5.59e-05     -0.454      0.650      -0.000    8.42e-05
# scale(preciptotal)  1.077e-05   5.75e-05      0.187      0.851      -0.000       0.000
# ==============================================================================
# Omnibus:                    66365.974   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        194668807.516
# Skew:                          -1.755   Prob(JB):                         0.00
# Kurtosis:                     224.959   Cond. No.                         128.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Anova 분석을 통해 p-value가 0.05보다 큰것은 제외

# %%
anova_result2_1 = sm.stats.anova_lm(result2_1).sort_values(by=['PR(>F)'], ascending = False)
anova_result2_1[anova_result2_1['PR(>F)'] <= 0.05]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#                 df       sum_sq    mean_sq              F         PR(>F)
# C(weekend)     1.0     0.254363   0.254363     998.883074  4.320258e-218
# C(year)        3.0    52.725043  17.575014   69017.178245   0.000000e+00
# C(month)      11.0     0.416880   0.037898     148.826498   0.000000e+00
# C(item_nbr)  110.0  5522.813321  50.207394  197164.711090   0.000000e+00

# %% [markdown]
# ### 최종 Anova 분석과 TIF 통과한 변수들을 바탕으로 최종 모델생성

# %%
# OLS - df2_1_1
model2_1 = sm.OLS.from_formula('log1p_units ~ C(year) + C(month) + \
+ C(item_nbr) + C(weekend) + 0', data = df2_1)

result = model2_1.fit()
result2_1 = model2_1.fit()
print(result2_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log1p_units   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 1.749e+05
# Date:                Fri, 06 Jul 2018   Prob (F-statistic):               0.00
# Time:                        13:06:09   Log-Likelihood:             2.5784e+05
# No. Observations:               94810   AIC:                        -5.154e+05
# Df Residuals:                   94685   BIC:                        -5.142e+05
# Df Model:                         124
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# C(year)[2012]          0.0004      0.001      0.778      0.437      -0.001       0.002
# C(year)[2013]          0.0003      0.001      0.573      0.567      -0.001       0.001
# C(year)[2014]      -4.997e-06      0.001     -0.009      0.993      -0.001       0.001
# C(month)[T.2]         -0.0004      0.000     -1.364      0.173      -0.001       0.000
# C(month)[T.3]         -0.0005      0.000     -1.934      0.053      -0.001    6.46e-06
# C(month)[T.4]         -0.0007      0.000     -2.936      0.003      -0.001      -0.000
# C(month)[T.5]         -0.0009      0.000     -3.623      0.000      -0.001      -0.000
# C(month)[T.6]         -0.0007      0.000     -2.809      0.005      -0.001      -0.000
# C(month)[T.7]         -0.0008      0.000     -3.254      0.001      -0.001      -0.000
# C(month)[T.8]         -0.0001      0.000     -0.473      0.636      -0.001       0.000
# C(month)[T.9]         -0.0001      0.000     -0.454      0.650      -0.001       0.000
# C(month)[T.10]        -0.0007      0.000     -2.757      0.006      -0.001      -0.000
# C(month)[T.11]        -0.0002      0.000     -0.822      0.411      -0.001       0.000
# C(month)[T.12]        -0.0002      0.000     -0.659      0.510      -0.001       0.000
# C(item_nbr)[T.2]   -1.403e-15      0.001  -1.84e-12      1.000      -0.001       0.001
# C(item_nbr)[T.3]    2.608e-16      0.001   3.42e-13      1.000      -0.001       0.001
# C(item_nbr)[T.4]      6.6e-16      0.001   8.67e-13      1.000      -0.001       0.001
# C(item_nbr)[T.5]   -3.121e-17      0.001   -4.1e-14      1.000      -0.001       0.001
# C(item_nbr)[T.6]   -1.793e-15      0.001  -2.35e-12      1.000      -0.001       0.001
# C(item_nbr)[T.7]    4.475e-16      0.001   5.88e-13      1.000      -0.001       0.001
# C(item_nbr)[T.8]    1.588e-16      0.001   2.09e-13      1.000      -0.001       0.001
# C(item_nbr)[T.9]   -1.327e-15      0.001  -1.74e-12      1.000      -0.001       0.001
# C(item_nbr)[T.10]   1.993e-16      0.001   2.62e-13      1.000      -0.001       0.001
# C(item_nbr)[T.11]    1.21e-17      0.001   1.59e-14      1.000      -0.001       0.001
# C(item_nbr)[T.12]   3.172e-16      0.001   4.16e-13      1.000      -0.001       0.001
# C(item_nbr)[T.13]  -5.992e-17      0.001  -7.87e-14      1.000      -0.001       0.001
# C(item_nbr)[T.14]   4.548e-17      0.001   5.97e-14      1.000      -0.001       0.001
# C(item_nbr)[T.15]   4.221e-05      0.001      0.053      0.958      -0.002       0.002
# C(item_nbr)[T.16]      2.8483      0.001   3013.330      0.000       2.846       2.850
# C(item_nbr)[T.17]   2.091e-16      0.001   2.75e-13      1.000      -0.001       0.001
# C(item_nbr)[T.18]   1.605e-16      0.001   2.11e-13      1.000      -0.001       0.001
# C(item_nbr)[T.19]   3.368e-16      0.001   4.42e-13      1.000      -0.001       0.001
# C(item_nbr)[T.20]   2.092e-16      0.001   2.75e-13      1.000      -0.001       0.001
# C(item_nbr)[T.21]   2.041e-16      0.001   2.68e-13      1.000      -0.001       0.001
# C(item_nbr)[T.22]    2.98e-16      0.001   3.91e-13      1.000      -0.001       0.001
# C(item_nbr)[T.23]   1.838e-16      0.001   2.41e-13      1.000      -0.001       0.001
# C(item_nbr)[T.24]   2.013e-16      0.001   2.64e-13      1.000      -0.001       0.001
# C(item_nbr)[T.25]   2.207e-16      0.001    2.9e-13      1.000      -0.001       0.001
# C(item_nbr)[T.26]   3.427e-16      0.001    4.5e-13      1.000      -0.001       0.001
# C(item_nbr)[T.27]   3.653e-16      0.001    4.8e-13      1.000      -0.001       0.001
# C(item_nbr)[T.28]   1.428e-16      0.001   1.88e-13      1.000      -0.001       0.001
# C(item_nbr)[T.29]   4.032e-16      0.001   5.29e-13      1.000      -0.001       0.001
# C(item_nbr)[T.30]   2.957e-16      0.001   3.88e-13      1.000      -0.001       0.001
# C(item_nbr)[T.31]   1.117e-16      0.001   1.47e-13      1.000      -0.001       0.001
# C(item_nbr)[T.32]   9.557e-17      0.001   1.25e-13      1.000      -0.001       0.001
# C(item_nbr)[T.33]   1.401e-16      0.001   1.84e-13      1.000      -0.001       0.001
# C(item_nbr)[T.34]   2.031e-16      0.001   2.67e-13      1.000      -0.001       0.001
# C(item_nbr)[T.35]   1.916e-16      0.001   2.52e-13      1.000      -0.001       0.001
# C(item_nbr)[T.36]   1.509e-16      0.001   1.98e-13      1.000      -0.001       0.001
# C(item_nbr)[T.37]   2.213e-16      0.001   2.91e-13      1.000      -0.001       0.001
# C(item_nbr)[T.38]   1.585e-16      0.001   2.08e-13      1.000      -0.001       0.001
# C(item_nbr)[T.39]   4.018e-05      0.001      0.051      0.959      -0.001       0.002
# C(item_nbr)[T.40]   2.721e-16      0.001   3.57e-13      1.000      -0.001       0.001
# C(item_nbr)[T.41]   2.489e-16      0.001   3.27e-13      1.000      -0.001       0.001
# C(item_nbr)[T.42]   3.234e-16      0.001   4.25e-13      1.000      -0.001       0.001
# C(item_nbr)[T.43]   7.408e-17      0.001   9.73e-14      1.000      -0.001       0.001
# C(item_nbr)[T.44]   5.251e-17      0.001   6.89e-14      1.000      -0.001       0.001
# C(item_nbr)[T.45]    5.52e-18      0.001   7.25e-15      1.000      -0.001       0.001
# C(item_nbr)[T.46]   1.884e-16      0.001   2.47e-13      1.000      -0.001       0.001
# C(item_nbr)[T.47]   1.574e-16      0.001   2.07e-13      1.000      -0.001       0.001
# C(item_nbr)[T.48]   2.537e-16      0.001   3.33e-13      1.000      -0.001       0.001
# C(item_nbr)[T.49]   2.272e-16      0.001   2.98e-13      1.000      -0.001       0.001
# C(item_nbr)[T.50]   2.236e-16      0.001   2.94e-13      1.000      -0.001       0.001
# C(item_nbr)[T.51]   2.566e-16      0.001   3.37e-13      1.000      -0.001       0.001
# C(item_nbr)[T.52]   1.266e-16      0.001   1.66e-13      1.000      -0.001       0.001
# C(item_nbr)[T.53]    2.13e-16      0.001    2.8e-13      1.000      -0.001       0.001
# C(item_nbr)[T.54]   2.879e-16      0.001   3.78e-13      1.000      -0.001       0.001
# C(item_nbr)[T.55]   1.139e-16      0.001    1.5e-13      1.000      -0.001       0.001
# C(item_nbr)[T.56]    1.63e-16      0.001   2.14e-13      1.000      -0.001       0.001
# C(item_nbr)[T.57]   2.798e-16      0.001   3.67e-13      1.000      -0.001       0.001
# C(item_nbr)[T.58]   1.875e-16      0.001   2.46e-13      1.000      -0.001       0.001
# C(item_nbr)[T.59]   2.125e-16      0.001   2.79e-13      1.000      -0.001       0.001
# C(item_nbr)[T.60]   2.117e-16      0.001   2.78e-13      1.000      -0.001       0.001
# C(item_nbr)[T.61]   2.662e-16      0.001   3.49e-13      1.000      -0.001       0.001
# C(item_nbr)[T.62]    2.35e-16      0.001   3.09e-13      1.000      -0.001       0.001
# C(item_nbr)[T.63]    2.43e-16      0.001   3.19e-13      1.000      -0.001       0.001
# C(item_nbr)[T.64]   1.864e-16      0.001   2.45e-13      1.000      -0.001       0.001
# C(item_nbr)[T.65]   3.678e-16      0.001   4.83e-13      1.000      -0.001       0.001
# C(item_nbr)[T.66]   1.707e-16      0.001   2.24e-13      1.000      -0.001       0.001
# C(item_nbr)[T.67]   1.821e-16      0.001   2.39e-13      1.000      -0.001       0.001
# C(item_nbr)[T.68]  -4.491e-16      0.001   -5.9e-13      1.000      -0.001       0.001
# C(item_nbr)[T.69]      0.6931      0.001    520.681      0.000       0.690       0.696
# C(item_nbr)[T.70]  -1.173e-17      0.001  -1.54e-14      1.000      -0.001       0.001
# C(item_nbr)[T.71]  -2.399e-17      0.001  -3.15e-14      1.000      -0.001       0.001
# C(item_nbr)[T.72]   9.866e-18      0.001    1.3e-14      1.000      -0.001       0.001
# C(item_nbr)[T.73]   1.103e-16      0.001   1.45e-13      1.000      -0.001       0.001
# C(item_nbr)[T.74]   3.111e-16      0.001   4.08e-13      1.000      -0.001       0.001
# C(item_nbr)[T.75]      0.0002      0.001      0.200      0.842      -0.002       0.002
# C(item_nbr)[T.76]   1.036e-16      0.001   1.36e-13      1.000      -0.001       0.001
# C(item_nbr)[T.77]   1.371e-16      0.001    1.8e-13      1.000      -0.001       0.001
# C(item_nbr)[T.78]   2.804e-16      0.001   3.68e-13      1.000      -0.001       0.001
# C(item_nbr)[T.79]   1.302e-16      0.001   1.71e-13      1.000      -0.001       0.001
# C(item_nbr)[T.80]   7.303e-17      0.001   9.59e-14      1.000      -0.001       0.001
# C(item_nbr)[T.81]   4.408e-16      0.001   5.79e-13      1.000      -0.001       0.001
# C(item_nbr)[T.82]   1.136e-16      0.001   1.49e-13      1.000      -0.001       0.001
# C(item_nbr)[T.83]      2.2664      0.001   2360.299      0.000       2.265       2.268
# C(item_nbr)[T.84]   1.135e-17      0.001   1.49e-14      1.000      -0.001       0.001
# C(item_nbr)[T.85]   3.079e-16      0.001   4.04e-13      1.000      -0.001       0.001
# C(item_nbr)[T.86]   2.472e-16      0.001   3.25e-13      1.000      -0.001       0.001
# C(item_nbr)[T.87]    3.11e-16      0.001   4.08e-13      1.000      -0.001       0.001
# C(item_nbr)[T.88]   7.372e-06      0.001      0.009      0.992      -0.002       0.002
# C(item_nbr)[T.89]   2.587e-16      0.001    3.4e-13      1.000      -0.001       0.001
# C(item_nbr)[T.90]   2.654e-16      0.001   3.48e-13      1.000      -0.001       0.001
# C(item_nbr)[T.91]   2.887e-16      0.001   3.79e-13      1.000      -0.001       0.001
# C(item_nbr)[T.92]   2.145e-16      0.001   2.82e-13      1.000      -0.001       0.001
# C(item_nbr)[T.93]      0.0001      0.001      0.134      0.893      -0.002       0.002
# C(item_nbr)[T.94]   2.669e-16      0.001    3.5e-13      1.000      -0.001       0.001
# C(item_nbr)[T.95]   2.423e-16      0.001   3.18e-13      1.000      -0.001       0.001
# C(item_nbr)[T.96]   3.609e-16      0.001   4.74e-13      1.000      -0.001       0.001
# C(item_nbr)[T.97]   4.182e-17      0.001   5.49e-14      1.000      -0.001       0.001
# C(item_nbr)[T.98]    3.94e-16      0.001   5.17e-13      1.000      -0.001       0.001
# C(item_nbr)[T.99]   4.077e-16      0.001   5.35e-13      1.000      -0.001       0.001
# C(item_nbr)[T.100]  2.823e-16      0.001   3.71e-13      1.000      -0.001       0.001
# C(item_nbr)[T.101]  2.309e-16      0.001   3.03e-13      1.000      -0.001       0.001
# C(item_nbr)[T.102]  2.085e-16      0.001   2.74e-13      1.000      -0.001       0.001
# C(item_nbr)[T.103]  4.566e-16      0.001      6e-13      1.000      -0.001       0.001
# C(item_nbr)[T.104]  3.837e-16      0.001   5.04e-13      1.000      -0.001       0.001
# C(item_nbr)[T.105]  1.497e-17      0.001   1.97e-14      1.000      -0.001       0.001
# C(item_nbr)[T.106]  2.282e-16      0.001      3e-13      1.000      -0.001       0.001
# C(item_nbr)[T.107]  2.631e-16      0.001   3.45e-13      1.000      -0.001       0.001
# C(item_nbr)[T.108]  2.769e-16      0.001   3.64e-13      1.000      -0.001       0.001
# C(item_nbr)[T.109]  2.251e-16      0.001   2.96e-13      1.000      -0.001       0.001
# C(item_nbr)[T.110]  4.119e-16      0.001   5.41e-13      1.000      -0.001       0.001
# C(item_nbr)[T.111] -3.452e-17      0.001  -4.53e-14      1.000      -0.001       0.001
# C(weekend)[T.1]        0.0006      0.000      4.967      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                    66358.748   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        194679696.134
# Skew:                          -1.754   Prob(JB):                         0.00
# Kurtosis:                     224.965   Cond. No.                         84.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from patsy import dmatrix
# 독립변수와 종속변수로 나누기
df2_1_X = df2_1.drop(columns=['log1p_units'])
df2_1_target = df2_1['log1p_units']

# %%
formula = 'C(year) + C(month) + C(weekend) + C(item_nbr) + 0'
dfX = dmatrix(formula, df2_1_X, return_type='dataframe')
dfy = pd.DataFrame(df2_1_target, columns=["log1p_units"])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score

model = LinearRegression()
cv = KFold(10)

scores = np.zeros(10)
for i, (train_index, test_index) in enumerate(cv.split(dfX)):
    X_train = dfX.values[train_index]
    y_train = dfy.values[train_index]
    X_test = dfX.values[test_index]
    y_test = dfy.values[test_index]
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    scores[i] = r2_score(y_test, y_pred)

scores
# Out:
# array([0.99617829, 0.99561219, 0.99589103, 0.99624464, 0.99630669,
#        0.99555641, 0.99527943, 0.9958109 , 0.99451679, 0.99419166])
