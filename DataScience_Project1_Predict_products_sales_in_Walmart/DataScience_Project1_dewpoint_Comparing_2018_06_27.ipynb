# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

data_key = pd.read_csv('key.csv')
data_key = data_key[data_key['station_nbr'] != 5]
data_weather = pd.read_csv('weather.csv')
data_weather = data_weather[data_weather['station_nbr'] != 5] ## Station 5번 제거한 나머지
data_train = pd.read_csv('train.csv')

df = pd.merge(data_weather, data_key)
station_nbr = df['station_nbr']
df.drop('station_nbr', axis=1, inplace=True)
df['station_nbr'] = station_nbr
df = pd.merge(df, data_train)
# Station 5번을 뺀 나머지 Merge 완성
# 'M'과 '-'을 np.nan으로 값을 변경하기 전에, '  T'값을 먼저 snowfall=0.05, preciptotal = 0.005로 변경하자 
df['snowfall'][df['snowfall'] == '  T'] = 0.05
df['preciptotal'][df['preciptotal'] == '  T'] = 0.005
df['snowfall'][df['snowfall'] == '  T'], df['preciptotal'][df['preciptotal'] == '  T']
# T 값 변경 완료. 이제, 19개 Station 별로 정리하기 (5번 Station 생략)
df['snowfall'][df['snowfall'] == '  T'] = 0.05
df['preciptotal'][df['preciptotal'] == '  T'] = 0.005
# T 값 변경 완료. 이제, 19개 Station 별로 정리하기 (5번 Station 생략)
df_s_1 = df[df['station_nbr'] == 1]; df_s_8 = df[df['station_nbr'] == 8]; df_s_15 = df[df['station_nbr'] == 15]
df_s_2 = df[df['station_nbr'] == 2]; df_s_9 = df[df['station_nbr'] == 9]; df_s_16 = df[df['station_nbr'] == 16]
df_s_3 = df[df['station_nbr'] == 3]; df_s_10 = df[df['station_nbr'] == 10]; df_s_17 = df[df['station_nbr'] == 17]
df_s_4 = df[df['station_nbr'] == 4]; df_s_11 = df[df['station_nbr'] == 11]; df_s_18 = df[df['station_nbr'] == 18]
df_s_5 = df[df['station_nbr'] == 5]; df_s_12 = df[df['station_nbr'] == 12]; df_s_19 = df[df['station_nbr'] == 19]
df_s_6 = df[df['station_nbr'] == 6]; df_s_13 = df[df['station_nbr'] == 13]; df_s_20 = df[df['station_nbr'] == 20]
df_s_7 = df[df['station_nbr'] == 7]; df_s_14 = df[df['station_nbr'] == 14]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# ...

# %%
# Each Station dewpoint 의 M값을 np.nan으로 변경
df_s_1_dewpoint = df_s_1['dewpoint'].copy(); df_s_1_dewpoint = pd.to_numeric(df_s_1_dewpoint, errors = 'coerce')
df_s_2_dewpoint = df_s_2['dewpoint'].copy(); df_s_2_dewpoint = pd.to_numeric(df_s_2_dewpoint, errors = 'coerce')
df_s_3_dewpoint = df_s_3['dewpoint'].copy(); df_s_3_dewpoint = pd.to_numeric(df_s_3_dewpoint, errors = 'coerce')
df_s_4_dewpoint = df_s_4['dewpoint'].copy(); df_s_4_dewpoint = pd.to_numeric(df_s_4_dewpoint, errors = 'coerce')
df_s_5_dewpoint = df_s_5['dewpoint'].copy(); df_s_5_dewpoint = pd.to_numeric(df_s_5_dewpoint, errors = 'coerce')
df_s_6_dewpoint = df_s_6['dewpoint'].copy(); df_s_6_dewpoint = pd.to_numeric(df_s_6_dewpoint, errors = 'coerce')
df_s_7_dewpoint = df_s_7['dewpoint'].copy(); df_s_7_dewpoint = pd.to_numeric(df_s_7_dewpoint, errors = 'coerce')
df_s_8_dewpoint = df_s_8['dewpoint'].copy(); df_s_8_dewpoint = pd.to_numeric(df_s_8_dewpoint, errors = 'coerce')
df_s_9_dewpoint = df_s_9['dewpoint'].copy(); df_s_9_dewpoint = pd.to_numeric(df_s_9_dewpoint, errors = 'coerce')
df_s_10_dewpoint = df_s_10['dewpoint'].copy(); df_s_10_dewpoint = pd.to_numeric(df_s_10_dewpoint, errors = 'coerce')
df_s_11_dewpoint = df_s_11['dewpoint'].copy(); df_s_11_dewpoint = pd.to_numeric(df_s_11_dewpoint, errors = 'coerce')
df_s_12_dewpoint = df_s_12['dewpoint'].copy(); df_s_12_dewpoint = pd.to_numeric(df_s_12_dewpoint, errors = 'coerce')
df_s_13_dewpoint = df_s_13['dewpoint'].copy(); df_s_13_dewpoint = pd.to_numeric(df_s_13_dewpoint, errors = 'coerce')
df_s_14_dewpoint = df_s_14['dewpoint'].copy(); df_s_14_dewpoint = pd.to_numeric(df_s_14_dewpoint, errors = 'coerce')
df_s_15_dewpoint = df_s_15['dewpoint'].copy(); df_s_15_dewpoint = pd.to_numeric(df_s_15_dewpoint, errors = 'coerce')
df_s_16_dewpoint = df_s_16['dewpoint'].copy(); df_s_16_dewpoint = pd.to_numeric(df_s_16_dewpoint, errors = 'coerce')
df_s_17_dewpoint = df_s_17['dewpoint'].copy(); df_s_17_dewpoint = pd.to_numeric(df_s_17_dewpoint, errors = 'coerce')
df_s_18_dewpoint = df_s_18['dewpoint'].copy(); df_s_18_dewpoint = pd.to_numeric(df_s_18_dewpoint, errors = 'coerce')
df_s_19_dewpoint = df_s_19['dewpoint'].copy(); df_s_19_dewpoint = pd.to_numeric(df_s_19_dewpoint, errors = 'coerce')
df_s_20_dewpoint = df_s_20['dewpoint'].copy(); df_s_20_dewpoint = pd.to_numeric(df_s_20_dewpoint, errors = 'coerce')

# 각 각의 Station의 Nan 값에, 위에서 구한 각각 station의 평균 값을 넣어서 NaN 값 뺏을 때와 비교할 것.
df_s_1_dewpoint_with_mean = df_s_1_dewpoint.copy(); df_s_1_dewpoint_with_mean[df_s_1_dewpoint_with_mean.isnull()] = df_s_1_dewpoint.mean()
df_s_2_dewpoint_with_mean = df_s_2_dewpoint.copy(); df_s_2_dewpoint_with_mean[df_s_2_dewpoint_with_mean.isnull()] = df_s_2_dewpoint.mean()
df_s_3_dewpoint_with_mean = df_s_3_dewpoint.copy(); df_s_3_dewpoint_with_mean[df_s_3_dewpoint_with_mean.isnull()] = df_s_3_dewpoint.mean()
df_s_4_dewpoint_with_mean = df_s_4_dewpoint.copy(); df_s_4_dewpoint_with_mean[df_s_4_dewpoint_with_mean.isnull()] = df_s_4_dewpoint.mean()
df_s_5_dewpoint_with_mean = df_s_5_dewpoint.copy(); df_s_5_dewpoint_with_mean[df_s_5_dewpoint_with_mean.isnull()] = df_s_5_dewpoint.mean()
df_s_6_dewpoint_with_mean = df_s_6_dewpoint.copy(); df_s_6_dewpoint_with_mean[df_s_6_dewpoint_with_mean.isnull()] = df_s_6_dewpoint.mean()
df_s_7_dewpoint_with_mean = df_s_7_dewpoint.copy(); df_s_7_dewpoint_with_mean[df_s_7_dewpoint_with_mean.isnull()] = df_s_7_dewpoint.mean()
df_s_8_dewpoint_with_mean = df_s_8_dewpoint.copy(); df_s_8_dewpoint_with_mean[df_s_8_dewpoint_with_mean.isnull()] = df_s_8_dewpoint.mean()
df_s_9_dewpoint_with_mean = df_s_9_dewpoint.copy(); df_s_9_dewpoint_with_mean[df_s_9_dewpoint_with_mean.isnull()] = df_s_9_dewpoint.mean()
df_s_10_dewpoint_with_mean = df_s_10_dewpoint.copy(); df_s_10_dewpoint_with_mean[df_s_10_dewpoint_with_mean.isnull()] = df_s_10_dewpoint.mean()
df_s_11_dewpoint_with_mean = df_s_11_dewpoint.copy(); df_s_11_dewpoint_with_mean[df_s_11_dewpoint_with_mean.isnull()] = df_s_11_dewpoint.mean()
df_s_12_dewpoint_with_mean = df_s_12_dewpoint.copy(); df_s_12_dewpoint_with_mean[df_s_12_dewpoint_with_mean.isnull()] = df_s_12_dewpoint.mean()
df_s_13_dewpoint_with_mean = df_s_13_dewpoint.copy(); df_s_13_dewpoint_with_mean[df_s_13_dewpoint_with_mean.isnull()] = df_s_13_dewpoint.mean()
df_s_14_dewpoint_with_mean = df_s_14_dewpoint.copy(); df_s_14_dewpoint_with_mean[df_s_14_dewpoint_with_mean.isnull()] = df_s_14_dewpoint.mean()
df_s_15_dewpoint_with_mean = df_s_15_dewpoint.copy(); df_s_15_dewpoint_with_mean[df_s_15_dewpoint_with_mean.isnull()] = df_s_15_dewpoint.mean()
df_s_16_dewpoint_with_mean = df_s_16_dewpoint.copy(); df_s_16_dewpoint_with_mean[df_s_16_dewpoint_with_mean.isnull()] = df_s_16_dewpoint.mean()
df_s_17_dewpoint_with_mean = df_s_17_dewpoint.copy(); df_s_17_dewpoint_with_mean[df_s_17_dewpoint_with_mean.isnull()] = df_s_17_dewpoint.mean()
df_s_18_dewpoint_with_mean = df_s_18_dewpoint.copy(); df_s_18_dewpoint_with_mean[df_s_18_dewpoint_with_mean.isnull()] = df_s_18_dewpoint.mean()
df_s_19_dewpoint_with_mean = df_s_19_dewpoint.copy(); df_s_19_dewpoint_with_mean[df_s_19_dewpoint_with_mean.isnull()] = df_s_19_dewpoint.mean()
df_s_20_dewpoint_with_mean = df_s_20_dewpoint.copy(); df_s_20_dewpoint_with_mean[df_s_20_dewpoint_with_mean.isnull()] = df_s_20_dewpoint.mean()

# 각 각의 Station 별로 dewpoint의 값이 np.nan일 때, 즉, missing value를 뺏을 때의 전체 mean 값을 나타낸다. 
print('#station1_without_nan_mean:', round(df_s_1_dewpoint.mean(),4), '#station1_without_nan_std:', round(df_s_1_dewpoint.std(),4)); 
print('#station2_without_nan_mean:', round(df_s_2_dewpoint.mean(),4), '#station2_without_nan_std:', round(df_s_2_dewpoint.std(),4)); 
print('#station3_without_nan_mean:', round(df_s_3_dewpoint.mean(),4), '#station3_without_nan_std:', round(df_s_3_dewpoint.std(),4)); 
print('#station4_without_nan_mean:', round(df_s_4_dewpoint.mean(),4), '#station4_without_nan_std:', round(df_s_4_dewpoint.std(),4)); 
print('#station5_without_nan_mean:', round(df_s_5_dewpoint.mean(),4), '#station5_without_nan_std:', round(df_s_5_dewpoint.std(),4)); 
print('#station6_without_nan_mean:', round(df_s_6_dewpoint.mean(),4), '#station6_without_nan_std:', round(df_s_6_dewpoint.std(),4)); 
print('#station7_without_nan_mean:', round(df_s_7_dewpoint.mean(),4), '#station7_without_nan_std:', round(df_s_7_dewpoint.std(),4)); 
print('#station8_without_nan_mean:', round(df_s_8_dewpoint.mean(),4), '#station8_without_nan_std:', round(df_s_8_dewpoint.std(),4)); 
print('#station9_without_nan_mean:', round(df_s_9_dewpoint.mean(),4), '#station9_without_nan_std:', round(df_s_9_dewpoint.std(),4)); 
print('#station10_without_nan_mean:', round(df_s_10_dewpoint.mean(),4), '#station10_without_nan_std:', round(df_s_10_dewpoint.std(),4));  
print('#station11_without_nan_mean:', round(df_s_11_dewpoint.mean(),4), '#station11_without_nan_std:', round(df_s_11_dewpoint.std(),4)); 
print('#station12_without_nan_mean:', round(df_s_12_dewpoint.mean(),4), '#station12_without_nan_std:', round(df_s_12_dewpoint.std(),4)); 
print('#station13_without_nan_mean:', round(df_s_13_dewpoint.mean(),4), '#station13_without_nan_std:', round(df_s_13_dewpoint.std(),4)); 
print('#station14_without_nan_mean:', round(df_s_14_dewpoint.mean(),4), '#station14_without_nan_std:', round(df_s_14_dewpoint.std(),4)); 
print('#station15_without_nan_mean:', round(df_s_15_dewpoint.mean(),4), '#station15_without_nan_std:', round(df_s_15_dewpoint.std(),4)); 
print('#station16_without_nan_mean:', round(df_s_16_dewpoint.mean(),4), '#station16_without_nan_std:', round(df_s_16_dewpoint.std(),4)); 
print('#station17_without_nan_mean:', round(df_s_17_dewpoint.mean(),4), '#station17_without_nan_std:', round(df_s_17_dewpoint.std(),4)); 
print('#station18_without_nan_mean:', round(df_s_18_dewpoint.mean(),4), '#station18_without_nan_std:', round(df_s_18_dewpoint.std(),4)); 
print('#station19_without_nan_mean:', round(df_s_19_dewpoint.mean(),4), '#station19_without_nan_std:', round(df_s_19_dewpoint.std(),4)); 
print('#station20_without_nan_mean:', round(df_s_20_dewpoint.mean(),4), '#station20_without_nan_std:', round(df_s_20_dewpoint.std(),4)); 

print('stat1_nan_as_mean:',round(df_s_1_dewpoint_with_mean.mean(),4),'#stat1_nan_as_std:', round(df_s_1_dewpoint_with_mean.std(),4));
print('stat2_nan_as_mean:',round(df_s_2_dewpoint_with_mean.mean(),4),'#stat2_nan_as_std:', round(df_s_2_dewpoint_with_mean.std(),4));
print('stat3_nan_as_mean:',round(df_s_3_dewpoint_with_mean.mean(),4),'#stat3_nan_as_std:', round(df_s_3_dewpoint_with_mean.std(),4));
print('stat4_nan_as_mean:',round(df_s_4_dewpoint_with_mean.mean(),4),'#stat4_nan_as_std:', round(df_s_4_dewpoint_with_mean.std(),4));
print('stat5_nan_as_mean:',round(df_s_5_dewpoint_with_mean.mean(),4),'#stat5_nan_as_std:', round(df_s_5_dewpoint_with_mean.std(),4));
print('stat6_nan_as_mean:',round(df_s_6_dewpoint_with_mean.mean(),4),'#stat6_nan_as_std:', round(df_s_6_dewpoint_with_mean.std(),4));
print('stat7_nan_as_mean:',round(df_s_7_dewpoint_with_mean.mean(),4),'#stat7_nan_as_std:', round(df_s_7_dewpoint_with_mean.std(),4));
print('stat8_nan_as_mean:',round(df_s_8_dewpoint_with_mean.mean(),4),'#stat8_nan_as_std:', round(df_s_8_dewpoint_with_mean.std(),4));
print('stat9_nan_as_mean:',round(df_s_9_dewpoint_with_mean.mean(),4),'#stat9_nan_as_std:', round(df_s_9_dewpoint_with_mean.std(),4));
print('stat10_nan_as_mean:',round(df_s_10_dewpoint_with_mean.mean(),4),'#stat10_nan_as_std:', round(df_s_10_dewpoint_with_mean.std(),4));
print('stat11_nan_as_mean:',round(df_s_11_dewpoint_with_mean.mean(),4),'#stat11_nan_as_std:', round(df_s_11_dewpoint_with_mean.std(),4));
print('stat12_nan_as_mean:',round(df_s_12_dewpoint_with_mean.mean(),4),'#stat12_nan_as_std:', round(df_s_12_dewpoint_with_mean.std(),4));
print('stat13_nan_as_mean:',round(df_s_13_dewpoint_with_mean.mean(),4),'#stat13_nan_as_std:', round(df_s_13_dewpoint_with_mean.std(),4));
print('stat14_nan_as_mean:',round(df_s_14_dewpoint_with_mean.mean(),4),'#stat14_nan_as_std:', round(df_s_14_dewpoint_with_mean.std(),4));
print('stat15_nan_as_mean:',round(df_s_15_dewpoint_with_mean.mean(),4),'#stat15_nan_as_std:', round(df_s_15_dewpoint_with_mean.std(),4));
print('stat16_nan_as_mean:',round(df_s_16_dewpoint_with_mean.mean(),4),'#stat16_nan_as_std:', round(df_s_16_dewpoint_with_mean.std(),4));
print('stat17_nan_as_mean:',round(df_s_17_dewpoint_with_mean.mean(),4),'#stat17_nan_as_std:', round(df_s_17_dewpoint_with_mean.std(),4));
print('stat18_nan_as_mean:',round(df_s_18_dewpoint_with_mean.mean(),4),'#stat18_nan_as_std:', round(df_s_18_dewpoint_with_mean.std(),4));
print('stat19_nan_as_mean:',round(df_s_19_dewpoint_with_mean.mean(),4),'#stat19_nan_as_std:', round(df_s_19_dewpoint_with_mean.std(),4));
print('stat20_nan_as_mean:',round(df_s_20_dewpoint_with_mean.mean(),4),'#stat20_nan_as_std:', round(df_s_20_dewpoint_with_mean.std(),4));
# Out:
# #station1_without_nan_mean: 37.9449 #station1_without_nan_std: 19.0444
# #station2_without_nan_mean: 38.5041 #station2_without_nan_std: 18.9149
# #station3_without_nan_mean: 47.0853 #station3_without_nan_std: 17.8316
# #station4_without_nan_mean: 54.3541 #station4_without_nan_std: 15.2066
# #station5_without_nan_mean: nan #station5_without_nan_std: nan
# #station6_without_nan_mean: 55.3898 #station6_without_nan_std: 14.9869
# #station7_without_nan_mean: 45.0744 #station7_without_nan_std: 17.8997
# #station8_without_nan_mean: 58.3056 #station8_without_nan_std: 14.7894
# #station9_without_nan_mean: 34.9672 #station9_without_nan_std: 21.3547
# #station10_without_nan_mean: 59.833 #station10_without_nan_std: 13.0264
# #station11_without_nan_mean: 59.5282 #station11_without_nan_std: 13.3596
# #station12_without_nan_mean: 59.4645 #station12_without_nan_std: 12.7723
# #station13_without_nan_mean: 28.3917 #station13_without_nan_std: 14.2761
# ...

# %%
y1 = np.array([df_s_1_dewpoint.mean(), df_s_2_dewpoint.mean(), df_s_3_dewpoint.mean(), df_s_4_dewpoint.mean(), df_s_5_dewpoint.mean(),
             df_s_6_dewpoint.mean(), df_s_7_dewpoint.mean(), df_s_8_dewpoint.mean(), df_s_9_dewpoint.mean(), df_s_10_dewpoint.mean(), 
             df_s_11_dewpoint.mean(), df_s_12_dewpoint.mean(), df_s_13_dewpoint.mean(), df_s_14_dewpoint.mean(), df_s_15_dewpoint.mean(),
             df_s_16_dewpoint.mean(), df_s_17_dewpoint.mean(), df_s_18_dewpoint.mean(), df_s_19_dewpoint.mean(), df_s_20_dewpoint.mean()])

y2 = np.array([df_s_1_dewpoint_with_mean.mean(), df_s_2_dewpoint_with_mean.mean(), df_s_3_dewpoint_with_mean.mean(), df_s_4_dewpoint_with_mean.mean()
             ,df_s_5_dewpoint_with_mean.mean(), df_s_6_dewpoint_with_mean.mean(), df_s_7_dewpoint_with_mean.mean(), df_s_8_dewpoint_with_mean.mean()
             ,df_s_9_dewpoint_with_mean.mean(), df_s_10_dewpoint_with_mean.mean(), df_s_11_dewpoint_with_mean.mean(), df_s_12_dewpoint_with_mean.mean()
             ,df_s_13_dewpoint_with_mean.mean(), df_s_14_dewpoint_with_mean.mean(), df_s_15_dewpoint_with_mean.mean(), df_s_16_dewpoint_with_mean.mean()
             ,df_s_17_dewpoint_with_mean.mean(),df_s_18_dewpoint_with_mean.mean(),df_s_19_dewpoint_with_mean.mean(),df_s_20_dewpoint_with_mean.mean()])

plt.figure(figsize=(10,5))
plt.plot()
x = range(1, 21)
plt.xlabel('Station Number')
plt.ylabel('dewpoint')
plt.bar(x, y1, color='y')
plt.bar(x, y2, color='r')
plt.show()

#### dewpoint 에서는
# 이 Graph가 나타내는 바는, y1과 y2가 차이가 거의 없다는 것. 그래프에는 r color와 y color이 있는데, 하나만 보인다는 것은
# 우리가 그래프에서 눈으로 보이지 않는 정도의 차이가 나온다는 것이다, 즉 차이가 극히 작다고 판단 할 수 있다.
# Missing Values를 np.nan으로 바꾸고, 거기서 Mean 값을 구하여 np.nan에 대입하여도, 
# 따라서, 여기서는 Missing Value에 Mean값을 적용하여 회귀 분석에 적용 할 수있다고 판단된다. 
plt.figure(figsize=(12,6))
xticks = range(1,21)
plt.plot(xticks, y1, 'ro-', label='stations_without_nan_mean')
plt.plot(xticks, y2, 'bd:', label='stations_nan_as_mean')
plt.legend(loc=0)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
y3 = np.array([df_s_1_dewpoint.std(), df_s_2_dewpoint.std(), df_s_3_dewpoint.std(), df_s_4_dewpoint.std(), df_s_5_dewpoint.std(),
             df_s_6_dewpoint.std(), df_s_7_dewpoint.std(), df_s_8_dewpoint.std(), df_s_9_dewpoint.std(), df_s_10_dewpoint.std(), 
             df_s_11_dewpoint.std(), df_s_12_dewpoint.std(), df_s_13_dewpoint.std(), df_s_14_dewpoint.std(), df_s_15_dewpoint.std(),
             df_s_16_dewpoint.std(), df_s_17_dewpoint.std(), df_s_18_dewpoint.std(), df_s_19_dewpoint.std(), df_s_20_dewpoint.std()])

y4 = np.array([df_s_1_dewpoint_with_mean.std(), df_s_2_dewpoint_with_mean.std(), df_s_3_dewpoint_with_mean.std(), df_s_4_dewpoint_with_mean.std()
             ,df_s_5_dewpoint_with_mean.std(), df_s_6_dewpoint_with_mean.std(), df_s_7_dewpoint_with_mean.std(), df_s_8_dewpoint_with_mean.std()
             ,df_s_9_dewpoint_with_mean.std(), df_s_10_dewpoint_with_mean.std(), df_s_11_dewpoint_with_mean.std(), df_s_12_dewpoint_with_mean.std()
             ,df_s_13_dewpoint_with_mean.std(), df_s_14_dewpoint_with_mean.std(), df_s_15_dewpoint_with_mean.std(), df_s_16_dewpoint_with_mean.std()
             ,df_s_17_dewpoint_with_mean.std(),df_s_18_dewpoint_with_mean.std(),df_s_19_dewpoint_with_mean.std(),df_s_20_dewpoint_with_mean.std()])

plt.figure(figsize=(10,5))
plt.plot()
x = range(1, 21)
plt.xlabel('Station Number')
plt.ylabel('dewpoint')
plt.bar(x, y3, color='r')
plt.bar(x, y4, color='g')
plt.show()

plt.figure(figsize=(12,6))
xticks = range(1,21)
plt.plot(xticks, y3, 'ro-', label='stations_without_nan_std')
plt.plot(xticks, y4, 'bd:', label='stations_nan_as_std')
plt.legend(loc=0)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
