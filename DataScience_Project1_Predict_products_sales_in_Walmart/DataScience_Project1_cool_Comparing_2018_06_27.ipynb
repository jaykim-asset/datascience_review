# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

data_key = pd.read_csv('key.csv')
data_key = data_key[data_key['station_nbr'] != 5]
data_weather = pd.read_csv('weather.csv')
data_weather = data_weather[data_weather['station_nbr'] != 5] ## Station 5번 제거한 나머지
data_train = pd.read_csv('train.csv')

df = pd.merge(data_weather, data_key)
station_nbr = df['station_nbr']
df.drop('station_nbr', axis=1, inplace=True)
df['station_nbr'] = station_nbr
df = pd.merge(df, data_train)
# Station 5번을 뺀 나머지 Merge 완성
# 'M'과 '-'을 np.nan으로 값을 변경하기 전에, '  T'값을 먼저 snowfall=0.05, preciptotal = 0.005로 변경하자 
df['snowfall'][df['snowfall'] == '  T'] = 0.05
df['preciptotal'][df['preciptotal'] == '  T'] = 0.005
df['snowfall'][df['snowfall'] == '  T'], df['preciptotal'][df['preciptotal'] == '  T']
# T 값 변경 완료. 이제, 19개 Station 별로 정리하기 (5번 Station 생략)
df['snowfall'][df['snowfall'] == '  T'] = 0.05
df['preciptotal'][df['preciptotal'] == '  T'] = 0.005
# T 값 변경 완료. 이제, 19개 Station 별로 정리하기 (5번 Station 생략)
df_s_1 = df[df['station_nbr'] == 1]; df_s_8 = df[df['station_nbr'] == 8]; df_s_15 = df[df['station_nbr'] == 15]
df_s_2 = df[df['station_nbr'] == 2]; df_s_9 = df[df['station_nbr'] == 9]; df_s_16 = df[df['station_nbr'] == 16]
df_s_3 = df[df['station_nbr'] == 3]; df_s_10 = df[df['station_nbr'] == 10]; df_s_17 = df[df['station_nbr'] == 17]
df_s_4 = df[df['station_nbr'] == 4]; df_s_11 = df[df['station_nbr'] == 11]; df_s_18 = df[df['station_nbr'] == 18]
df_s_5 = df[df['station_nbr'] == 5]; df_s_12 = df[df['station_nbr'] == 12]; df_s_19 = df[df['station_nbr'] == 19]
df_s_6 = df[df['station_nbr'] == 6]; df_s_13 = df[df['station_nbr'] == 13]; df_s_20 = df[df['station_nbr'] == 20]
df_s_7 = df[df['station_nbr'] == 7]; df_s_14 = df[df['station_nbr'] == 14]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# ...

# %%
# Each Station cool 의 M값을 np.nan으로 변경
df_s_1_cool = df_s_1['cool'].copy(); df_s_1_cool = pd.to_numeric(df_s_1_cool, errors = 'coerce')
df_s_2_cool = df_s_2['cool'].copy(); df_s_2_cool = pd.to_numeric(df_s_2_cool, errors = 'coerce')
df_s_3_cool = df_s_3['cool'].copy(); df_s_3_cool = pd.to_numeric(df_s_3_cool, errors = 'coerce')
df_s_4_cool = df_s_4['cool'].copy(); df_s_4_cool = pd.to_numeric(df_s_4_cool, errors = 'coerce')
df_s_5_cool = df_s_5['cool'].copy(); df_s_5_cool = pd.to_numeric(df_s_5_cool, errors = 'coerce')
df_s_6_cool = df_s_6['cool'].copy(); df_s_6_cool = pd.to_numeric(df_s_6_cool, errors = 'coerce')
df_s_7_cool = df_s_7['cool'].copy(); df_s_7_cool = pd.to_numeric(df_s_7_cool, errors = 'coerce')
df_s_8_cool = df_s_8['cool'].copy(); df_s_8_cool = pd.to_numeric(df_s_8_cool, errors = 'coerce')
df_s_9_cool = df_s_9['cool'].copy(); df_s_9_cool = pd.to_numeric(df_s_9_cool, errors = 'coerce')
df_s_10_cool = df_s_10['cool'].copy(); df_s_10_cool = pd.to_numeric(df_s_10_cool, errors = 'coerce')
df_s_11_cool = df_s_11['cool'].copy(); df_s_11_cool = pd.to_numeric(df_s_11_cool, errors = 'coerce')
df_s_12_cool = df_s_12['cool'].copy(); df_s_12_cool = pd.to_numeric(df_s_12_cool, errors = 'coerce')
df_s_13_cool = df_s_13['cool'].copy(); df_s_13_cool = pd.to_numeric(df_s_13_cool, errors = 'coerce')
df_s_14_cool = df_s_14['cool'].copy(); df_s_14_cool = pd.to_numeric(df_s_14_cool, errors = 'coerce')
df_s_15_cool = df_s_15['cool'].copy(); df_s_15_cool = pd.to_numeric(df_s_15_cool, errors = 'coerce')
df_s_16_cool = df_s_16['cool'].copy(); df_s_16_cool = pd.to_numeric(df_s_16_cool, errors = 'coerce')
df_s_17_cool = df_s_17['cool'].copy(); df_s_17_cool = pd.to_numeric(df_s_17_cool, errors = 'coerce')
df_s_18_cool = df_s_18['cool'].copy(); df_s_18_cool = pd.to_numeric(df_s_18_cool, errors = 'coerce')
df_s_19_cool = df_s_19['cool'].copy(); df_s_19_cool = pd.to_numeric(df_s_19_cool, errors = 'coerce')
df_s_20_cool = df_s_20['cool'].copy(); df_s_20_cool = pd.to_numeric(df_s_20_cool, errors = 'coerce')

# 각 각의 Station의 Nan 값에, 위에서 구한 각각 station의 평균 값을 넣어서 NaN 값 뺏을 때와 비교할 것.
df_s_1_cool_with_mean = df_s_1_cool.copy(); df_s_1_cool_with_mean[df_s_1_cool_with_mean.isnull()] = df_s_1_cool.mean()
df_s_2_cool_with_mean = df_s_2_cool.copy(); df_s_2_cool_with_mean[df_s_2_cool_with_mean.isnull()] = df_s_2_cool.mean()
df_s_3_cool_with_mean = df_s_3_cool.copy(); df_s_3_cool_with_mean[df_s_3_cool_with_mean.isnull()] = df_s_3_cool.mean()
df_s_4_cool_with_mean = df_s_4_cool.copy(); df_s_4_cool_with_mean[df_s_4_cool_with_mean.isnull()] = df_s_4_cool.mean()
df_s_5_cool_with_mean = df_s_5_cool.copy(); df_s_5_cool_with_mean[df_s_5_cool_with_mean.isnull()] = df_s_5_cool.mean()
df_s_6_cool_with_mean = df_s_6_cool.copy(); df_s_6_cool_with_mean[df_s_6_cool_with_mean.isnull()] = df_s_6_cool.mean()
df_s_7_cool_with_mean = df_s_7_cool.copy(); df_s_7_cool_with_mean[df_s_7_cool_with_mean.isnull()] = df_s_7_cool.mean()
df_s_8_cool_with_mean = df_s_8_cool.copy(); df_s_8_cool_with_mean[df_s_8_cool_with_mean.isnull()] = df_s_8_cool.mean()
df_s_9_cool_with_mean = df_s_9_cool.copy(); df_s_9_cool_with_mean[df_s_9_cool_with_mean.isnull()] = df_s_9_cool.mean()
df_s_10_cool_with_mean = df_s_10_cool.copy(); df_s_10_cool_with_mean[df_s_10_cool_with_mean.isnull()] = df_s_10_cool.mean()
df_s_11_cool_with_mean = df_s_11_cool.copy(); df_s_11_cool_with_mean[df_s_11_cool_with_mean.isnull()] = df_s_11_cool.mean()
df_s_12_cool_with_mean = df_s_12_cool.copy(); df_s_12_cool_with_mean[df_s_12_cool_with_mean.isnull()] = df_s_12_cool.mean()
df_s_13_cool_with_mean = df_s_13_cool.copy(); df_s_13_cool_with_mean[df_s_13_cool_with_mean.isnull()] = df_s_13_cool.mean()
df_s_14_cool_with_mean = df_s_14_cool.copy(); df_s_14_cool_with_mean[df_s_14_cool_with_mean.isnull()] = df_s_14_cool.mean()
df_s_15_cool_with_mean = df_s_15_cool.copy(); df_s_15_cool_with_mean[df_s_15_cool_with_mean.isnull()] = df_s_15_cool.mean()
df_s_16_cool_with_mean = df_s_16_cool.copy(); df_s_16_cool_with_mean[df_s_16_cool_with_mean.isnull()] = df_s_16_cool.mean()
df_s_17_cool_with_mean = df_s_17_cool.copy(); df_s_17_cool_with_mean[df_s_17_cool_with_mean.isnull()] = df_s_17_cool.mean()
df_s_18_cool_with_mean = df_s_18_cool.copy(); df_s_18_cool_with_mean[df_s_18_cool_with_mean.isnull()] = df_s_18_cool.mean()
df_s_19_cool_with_mean = df_s_19_cool.copy(); df_s_19_cool_with_mean[df_s_19_cool_with_mean.isnull()] = df_s_19_cool.mean()
df_s_20_cool_with_mean = df_s_20_cool.copy(); df_s_20_cool_with_mean[df_s_20_cool_with_mean.isnull()] = df_s_20_cool.mean()

# 각 각의 Station 별로 cool의 값이 np.nan일 때, 즉, missing value를 뺏을 때의 전체 mean 값을 나타낸다. 
print('#station1_without_nan_mean:', round(df_s_1_cool.mean(),4), '#station1_without_nan_std:', round(df_s_1_cool.std(),4)); 
print('#station2_without_nan_mean:', round(df_s_2_cool.mean(),4), '#station2_without_nan_std:', round(df_s_2_cool.std(),4)); 
print('#station3_without_nan_mean:', round(df_s_3_cool.mean(),4), '#station3_without_nan_std:', round(df_s_3_cool.std(),4)); 
print('#station4_without_nan_mean:', round(df_s_4_cool.mean(),4), '#station4_without_nan_std:', round(df_s_4_cool.std(),4)); 
print('#station5_without_nan_mean:', round(df_s_5_cool.mean(),4), '#station5_without_nan_std:', round(df_s_5_cool.std(),4)); 
print('#station6_without_nan_mean:', round(df_s_6_cool.mean(),4), '#station6_without_nan_std:', round(df_s_6_cool.std(),4)); 
print('#station7_without_nan_mean:', round(df_s_7_cool.mean(),4), '#station7_without_nan_std:', round(df_s_7_cool.std(),4)); 
print('#station8_without_nan_mean:', round(df_s_8_cool.mean(),4), '#station8_without_nan_std:', round(df_s_8_cool.std(),4)); 
print('#station9_without_nan_mean:', round(df_s_9_cool.mean(),4), '#station9_without_nan_std:', round(df_s_9_cool.std(),4)); 
print('#station10_without_nan_mean:', round(df_s_10_cool.mean(),4), '#station10_without_nan_std:', round(df_s_10_cool.std(),4));  
print('#station11_without_nan_mean:', round(df_s_11_cool.mean(),4), '#station11_without_nan_std:', round(df_s_11_cool.std(),4)); 
print('#station12_without_nan_mean:', round(df_s_12_cool.mean(),4), '#station12_without_nan_std:', round(df_s_12_cool.std(),4)); 
print('#station13_without_nan_mean:', round(df_s_13_cool.mean(),4), '#station13_without_nan_std:', round(df_s_13_cool.std(),4)); 
print('#station14_without_nan_mean:', round(df_s_14_cool.mean(),4), '#station14_without_nan_std:', round(df_s_14_cool.std(),4)); 
print('#station15_without_nan_mean:', round(df_s_15_cool.mean(),4), '#station15_without_nan_std:', round(df_s_15_cool.std(),4)); 
print('#station16_without_nan_mean:', round(df_s_16_cool.mean(),4), '#station16_without_nan_std:', round(df_s_16_cool.std(),4)); 
print('#station17_without_nan_mean:', round(df_s_17_cool.mean(),4), '#station17_without_nan_std:', round(df_s_17_cool.std(),4)); 
print('#station18_without_nan_mean:', round(df_s_18_cool.mean(),4), '#station18_without_nan_std:', round(df_s_18_cool.std(),4)); 
print('#station19_without_nan_mean:', round(df_s_19_cool.mean(),4), '#station19_without_nan_std:', round(df_s_19_cool.std(),4)); 
print('#station20_without_nan_mean:', round(df_s_20_cool.mean(),4), '#station20_without_nan_std:', round(df_s_20_cool.std(),4)); 

print('stat1_nan_as_mean:',round(df_s_1_cool_with_mean.mean(),4),'#stat1_nan_as_std:', round(df_s_1_cool_with_mean.std(),4));
print('stat2_nan_as_mean:',round(df_s_2_cool_with_mean.mean(),4),'#stat2_nan_as_std:', round(df_s_2_cool_with_mean.std(),4));
print('stat3_nan_as_mean:',round(df_s_3_cool_with_mean.mean(),4),'#stat3_nan_as_std:', round(df_s_3_cool_with_mean.std(),4));
print('stat4_nan_as_mean:',round(df_s_4_cool_with_mean.mean(),4),'#stat4_nan_as_std:', round(df_s_4_cool_with_mean.std(),4));
print('stat5_nan_as_mean:',round(df_s_5_cool_with_mean.mean(),4),'#stat5_nan_as_std:', round(df_s_5_cool_with_mean.std(),4));
print('stat6_nan_as_mean:',round(df_s_6_cool_with_mean.mean(),4),'#stat6_nan_as_std:', round(df_s_6_cool_with_mean.std(),4));
print('stat7_nan_as_mean:',round(df_s_7_cool_with_mean.mean(),4),'#stat7_nan_as_std:', round(df_s_7_cool_with_mean.std(),4));
print('stat8_nan_as_mean:',round(df_s_8_cool_with_mean.mean(),4),'#stat8_nan_as_std:', round(df_s_8_cool_with_mean.std(),4));
print('stat9_nan_as_mean:',round(df_s_9_cool_with_mean.mean(),4),'#stat9_nan_as_std:', round(df_s_9_cool_with_mean.std(),4));
print('stat10_nan_as_mean:',round(df_s_10_cool_with_mean.mean(),4),'#stat10_nan_as_std:', round(df_s_10_cool_with_mean.std(),4));
print('stat11_nan_as_mean:',round(df_s_11_cool_with_mean.mean(),4),'#stat11_nan_as_std:', round(df_s_11_cool_with_mean.std(),4));
print('stat12_nan_as_mean:',round(df_s_12_cool_with_mean.mean(),4),'#stat12_nan_as_std:', round(df_s_12_cool_with_mean.std(),4));
print('stat13_nan_as_mean:',round(df_s_13_cool_with_mean.mean(),4),'#stat13_nan_as_std:', round(df_s_13_cool_with_mean.std(),4));
print('stat14_nan_as_mean:',round(df_s_14_cool_with_mean.mean(),4),'#stat14_nan_as_std:', round(df_s_14_cool_with_mean.std(),4));
print('stat15_nan_as_mean:',round(df_s_15_cool_with_mean.mean(),4),'#stat15_nan_as_std:', round(df_s_15_cool_with_mean.std(),4));
print('stat16_nan_as_mean:',round(df_s_16_cool_with_mean.mean(),4),'#stat16_nan_as_std:', round(df_s_16_cool_with_mean.std(),4));
print('stat17_nan_as_mean:',round(df_s_17_cool_with_mean.mean(),4),'#stat17_nan_as_std:', round(df_s_17_cool_with_mean.std(),4));
print('stat18_nan_as_mean:',round(df_s_18_cool_with_mean.mean(),4),'#stat18_nan_as_std:', round(df_s_18_cool_with_mean.std(),4));
print('stat19_nan_as_mean:',round(df_s_19_cool_with_mean.mean(),4),'#stat19_nan_as_std:', round(df_s_19_cool_with_mean.std(),4));
print('stat20_nan_as_mean:',round(df_s_20_cool_with_mean.mean(),4),'#stat20_nan_as_std:', round(df_s_20_cool_with_mean.std(),4));
# Out:
# #station1_without_nan_mean: 2.0639 #station1_without_nan_std: 4.3212
# #station2_without_nan_mean: 1.6407 #station2_without_nan_std: 3.5853
# #station3_without_nan_mean: 6.3289 #station3_without_nan_std: 8.389
# #station4_without_nan_mean: 9.8315 #station4_without_nan_std: 9.2648
# #station5_without_nan_mean: nan #station5_without_nan_std: nan
# #station6_without_nan_mean: 8.5478 #station6_without_nan_std: 8.6833
# #station7_without_nan_mean: 6.4784 #station7_without_nan_std: 8.3325
# #station8_without_nan_mean: 11.1163 #station8_without_nan_std: 9.3163
# #station9_without_nan_mean: 2.2898 #station9_without_nan_std: 4.6305
# #station10_without_nan_mean: 10.1369 #station10_without_nan_std: 8.1236
# #station11_without_nan_mean: 7.656 #station11_without_nan_std: 7.0557
# #station12_without_nan_mean: 8.3032 #station12_without_nan_std: 7.4584
# #station13_without_nan_mean: 2.0943 #station13_without_nan_std: 4.0589
# #station14_without_nan_mean: 6.0126 #station14_without_nan_std: 8.1015
# ...

# %%
y1 = np.array([df_s_1_cool.mean(), df_s_2_cool.mean(), df_s_3_cool.mean(), df_s_4_cool.mean(), df_s_5_cool.mean(),
             df_s_6_cool.mean(), df_s_7_cool.mean(), df_s_8_cool.mean(), df_s_9_cool.mean(), df_s_10_cool.mean(), 
             df_s_11_cool.mean(), df_s_12_cool.mean(), df_s_13_cool.mean(), df_s_14_cool.mean(), df_s_15_cool.mean(),
             df_s_16_cool.mean(), df_s_17_cool.mean(), df_s_18_cool.mean(), df_s_19_cool.mean(), df_s_20_cool.mean()])

y2 = np.array([df_s_1_cool_with_mean.mean(), df_s_2_cool_with_mean.mean(), df_s_3_cool_with_mean.mean(), df_s_4_cool_with_mean.mean()
             ,df_s_5_cool_with_mean.mean(), df_s_6_cool_with_mean.mean(), df_s_7_cool_with_mean.mean(), df_s_8_cool_with_mean.mean()
             ,df_s_9_cool_with_mean.mean(), df_s_10_cool_with_mean.mean(), df_s_11_cool_with_mean.mean(), df_s_12_cool_with_mean.mean()
             ,df_s_13_cool_with_mean.mean(), df_s_14_cool_with_mean.mean(), df_s_15_cool_with_mean.mean(), df_s_16_cool_with_mean.mean()
             ,df_s_17_cool_with_mean.mean(),df_s_18_cool_with_mean.mean(),df_s_19_cool_with_mean.mean(),df_s_20_cool_with_mean.mean()])

plt.figure(figsize=(10,5))
plt.plot()
x = range(1, 21)
plt.xlabel('Station Number')
plt.ylabel('cool')
plt.bar(x, y1, color='y')
plt.bar(x, y2, color='r')
plt.show()

#### cool 에서는
# 이 Graph가 나타내는 바는, y1과 y2가 차이가 거의 없다는 것. 그래프에는 r color와 y color이 있는데, 하나만 보인다는 것은
# 우리가 그래프에서 눈으로 보이지 않는 정도의 차이가 나온다는 것이다, 즉 차이가 극히 작다고 판단 할 수 있다.
# Missing Values를 np.nan으로 바꾸고, 거기서 Mean 값을 구하여 np.nan에 대입하여도, 
# 따라서, 여기서는 Missing Value에 Mean값을 적용하여 회귀 분석에 적용 할 수있다고 판단된다. 
plt.figure(figsize=(12,6))
xticks = range(1,21)
plt.plot(xticks, y1, 'ro-', label='stations_without_nan_mean')
plt.plot(xticks, y2, 'bd:', label='stations_nan_as_mean')
plt.legend(loc=0)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
y3 = np.array([df_s_1_cool.std(), df_s_2_cool.std(), df_s_3_cool.std(), df_s_4_cool.std(), df_s_5_cool.std(),
             df_s_6_cool.std(), df_s_7_cool.std(), df_s_8_cool.std(), df_s_9_cool.std(), df_s_10_cool.std(), 
             df_s_11_cool.std(), df_s_12_cool.std(), df_s_13_cool.std(), df_s_14_cool.std(), df_s_15_cool.std(),
             df_s_16_cool.std(), df_s_17_cool.std(), df_s_18_cool.std(), df_s_19_cool.std(), df_s_20_cool.std()])

y4 = np.array([df_s_1_cool_with_mean.std(), df_s_2_cool_with_mean.std(), df_s_3_cool_with_mean.std(), df_s_4_cool_with_mean.std()
             ,df_s_5_cool_with_mean.std(), df_s_6_cool_with_mean.std(), df_s_7_cool_with_mean.std(), df_s_8_cool_with_mean.std()
             ,df_s_9_cool_with_mean.std(), df_s_10_cool_with_mean.std(), df_s_11_cool_with_mean.std(), df_s_12_cool_with_mean.std()
             ,df_s_13_cool_with_mean.std(), df_s_14_cool_with_mean.std(), df_s_15_cool_with_mean.std(), df_s_16_cool_with_mean.std()
             ,df_s_17_cool_with_mean.std(),df_s_18_cool_with_mean.std(),df_s_19_cool_with_mean.std(),df_s_20_cool_with_mean.std()])

plt.figure(figsize=(10,5))
plt.plot()
x = range(1, 21)
plt.xlabel('Station Number')
plt.ylabel('cool')
plt.bar(x, y3, color='r')
plt.bar(x, y4, color='g')
plt.show()

plt.figure(figsize=(12,6))
xticks = range(1,21)
plt.plot(xticks, y3, 'ro-', label='stations_without_nan_std')
plt.plot(xticks, y4, 'bd:', label='stations_nan_as_std')
plt.legend(loc=0)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1320: UserWarning: findfont: Font family ['nanumgothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
